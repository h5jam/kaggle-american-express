# %%
import pandas as pd
import numpy as np
import pickle
from matplotlib import pyplot as plt
import random
import datetime
import math
from matplotlib.ticker import MaxNLocator
from colorama import Fore, Back, Style
import gc
import copy

from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler, QuantileTransformer, OneHotEncoder
from sklearn.metrics import roc_curve, roc_auc_score, average_precision_score

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import MultiStepLR

INFERENCE = True

# %%
def amex_metric(y_true, y_pred, return_components=False) -> float:
    """Amex metric for ndarrays"""
    def top_four_percent_captured(df) -> float:
        """Corresponds to the recall for a threshold of 4 %"""
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        four_pct_cutoff = int(0.04 * df['weight'].sum())
        df['weight_cumsum'] = df['weight'].cumsum()
        df_cutoff = df.loc[df['weight_cumsum'] <= four_pct_cutoff]
        return (df_cutoff['target'] == 1).sum() / (df['target'] == 1).sum()
        
    def weighted_gini(df) -> float:
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        df['random'] = (df['weight'] / df['weight'].sum()).cumsum()
        total_pos = (df['target'] * df['weight']).sum()
        df['cum_pos_found'] = (df['target'] * df['weight']).cumsum()
        df['lorentz'] = df['cum_pos_found'] / total_pos
        df['gini'] = (df['lorentz'] - df['random']) * df['weight']
        return df['gini'].sum()

    def normalized_weighted_gini(df) -> float:
        """Corresponds to 2 * AUC - 1"""
        df2 = pd.DataFrame({'target': df.target, 'prediction': df.target})
        df2.sort_values('prediction', ascending=False, inplace=True)
        return weighted_gini(df) / weighted_gini(df2)

    df = pd.DataFrame({'target': y_true.ravel(), 'prediction': y_pred.ravel()})
    df.sort_values('prediction', ascending=False, inplace=True)
    g = normalized_weighted_gini(df)
    d = top_four_percent_captured(df)
    print("G: {:.6f}, D: {:.6f}, ALL: {:6f}".format(g, d, 0.5*(g+d)))
    if return_components: return g, d, 0.5 * (g + d)
    return 0.5 * (g + d)

# %%
# %%time
features_avg = ['B_11', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_2', 
                'B_20', 'B_28', 'B_29', 'B_3', 'B_33', 'B_36', 'B_37', 'B_4', 'B_42', 
                'B_5', 'B_8', 'B_9', 'D_102', 'D_103', 'D_105', 'D_111', 'D_112', 'D_113', 
                'D_115', 'D_118', 'D_119', 'D_121', 'D_124', 'D_128', 'D_129', 'D_131', 
                'D_132', 'D_133', 'D_139', 'D_140', 'D_141', 'D_143', 'D_144', 'D_145', 
                'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 
                'D_49', 'D_50', 'D_51', 'D_52', 'D_56', 'D_58', 'D_62', 'D_70', 'D_71', 
                'D_72', 'D_74', 'D_75', 'D_79', 'D_81', 'D_83', 'D_84', 'D_88', 'D_91', 
                'P_2', 'P_3', 'R_1', 'R_10', 'R_11', 'R_13', 'R_18', 'R_19', 'R_2', 'R_26', 
                'R_27', 'R_28', 'R_3', 'S_11', 'S_12', 'S_22', 'S_23', 'S_24', 'S_26', 
                'S_27', 'S_5', 'S_7', 'S_8', ]
features_min = ['B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_19', 'B_2', 'B_20', 'B_22', 
                'B_24', 'B_27', 'B_28', 'B_29', 'B_3', 'B_33', 'B_36', 'B_4', 'B_42', 
                'B_5', 'B_9', 'D_102', 'D_103', 'D_107', 'D_109', 'D_110', 'D_111', 
                'D_112', 'D_113', 'D_115', 'D_118', 'D_119', 'D_121', 'D_122', 'D_128', 
                'D_129', 'D_132', 'D_133', 'D_139', 'D_140', 'D_141', 'D_143', 'D_144', 
                'D_145', 'D_39', 'D_41', 'D_42', 'D_45', 'D_46', 'D_48', 'D_50', 'D_51', 
                'D_53', 'D_54', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_62', 'D_70', 
                'D_71', 'D_74', 'D_75', 'D_78', 'D_79', 'D_81', 'D_83', 'D_84', 'D_86', 
                'D_88', 'D_96', 'P_2', 'P_3', 'P_4', 'R_1', 'R_11', 'R_13', 'R_17', 'R_19', 
                'R_2', 'R_27', 'R_28', 'R_4', 'R_5', 'R_8', 'S_11', 'S_12', 'S_23', 'S_25', 
                'S_3', 'S_5', 'S_7', 'S_9', ]
features_max = ['B_1', 'B_11', 'B_13', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_2', 
                'B_22', 'B_24', 'B_27', 'B_28', 'B_29', 'B_3', 'B_31', 'B_33', 'B_36', 
                'B_4', 'B_42', 'B_5', 'B_7', 'B_9', 'D_102', 'D_103', 'D_105', 'D_109', 
                'D_110', 'D_112', 'D_113', 'D_115', 'D_121', 'D_124', 'D_128', 'D_129', 
                'D_131', 'D_139', 'D_141', 'D_144', 'D_145', 'D_39', 'D_41', 'D_42', 
                'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_50', 'D_51', 'D_52', 
                'D_53', 'D_56', 'D_58', 'D_59', 'D_60', 'D_62', 'D_70', 'D_72', 'D_74', 
                'D_75', 'D_79', 'D_81', 'D_83', 'D_84', 'D_88', 'D_89', 'P_2', 'P_3', 
                'R_1', 'R_10', 'R_11', 'R_26', 'R_28', 'R_3', 'R_4', 'R_5', 'R_7', 'R_8', 
                'S_11', 'S_12', 'S_23', 'S_25', 'S_26', 'S_27', 'S_3', 'S_5', 'S_7', 'S_8', ]
features_last = ['B_1', 'B_11', 'B_12', 'B_13', 'B_14', 'B_16', 'B_18', 'B_19', 'B_2', 
                 'B_20', 'B_21', 'B_24', 'B_27', 'B_28', 'B_29', 'B_3', 'B_30', 'B_31', 
                 'B_33', 'B_36', 'B_37', 'B_38', 'B_39', 'B_4', 'B_40', 'B_42', 'B_5', 
                 'B_8', 'B_9', 'D_102', 'D_105', 'D_106', 'D_107', 'D_108', 'D_110', 
                 'D_111', 'D_112', 'D_113', 'D_114', 'D_115', 'D_116', 'D_117', 'D_118', 
                 'D_119', 'D_120', 'D_121', 'D_124', 'D_126', 'D_128', 'D_129', 'D_131', 
                 'D_132', 'D_133', 'D_137', 'D_138', 'D_139', 'D_140', 'D_141', 'D_142', 
                 'D_143', 'D_144', 'D_145', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 
                 'D_46', 'D_47', 'D_48', 'D_49', 'D_50', 'D_51', 'D_52', 'D_53', 'D_55', 
                 'D_56', 'D_59', 'D_60', 'D_62', 'D_63', 'D_64', 'D_66', 'D_68', 'D_70', 
                 'D_71', 'D_72', 'D_73', 'D_74', 'D_75', 'D_77', 'D_78', 'D_81', 'D_82', 
                 'D_83', 'D_84', 'D_88', 'D_89', 'D_91', 'D_94', 'D_96', 'P_2', 'P_3', 
                 'P_4', 'R_1', 'R_10', 'R_11', 'R_12', 'R_13', 'R_16', 'R_17', 'R_18', 
                 'R_19', 'R_25', 'R_28', 'R_3', 'R_4', 'R_5', 'R_8', 'S_11', 'S_12', 
                 'S_23', 'S_25', 'S_26', 'S_27', 'S_3', 'S_5', 'S_7', 'S_8', 'S_9', ]
features_categorical = ['B_30_last', 'B_38_last', 'D_114_last', 'D_116_last',
                        'D_117_last', 'D_120_last', 'D_126_last',
                        'D_63_last', 'D_64_last', 'D_66_last', 'D_68_last']

na_features = ['D_87', 'D_88', 'D_108', 'D_111', 'D_110', 'B_39', 'D_73', 'B_42',
       'D_136', 'D_138', 'D_137', 'D_135', 'D_134', 'R_9', 'B_29', 'D_106',
       'D_132', 'D_49', 'R_26', 'D_76']

features_avg = list(set(features_avg) - set([]))
features_min = list(set(features_min) - set(na_features))
features_max = list(set(features_max) - set(na_features))
features_last = list(set(features_last) - set(na_features))

for i in [0, 1] if INFERENCE else [0]:
    # i == 0 -> process the train data
    # i == 1 -> process the test data
    df = pd.read_feather(['train_data.ftr',
                          'test_data.ftr'][i])
    cid = pd.Categorical(df.pop('customer_ID'), ordered=True)
    last = (cid != np.roll(cid, -1)) # mask for last statement of every customer
    if i == 0: # train
        target = df.loc[last, 'target']
    print('Read', i)
    gc.collect()
    df_avg = (df
              .groupby(cid)
              .mean()[features_avg]
              .rename(columns={f: f"{f}_avg" for f in features_avg})
             )
    print('Computed avg', i)
    gc.collect()
    df_max = (df
              .groupby(cid)
              .max()[features_max]
              .rename(columns={f: f"{f}_max" for f in features_max})
             )
    print('Computed max', i)
    gc.collect()
    df_min = (df
              .groupby(cid)
              .min()[features_min]
              .rename(columns={f: f"{f}_min" for f in features_min})
             )
    print('Computed min', i)
    gc.collect()
    df_last = (df.loc[last, features_last]
               .rename(columns={f: f"{f}_last" for f in features_last})
               .set_index(np.asarray(cid[last]))
              )
    df = None # we no longer need the original data
    print('Computed last', i)
    
    df_categorical = df_last[features_categorical].astype(object)
    features_not_cat = [f for f in df_last.columns if f not in features_categorical]
    if i == 0: # train
        ohe = OneHotEncoder(drop='first', sparse=False, dtype=np.float32, handle_unknown='ignore')
        ohe.fit(df_categorical)
        with open("ohe.pickle", 'wb') as f: pickle.dump(ohe, f)
    df_categorical = pd.DataFrame(ohe.transform(df_categorical).astype(np.float16),
                                  index=df_categorical.index).rename(columns=str)
    print('Computed categorical', i)
    
    df = pd.concat([df_last[features_not_cat], df_categorical, df_avg, df_min, df_max], axis=1)
    
    # Impute missing values
    df.fillna(value=0, inplace=True)
    
    del df_avg, df_max, df_min, df_last, df_categorical, cid, last, features_not_cat
    
    if i == 0: # train
        # Free the memory
        df.reset_index(drop=True, inplace=True) # frees 0.2 GByte
        df.to_feather('train_processed.ftr')
        df = None
        gc.collect()

train = pd.read_feather('train_processed.ftr')
test = df
del df, ohe

print('Shapes:', train.shape, target.shape)
# Out:
# Read 0
# Computed avg 0
# <timed exec>:79: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
# Computed max 0
# <timed exec>:86: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
# Computed min 0
# Computed last 0
# Computed categorical 0
# Read 1
# Computed avg 1
# <timed exec>:79: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
# Computed max 1
# <timed exec>:86: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
# Computed min 1
# Computed last 1
# Computed categorical 1
# Shapes: (458913, 404) (458913,)
# CPU times: user 2min 4s, sys: 34.5 s, total: 2min 39s
# Wall time: 2min 6s

# %%
class my_model(nn.Module):
    def __init__(self, in_feat, hid_dim=256, activation=nn.ReLU(), dropout=0.1):
        super(my_model, self).__init__()
        self.encode = nn.Linear(in_feat, hid_dim)
        self.activation = activation
        self.hidden1 = nn.Linear(hid_dim, 64)
        self.hidden2 = nn.Linear(64, 64)
        self.drop = nn.Dropout(dropout)
        self.hidden3 = nn.Linear(64+hid_dim, 16)
        self.pred = nn.Linear(16, 2)
    
    def forward(self, x):
        h0 = self.activation(self.encode(x))
        h1 = self.activation(self.hidden2(self.activation(self.hidden1(h0))))
        h = self.drop(torch.concat([h0, h1], dim=-1))
        h = self.activation(self.hidden3(h))
        return self.pred(h)

# %%
class early_stopper(object):
    def __init__(self, patience=12, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.delta = delta
        self.best_value = None
        self.best_cv = None
        self.is_earlystop = False
        self.count = 0
        self.best_model = None
        #self.val_preds = []
        #self.val_logits = []

    def earlystop(self, loss, value, model=None):#, preds, logits):
        """
        value: evaluation value on valiation dataset
        """
        cv = value
        if self.best_value is None:
            self.best_value = value
            self.best_cv = cv
            self.best_model = copy.deepcopy(model).to('cpu')
            #self.val_preds = preds
            #self.val_logits = logits
        elif value < self.best_value + self.delta:
            self.count += 1
            if self.verbose:
                print('EarlyStoper count: {:02d}'.format(self.count))
            if self.count >= self.patience:
                self.is_earlystop = True
        else:
            self.best_value = value
            self.best_cv = cv
            self.best_model = copy.deepcopy(model).to('cpu')
            #self.val_preds = preds
            #self.val_logits = logits
            self.count = 0

# %%
def fit_model(train_nn, train_y, test_nn, params):
    device = params['device']
    oof_predictions = torch.from_numpy(np.zeros([len(train_nn), 2])).float().to(device)
    test_predictions = torch.from_numpy(np.zeros([len(test_nn), 2])).float().to(device)
    kfold = StratifiedKFold(n_splits=params['n_fold'], shuffle=True, random_state=params['seed'])
    features_numerical = [f for f in train_nn.columns if f != 'target' and f != 'customer_ID']
    y_target = train_y.target.values
    num_feat = train_nn[features_numerical]
    y = train_y.target
    labels = torch.from_numpy(y.values).long().to(device)
    loss_fn = nn.CrossEntropyLoss(weight=torch.from_numpy(np.array([118828, 340085])).float()).to(device)
    for fold, (trn_idx, val_idx) in enumerate(kfold.split(train_nn, y_target)):
        print(f'Training fold {fold + 1}')
        x_train, x_val = num_feat.iloc[trn_idx], num_feat.iloc[val_idx]
        scaler = StandardScaler()
        x_train = torch.from_numpy(scaler.fit_transform(x_train)).float().to(device)
        x_val = torch.from_numpy(scaler.transform(x_val)).float().to(device)
        y_train, y_val = labels[trn_idx], labels[val_idx]
        train_sample_strategy = torch.utils.data.sampler.WeightedRandomSampler(np.ones(len(trn_idx)),
                                                                               num_samples=len(trn_idx), replacement=False)
        train_dataloader = torch.utils.data.DataLoader(np.array(range(len(trn_idx))), batch_size=params['batch_size'], num_workers=0,
                                                       sampler=train_sample_strategy, drop_last=False)
        val_sample_strategy = torch.utils.data.sampler.WeightedRandomSampler(np.ones(len(val_idx)),
                                                                             num_samples=len(val_idx), replacement=False)
        val_dataloader = torch.utils.data.DataLoader(np.array(range(len(val_idx))), batch_size=params['batch_size'], num_workers=0,
                                                     sampler=val_sample_strategy, drop_last=False)
        model = eval(params['model'])(x_train.shape[1]).to(device)
        lr = params['lr'] * np.sqrt(params['batch_size']/2048)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=params['wd'])
        lr_scheduler = MultiStepLR(optimizer=optimizer, milestones=[800, 1600, 2400, 3200, 4000, 4800, 5600, 6400, 7200], gamma=0.6)
        earlystoper = early_stopper(patience=params['early_stopping'], verbose=True)
        start_epoch = 0
        for epoch in range(start_epoch, params['max_epochs']):
            train_loss_list = []
            # train_acc_list = []
            model.train()
            for step, input_seeds in enumerate(train_dataloader):
                batch_inputs = x_train[input_seeds].to(device)
                batch_labels = y_train[input_seeds].to(device)
                train_batch_logits = model(batch_inputs)
                train_loss = loss_fn(train_batch_logits, batch_labels)
                # backward
                optimizer.zero_grad()
                train_loss.backward()
                optimizer.step()
                lr_scheduler.step()
                train_loss_list.append(train_loss.cpu().detach().numpy())
                
                #tr_batch_pred = None

                if step % 10 == 0:
                    tr_batch_pred = torch.sum(torch.argmax(train_batch_logits.clone().detach(), dim=1) == batch_labels) / batch_labels.shape[0]
                    score = torch.softmax(train_batch_logits.clone().detach(), dim=1)[:, 1].cpu().numpy()
                    print('In epoch:{:03d}|batch:{:04d}, train_loss:{:4f}, '
                          'train_ap:{:.4f}, train_acc:{:.4f}, train_auc:{:.4f}'.format(epoch,step,
                                                                                       np.mean(train_loss_list),
                                                                                       average_precision_score(batch_labels.cpu().numpy(), score), 
                                                                                       tr_batch_pred.detach(),
                                                                                       roc_auc_score(batch_labels.cpu().numpy(), score)))
        
            # mini-batch for validation
            val_loss_list = 0
            val_acc_list = 0
            #val_correct_list = 0
            val_all_list = 0
            model.eval()
            with torch.no_grad():
                for step, input_seeds in enumerate(val_dataloader):
                    batch_inputs = x_val[input_seeds].to(device)
                    batch_labels = y_val[input_seeds].to(device)
                    val_batch_logits = model(batch_inputs)
                    oof_predictions[val_idx[input_seeds]] = val_batch_logits
                    val_loss_list = val_loss_list + loss_fn(val_batch_logits, batch_labels)
                    val_batch_pred = torch.sum(torch.argmax(val_batch_logits, dim=1) == batch_labels) / torch.tensor(batch_labels.shape[0])
                    val_acc_list = val_acc_list + val_batch_pred * torch.tensor(batch_labels.shape[0])
                    val_all_list = val_all_list + batch_labels.shape[0]
                    if step % 10 == 0:
                        score = torch.softmax(val_batch_logits.clone().detach(), dim=1)[:, 1].cpu().numpy()
                        print('In epoch:{:03d}|batch:{:04d}, val_loss:{:4f}, val_ap:{:.4f}, '
                              'val_acc:{:.4f}, val_auc:{:.4f}'.format(epoch,
                                                                      step,
                                                                      val_loss_list/val_all_list,
                                                                      average_precision_score(batch_labels.cpu().numpy(), score), 
                                                                      val_batch_pred.detach(),
                                                                      roc_auc_score(batch_labels.cpu().numpy(), score)))
                #tmp_predictions = model(test_feature).cpu().numpy()
            #infold_preds[fold] = tmp_predictions
            #test_predictions += tmp_predictions / params['n_fold']
            val_predictions = torch.softmax(oof_predictions[val_idx, :].detach(), dim=-1)[:, 1].cpu().numpy()
            earlystoper.earlystop(val_loss_list, amex_metric(y_val.float().cpu().numpy(), val_predictions), model)
            if earlystoper.is_earlystop:
                print("Early Stopping!")
                break
        print("Best val_metric is: {:.7f}".format(earlystoper.best_cv))
        test_sample_strategy = torch.utils.data.sampler.WeightedRandomSampler(np.ones(len(test_nn)),
                                                                              num_samples=len(test_nn), replacement=False)
        test_dataloader = torch.utils.data.DataLoader(np.array(range(len(test_nn))), batch_size=params['batch_size'], num_workers=0,
                                                      sampler=test_sample_strategy, drop_last=False)
        test_num_feat = torch.from_numpy(scaler.transform(test_nn[features_numerical])).float().to(device)
        b_model = earlystoper.best_model.to(device)
        b_model.eval()
        with torch.no_grad():
            for step, input_seeds in enumerate(test_dataloader):
                batch_inputs = test_num_feat[input_seeds].to(device)
                test_batch_logits = b_model(batch_inputs)
                test_predictions[input_seeds] = test_batch_logits
                #test_batch_pred = torch.sum(torch.argmax(test_batch_logits, dim=1) == batch_labels) / torch.tensor(batch_labels.shape[0])
                if step % 10 == 0:
                    print('In test batch:{:04d}'.format(step))
    #my_acc = acc(y, oof_predictions)
    my_ap = average_precision_score(y_target, torch.softmax(oof_predictions, dim=1).cpu()[:, 1])
    print("NN out of fold AP is:", my_ap)
    return earlystoper.best_model.to('cpu'), oof_predictions, test_predictions

# %%
params = {
    'model': 'my_model',
    'batch_size': 2048,
    'lr': 0.01,
    'wd': 4e-4,
    #'device': 'cpu',
    'device': 'cuda:0',
    'early_stopping': 12,
    'n_fold': 5,
    'seed': 2021,
    'max_epochs': 200,
}

b_models, val_nn_0, test_nn_0 = fit_model(train_nn=train,
                                          train_y=pd.DataFrame(target), 
                                          test_nn=test,
                                          params=params)
# Out:
# Training fold 1
# In epoch:000|batch:0000, train_loss:0.692965, train_ap:0.3201, train_acc:0.2905, train_auc:0.5511
# In epoch:000|batch:0010, train_loss:0.360310, train_ap:0.8919, train_acc:0.8691, train_auc:0.9571
# In epoch:000|batch:0020, train_loss:0.320793, train_ap:0.8911, train_acc:0.8706, train_auc:0.9589
# In epoch:000|batch:0030, train_loss:0.306330, train_ap:0.8760, train_acc:0.8730, train_auc:0.9524
# In epoch:000|batch:0040, train_loss:0.295106, train_ap:0.8912, train_acc:0.8799, train_auc:0.9593
# In epoch:000|batch:0050, train_loss:0.288479, train_ap:0.8748, train_acc:0.8672, train_auc:0.9528
# In epoch:000|batch:0060, train_loss:0.285578, train_ap:0.9071, train_acc:0.8755, train_auc:0.9645
# In epoch:000|batch:0070, train_loss:0.282965, train_ap:0.8862, train_acc:0.8794, train_auc:0.9576
# In epoch:000|batch:0080, train_loss:0.280583, train_ap:0.8841, train_acc:0.8716, train_auc:0.9540
# In epoch:000|batch:0090, train_loss:0.278913, train_ap:0.8928, train_acc:0.8760, train_auc:0.9564
# In epoch:000|batch:0100, train_loss:0.277826, train_ap:0.8605, train_acc:0.8726, train_auc:0.9516
# In epoch:000|batch:0110, train_loss:0.277328, train_ap:0.8810, train_acc:0.8770, train_auc:0.9552
# In epoch:000|batch:0120, train_loss:0.276293, train_ap:0.8754, train_acc:0.8862, train_auc:0.9603
# In epoch:000|batch:0130, train_loss:0.275557, train_ap:0.8588, train_acc:0.8735, train_auc:0.9477
# In epoch:000|batch:0140, train_loss:0.274606, train_ap:0.8800, train_acc:0.8828, train_auc:0.9558
# In epoch:000|batch:0150, train_loss:0.273794, train_ap:0.8971, train_acc:0.8833, train_auc:0.9619
# In epoch:000|batch:0160, train_loss:0.273210, train_ap:0.8864, train_acc:0.8740, train_auc:0.9521
# In epoch:000|batch:0170, train_loss:0.272342, train_ap:0.9003, train_acc:0.8857, train_auc:0.9628
# In epoch:000|batch:0000, val_loss:0.000123, val_ap:0.8961, val_acc:0.8706, val_auc:0.9607
# In epoch:000|batch:0010, val_loss:0.000125, val_ap:0.9050, val_acc:0.8848, val_auc:0.9642
# In epoch:000|batch:0020, val_loss:0.000127, val_ap:0.8822, val_acc:0.8716, val_auc:0.9590
# In epoch:000|batch:0030, val_loss:0.000127, val_ap:0.8711, val_acc:0.8667, val_auc:0.9504
# In epoch:000|batch:0040, val_loss:0.000128, val_ap:0.8715, val_acc:0.8579, val_auc:0.9487
# G: 0.915115, D: 0.637507, ALL: 0.776311
# In epoch:001|batch:0000, train_loss:0.263940, train_ap:0.8818, train_acc:0.8643, train_auc:0.9580
# In epoch:001|batch:0010, train_loss:0.266368, train_ap:0.8531, train_acc:0.8599, train_auc:0.9454
# In epoch:001|batch:0020, train_loss:0.265528, train_ap:0.8750, train_acc:0.8721, train_auc:0.9513
# In epoch:001|batch:0030, train_loss:0.264252, train_ap:0.8935, train_acc:0.8677, train_auc:0.9571
# In epoch:001|batch:0040, train_loss:0.265675, train_ap:0.8973, train_acc:0.8770, train_auc:0.9586
# In epoch:001|batch:0050, train_loss:0.265876, train_ap:0.8823, train_acc:0.8735, train_auc:0.9544
# In epoch:001|batch:0060, train_loss:0.266718, train_ap:0.8796, train_acc:0.8667, train_auc:0.9510
# In epoch:001|batch:0070, train_loss:0.265902, train_ap:0.9192, train_acc:0.8936, train_auc:0.9686
# In epoch:001|batch:0080, train_loss:0.266272, train_ap:0.8806, train_acc:0.8721, train_auc:0.9513
# In epoch:001|batch:0090, train_loss:0.265827, train_ap:0.8851, train_acc:0.8809, train_auc:0.9547
# In epoch:001|batch:0100, train_loss:0.265198, train_ap:0.8774, train_acc:0.8662, train_auc:0.9562
# In epoch:001|batch:0110, train_loss:0.264931, train_ap:0.8984, train_acc:0.8721, train_auc:0.9576
# In epoch:001|batch:0120, train_loss:0.264733, train_ap:0.8941, train_acc:0.8921, train_auc:0.9647
# In epoch:001|batch:0130, train_loss:0.264809, train_ap:0.8836, train_acc:0.8711, train_auc:0.9542
# In epoch:001|batch:0140, train_loss:0.264795, train_ap:0.8672, train_acc:0.8667, train_auc:0.9551
# In epoch:001|batch:0150, train_loss:0.264220, train_ap:0.8942, train_acc:0.8896, train_auc:0.9579
# In epoch:001|batch:0160, train_loss:0.264900, train_ap:0.8772, train_acc:0.8667, train_auc:0.9519
# In epoch:001|batch:0170, train_loss:0.264466, train_ap:0.8811, train_acc:0.8770, train_auc:0.9580
# In epoch:001|batch:0000, val_loss:0.000136, val_ap:0.8891, val_acc:0.8682, val_auc:0.9537
# In epoch:001|batch:0010, val_loss:0.000130, val_ap:0.9028, val_acc:0.8760, val_auc:0.9626
# In epoch:001|batch:0020, val_loss:0.000129, val_ap:0.8965, val_acc:0.8853, val_auc:0.9632
# In epoch:001|batch:0030, val_loss:0.000128, val_ap:0.8930, val_acc:0.8789, val_auc:0.9618
# In epoch:001|batch:0040, val_loss:0.000127, val_ap:0.9097, val_acc:0.8818, val_auc:0.9670
# G: 0.916135, D: 0.634772, ALL: 0.775454
# EarlyStoper count: 01
# In epoch:002|batch:0000, train_loss:0.262982, train_ap:0.8877, train_acc:0.8774, train_auc:0.9576
# In epoch:002|batch:0010, train_loss:0.261654, train_ap:0.8799, train_acc:0.8765, train_auc:0.9567
# In epoch:002|batch:0020, train_loss:0.263659, train_ap:0.8745, train_acc:0.8877, train_auc:0.9542
# In epoch:002|batch:0030, train_loss:0.264927, train_ap:0.8829, train_acc:0.8750, train_auc:0.9544
# In epoch:002|batch:0040, train_loss:0.265238, train_ap:0.8743, train_acc:0.8750, train_auc:0.9490
# In epoch:002|batch:0050, train_loss:0.263279, train_ap:0.8877, train_acc:0.8823, train_auc:0.9594
# In epoch:002|batch:0060, train_loss:0.264962, train_ap:0.8696, train_acc:0.8770, train_auc:0.9541
# In epoch:002|batch:0070, train_loss:0.265819, train_ap:0.8784, train_acc:0.8623, train_auc:0.9491
# In epoch:002|batch:0080, train_loss:0.264205, train_ap:0.8859, train_acc:0.8730, train_auc:0.9591
# In epoch:002|batch:0090, train_loss:0.263939, train_ap:0.8935, train_acc:0.8813, train_auc:0.9591
# In epoch:002|batch:0100, train_loss:0.263647, train_ap:0.8940, train_acc:0.8652, train_auc:0.9555
# In epoch:002|batch:0110, train_loss:0.263915, train_ap:0.8752, train_acc:0.8730, train_auc:0.9539
# In epoch:002|batch:0120, train_loss:0.263831, train_ap:0.8992, train_acc:0.8862, train_auc:0.9622
# In epoch:002|batch:0130, train_loss:0.263934, train_ap:0.8815, train_acc:0.8794, train_auc:0.9542
# In epoch:002|batch:0140, train_loss:0.264110, train_ap:0.8779, train_acc:0.8774, train_auc:0.9549
# In epoch:002|batch:0150, train_loss:0.264116, train_ap:0.8889, train_acc:0.8818, train_auc:0.9601
# In epoch:002|batch:0160, train_loss:0.263625, train_ap:0.8737, train_acc:0.8779, train_auc:0.9562
# In epoch:002|batch:0170, train_loss:0.264008, train_ap:0.8957, train_acc:0.8838, train_auc:0.9569
# In epoch:002|batch:0000, val_loss:0.000131, val_ap:0.8823, val_acc:0.8613, val_auc:0.9554
# In epoch:002|batch:0010, val_loss:0.000126, val_ap:0.8878, val_acc:0.8652, val_auc:0.9593
# In epoch:002|batch:0020, val_loss:0.000126, val_ap:0.9006, val_acc:0.8560, val_auc:0.9581
# In epoch:002|batch:0030, val_loss:0.000127, val_ap:0.8801, val_acc:0.8633, val_auc:0.9564
# In epoch:002|batch:0040, val_loss:0.000127, val_ap:0.8776, val_acc:0.8555, val_auc:0.9537
# G: 0.916921, D: 0.636918, ALL: 0.776920
# In epoch:003|batch:0000, train_loss:0.256624, train_ap:0.8955, train_acc:0.8657, train_auc:0.9602
# In epoch:003|batch:0010, train_loss:0.261826, train_ap:0.9010, train_acc:0.8828, train_auc:0.9592
# In epoch:003|batch:0020, train_loss:0.260436, train_ap:0.8924, train_acc:0.8818, train_auc:0.9612
# In epoch:003|batch:0030, train_loss:0.260578, train_ap:0.8749, train_acc:0.8721, train_auc:0.9536
# In epoch:003|batch:0040, train_loss:0.261192, train_ap:0.8870, train_acc:0.8701, train_auc:0.9589
# In epoch:003|batch:0050, train_loss:0.261972, train_ap:0.9133, train_acc:0.9023, train_auc:0.9673
# In epoch:003|batch:0060, train_loss:0.261930, train_ap:0.8785, train_acc:0.8486, train_auc:0.9518
# In epoch:003|batch:0070, train_loss:0.262060, train_ap:0.8932, train_acc:0.8818, train_auc:0.9562
# In epoch:003|batch:0080, train_loss:0.262094, train_ap:0.8893, train_acc:0.8755, train_auc:0.9574
# In epoch:003|batch:0090, train_loss:0.262218, train_ap:0.9050, train_acc:0.8906, train_auc:0.9612
# In epoch:003|batch:0100, train_loss:0.262656, train_ap:0.8827, train_acc:0.8760, train_auc:0.9575
# In epoch:003|batch:0110, train_loss:0.262861, train_ap:0.8848, train_acc:0.8730, train_auc:0.9569
# In epoch:003|batch:0120, train_loss:0.263343, train_ap:0.8771, train_acc:0.8809, train_auc:0.9552
# In epoch:003|batch:0130, train_loss:0.263197, train_ap:0.8430, train_acc:0.8613, train_auc:0.9438
# In epoch:003|batch:0140, train_loss:0.263179, train_ap:0.8944, train_acc:0.8818, train_auc:0.9587
# In epoch:003|batch:0150, train_loss:0.262859, train_ap:0.8934, train_acc:0.8901, train_auc:0.9631
# In epoch:003|batch:0160, train_loss:0.263053, train_ap:0.8844, train_acc:0.8706, train_auc:0.9581
# In epoch:003|batch:0170, train_loss:0.263431, train_ap:0.8901, train_acc:0.8760, train_auc:0.9598
# In epoch:003|batch:0000, val_loss:0.000128, val_ap:0.8811, val_acc:0.8608, val_auc:0.9571
# In epoch:003|batch:0010, val_loss:0.000124, val_ap:0.8853, val_acc:0.8657, val_auc:0.9595
# In epoch:003|batch:0020, val_loss:0.000125, val_ap:0.8990, val_acc:0.8789, val_auc:0.9599
# In epoch:003|batch:0030, val_loss:0.000125, val_ap:0.8857, val_acc:0.8633, val_auc:0.9539
# In epoch:003|batch:0040, val_loss:0.000124, val_ap:0.9113, val_acc:0.8794, val_auc:0.9658
# G: 0.918300, D: 0.643524, ALL: 0.780912
# In epoch:004|batch:0000, train_loss:0.264719, train_ap:0.8768, train_acc:0.8667, train_auc:0.9558
# In epoch:004|batch:0010, train_loss:0.271339, train_ap:0.8849, train_acc:0.8711, train_auc:0.9546
# In epoch:004|batch:0020, train_loss:0.268535, train_ap:0.8772, train_acc:0.8755, train_auc:0.9582
# In epoch:004|batch:0030, train_loss:0.265844, train_ap:0.8864, train_acc:0.8828, train_auc:0.9590
# In epoch:004|batch:0040, train_loss:0.264872, train_ap:0.8763, train_acc:0.8794, train_auc:0.9525
# In epoch:004|batch:0050, train_loss:0.265975, train_ap:0.8740, train_acc:0.8579, train_auc:0.9591
# In epoch:004|batch:0060, train_loss:0.266115, train_ap:0.9024, train_acc:0.8687, train_auc:0.9602
# In epoch:004|batch:0070, train_loss:0.265672, train_ap:0.8782, train_acc:0.8608, train_auc:0.9530
# In epoch:004|batch:0080, train_loss:0.266390, train_ap:0.8909, train_acc:0.8770, train_auc:0.9608
# In epoch:004|batch:0090, train_loss:0.266168, train_ap:0.8999, train_acc:0.8750, train_auc:0.9585
# In epoch:004|batch:0100, train_loss:0.265955, train_ap:0.8997, train_acc:0.8818, train_auc:0.9603
# In epoch:004|batch:0110, train_loss:0.265921, train_ap:0.8803, train_acc:0.8726, train_auc:0.9561
# In epoch:004|batch:0120, train_loss:0.265402, train_ap:0.8980, train_acc:0.8818, train_auc:0.9573
# In epoch:004|batch:0130, train_loss:0.264543, train_ap:0.8679, train_acc:0.8643, train_auc:0.9511
# In epoch:004|batch:0140, train_loss:0.264147, train_ap:0.8838, train_acc:0.8750, train_auc:0.9553
# In epoch:004|batch:0150, train_loss:0.263497, train_ap:0.8962, train_acc:0.8779, train_auc:0.9577
# In epoch:004|batch:0160, train_loss:0.263293, train_ap:0.8900, train_acc:0.8760, train_auc:0.9568
# In epoch:004|batch:0170, train_loss:0.262610, train_ap:0.8860, train_acc:0.8706, train_auc:0.9568
# In epoch:004|batch:0000, val_loss:0.000121, val_ap:0.8841, val_acc:0.8857, val_auc:0.9609
# In epoch:004|batch:0010, val_loss:0.000124, val_ap:0.8935, val_acc:0.8691, val_auc:0.9582
# In epoch:004|batch:0020, val_loss:0.000125, val_ap:0.8893, val_acc:0.8735, val_auc:0.9619
# In epoch:004|batch:0030, val_loss:0.000124, val_ap:0.8951, val_acc:0.8779, val_auc:0.9611
# In epoch:004|batch:0040, val_loss:0.000124, val_ap:0.8993, val_acc:0.8755, val_auc:0.9623
# G: 0.918459, D: 0.643356, ALL: 0.780907
# EarlyStoper count: 01
# In epoch:005|batch:0000, train_loss:0.271392, train_ap:0.8732, train_acc:0.8726, train_auc:0.9529
# In epoch:005|batch:0010, train_loss:0.256905, train_ap:0.9105, train_acc:0.8809, train_auc:0.9650
# In epoch:005|batch:0020, train_loss:0.258843, train_ap:0.8723, train_acc:0.8574, train_auc:0.9486
# In epoch:005|batch:0030, train_loss:0.259623, train_ap:0.8980, train_acc:0.8892, train_auc:0.9631
# In epoch:005|batch:0040, train_loss:0.259146, train_ap:0.8871, train_acc:0.8755, train_auc:0.9577
# In epoch:005|batch:0050, train_loss:0.259872, train_ap:0.9082, train_acc:0.8838, train_auc:0.9626
# In epoch:005|batch:0060, train_loss:0.259421, train_ap:0.8668, train_acc:0.8677, train_auc:0.9539
# In epoch:005|batch:0070, train_loss:0.259636, train_ap:0.8957, train_acc:0.8740, train_auc:0.9593
# In epoch:005|batch:0080, train_loss:0.260813, train_ap:0.8913, train_acc:0.8765, train_auc:0.9574
# In epoch:005|batch:0090, train_loss:0.260895, train_ap:0.8963, train_acc:0.8755, train_auc:0.9577
# In epoch:005|batch:0100, train_loss:0.261300, train_ap:0.8706, train_acc:0.8755, train_auc:0.9560
# In epoch:005|batch:0110, train_loss:0.261271, train_ap:0.8836, train_acc:0.8804, train_auc:0.9533
# In epoch:005|batch:0120, train_loss:0.261008, train_ap:0.8924, train_acc:0.8726, train_auc:0.9614
# In epoch:005|batch:0130, train_loss:0.261002, train_ap:0.8881, train_acc:0.8794, train_auc:0.9562
# In epoch:005|batch:0140, train_loss:0.260525, train_ap:0.8871, train_acc:0.8804, train_auc:0.9577
# In epoch:005|batch:0150, train_loss:0.260721, train_ap:0.8749, train_acc:0.8833, train_auc:0.9557
# In epoch:005|batch:0160, train_loss:0.260436, train_ap:0.8878, train_acc:0.8818, train_auc:0.9572
# In epoch:005|batch:0170, train_loss:0.260295, train_ap:0.8874, train_acc:0.8823, train_auc:0.9560
# In epoch:005|batch:0000, val_loss:0.000129, val_ap:0.8856, val_acc:0.8696, val_auc:0.9541
# In epoch:005|batch:0010, val_loss:0.000123, val_ap:0.9084, val_acc:0.8882, val_auc:0.9660
# In epoch:005|batch:0020, val_loss:0.000123, val_ap:0.9030, val_acc:0.8794, val_auc:0.9597
# In epoch:005|batch:0030, val_loss:0.000124, val_ap:0.9024, val_acc:0.8779, val_auc:0.9632
# In epoch:005|batch:0040, val_loss:0.000124, val_ap:0.8944, val_acc:0.8813, val_auc:0.9607
# G: 0.918601, D: 0.642599, ALL: 0.780600
# EarlyStoper count: 02
# In epoch:006|batch:0000, train_loss:0.254083, train_ap:0.8930, train_acc:0.8784, train_auc:0.9582
# In epoch:006|batch:0010, train_loss:0.254945, train_ap:0.9010, train_acc:0.8809, train_auc:0.9611
# In epoch:006|batch:0020, train_loss:0.255202, train_ap:0.8772, train_acc:0.8735, train_auc:0.9564
# In epoch:006|batch:0030, train_loss:0.257713, train_ap:0.8864, train_acc:0.8667, train_auc:0.9555
# In epoch:006|batch:0040, train_loss:0.258162, train_ap:0.8653, train_acc:0.8779, train_auc:0.9545
# In epoch:006|batch:0050, train_loss:0.258652, train_ap:0.8820, train_acc:0.8755, train_auc:0.9557
# In epoch:006|batch:0060, train_loss:0.258197, train_ap:0.8819, train_acc:0.8711, train_auc:0.9577
# In epoch:006|batch:0070, train_loss:0.258026, train_ap:0.8782, train_acc:0.8745, train_auc:0.9557
# In epoch:006|batch:0080, train_loss:0.258536, train_ap:0.8970, train_acc:0.8828, train_auc:0.9610
# In epoch:006|batch:0090, train_loss:0.258819, train_ap:0.8814, train_acc:0.8770, train_auc:0.9548
# In epoch:006|batch:0100, train_loss:0.259890, train_ap:0.9045, train_acc:0.8857, train_auc:0.9639
# In epoch:006|batch:0110, train_loss:0.259801, train_ap:0.8943, train_acc:0.8828, train_auc:0.9599
# In epoch:006|batch:0120, train_loss:0.259971, train_ap:0.8918, train_acc:0.8799, train_auc:0.9587
# In epoch:006|batch:0130, train_loss:0.260258, train_ap:0.8872, train_acc:0.8691, train_auc:0.9553
# In epoch:006|batch:0140, train_loss:0.260522, train_ap:0.8931, train_acc:0.8838, train_auc:0.9611
# In epoch:006|batch:0150, train_loss:0.260767, train_ap:0.8790, train_acc:0.8774, train_auc:0.9548
# In epoch:006|batch:0160, train_loss:0.261011, train_ap:0.8809, train_acc:0.8755, train_auc:0.9550
# In epoch:006|batch:0170, train_loss:0.260350, train_ap:0.9004, train_acc:0.8735, train_auc:0.9570
# In epoch:006|batch:0000, val_loss:0.000123, val_ap:0.8941, val_acc:0.8843, val_auc:0.9596
# In epoch:006|batch:0010, val_loss:0.000122, val_ap:0.9156, val_acc:0.8994, val_auc:0.9675
# In epoch:006|batch:0020, val_loss:0.000122, val_ap:0.9113, val_acc:0.9028, val_auc:0.9666
# In epoch:006|batch:0030, val_loss:0.000123, val_ap:0.8704, val_acc:0.8750, val_auc:0.9524
# In epoch:006|batch:0040, val_loss:0.000124, val_ap:0.8982, val_acc:0.8838, val_auc:0.9611
# G: 0.919257, D: 0.646680, ALL: 0.782968
# In epoch:007|batch:0000, train_loss:0.257562, train_ap:0.8929, train_acc:0.8818, train_auc:0.9583
# In epoch:007|batch:0010, train_loss:0.254802, train_ap:0.9101, train_acc:0.8867, train_auc:0.9626
# In epoch:007|batch:0020, train_loss:0.261637, train_ap:0.8833, train_acc:0.8779, train_auc:0.9580
# In epoch:007|batch:0030, train_loss:0.262268, train_ap:0.8872, train_acc:0.8721, train_auc:0.9544
# In epoch:007|batch:0040, train_loss:0.260615, train_ap:0.8807, train_acc:0.8804, train_auc:0.9582
# In epoch:007|batch:0050, train_loss:0.260136, train_ap:0.9156, train_acc:0.8896, train_auc:0.9659
# In epoch:007|batch:0060, train_loss:0.260133, train_ap:0.8706, train_acc:0.8701, train_auc:0.9516
# In epoch:007|batch:0070, train_loss:0.258659, train_ap:0.8980, train_acc:0.8892, train_auc:0.9595
# In epoch:007|batch:0080, train_loss:0.259209, train_ap:0.9002, train_acc:0.8828, train_auc:0.9564
# In epoch:007|batch:0090, train_loss:0.259216, train_ap:0.8755, train_acc:0.8711, train_auc:0.9495
# In epoch:007|batch:0100, train_loss:0.259566, train_ap:0.8877, train_acc:0.8804, train_auc:0.9569
# In epoch:007|batch:0110, train_loss:0.259639, train_ap:0.8861, train_acc:0.8848, train_auc:0.9527
# In epoch:007|batch:0120, train_loss:0.259806, train_ap:0.8842, train_acc:0.8843, train_auc:0.9581
# In epoch:007|batch:0130, train_loss:0.259813, train_ap:0.9114, train_acc:0.8911, train_auc:0.9681
# In epoch:007|batch:0140, train_loss:0.260027, train_ap:0.8932, train_acc:0.8628, train_auc:0.9593
# In epoch:007|batch:0150, train_loss:0.259846, train_ap:0.9062, train_acc:0.8804, train_auc:0.9668
# In epoch:007|batch:0160, train_loss:0.259904, train_ap:0.8928, train_acc:0.8896, train_auc:0.9606
# In epoch:007|batch:0170, train_loss:0.259835, train_ap:0.8899, train_acc:0.8843, train_auc:0.9579
# In epoch:007|batch:0000, val_loss:0.000123, val_ap:0.8866, val_acc:0.8857, val_auc:0.9586
# In epoch:007|batch:0010, val_loss:0.000122, val_ap:0.8940, val_acc:0.8818, val_auc:0.9602
# In epoch:007|batch:0020, val_loss:0.000121, val_ap:0.8903, val_acc:0.8745, val_auc:0.9568
# In epoch:007|batch:0030, val_loss:0.000123, val_ap:0.8786, val_acc:0.8921, val_auc:0.9567
# In epoch:007|batch:0040, val_loss:0.000124, val_ap:0.8919, val_acc:0.8828, val_auc:0.9599
# G: 0.919252, D: 0.646470, ALL: 0.782861
# EarlyStoper count: 01
# In epoch:008|batch:0000, train_loss:0.257800, train_ap:0.8836, train_acc:0.8774, train_auc:0.9582
# In epoch:008|batch:0010, train_loss:0.254745, train_ap:0.8905, train_acc:0.8867, train_auc:0.9580
# In epoch:008|batch:0020, train_loss:0.254470, train_ap:0.8812, train_acc:0.8804, train_auc:0.9564
# In epoch:008|batch:0030, train_loss:0.255503, train_ap:0.8825, train_acc:0.8667, train_auc:0.9570
# In epoch:008|batch:0040, train_loss:0.257730, train_ap:0.8842, train_acc:0.8745, train_auc:0.9559
# In epoch:008|batch:0050, train_loss:0.257864, train_ap:0.8636, train_acc:0.8589, train_auc:0.9520
# In epoch:008|batch:0060, train_loss:0.258502, train_ap:0.8840, train_acc:0.8711, train_auc:0.9534
# In epoch:008|batch:0070, train_loss:0.258065, train_ap:0.8798, train_acc:0.8691, train_auc:0.9552
# In epoch:008|batch:0080, train_loss:0.258591, train_ap:0.8961, train_acc:0.8818, train_auc:0.9591
# In epoch:008|batch:0090, train_loss:0.258820, train_ap:0.8943, train_acc:0.8804, train_auc:0.9634
# In epoch:008|batch:0100, train_loss:0.259046, train_ap:0.8894, train_acc:0.8828, train_auc:0.9618
# In epoch:008|batch:0110, train_loss:0.259442, train_ap:0.8854, train_acc:0.8711, train_auc:0.9543
# In epoch:008|batch:0120, train_loss:0.260104, train_ap:0.8828, train_acc:0.8711, train_auc:0.9551
# In epoch:008|batch:0130, train_loss:0.260023, train_ap:0.8981, train_acc:0.8892, train_auc:0.9575
# In epoch:008|batch:0140, train_loss:0.260312, train_ap:0.9054, train_acc:0.8916, train_auc:0.9653
# In epoch:008|batch:0150, train_loss:0.260251, train_ap:0.8901, train_acc:0.8735, train_auc:0.9517
# In epoch:008|batch:0160, train_loss:0.259953, train_ap:0.8812, train_acc:0.8730, train_auc:0.9582
# In epoch:008|batch:0170, train_loss:0.260089, train_ap:0.8868, train_acc:0.8716, train_auc:0.9561
# In epoch:008|batch:0000, val_loss:0.000124, val_ap:0.8982, val_acc:0.8867, val_auc:0.9601
# In epoch:008|batch:0010, val_loss:0.000123, val_ap:0.8991, val_acc:0.8906, val_auc:0.9602
# In epoch:008|batch:0020, val_loss:0.000123, val_ap:0.9071, val_acc:0.8901, val_auc:0.9649
# In epoch:008|batch:0030, val_loss:0.000123, val_ap:0.8969, val_acc:0.8882, val_auc:0.9614
# In epoch:008|batch:0040, val_loss:0.000124, val_ap:0.9155, val_acc:0.8872, val_auc:0.9639
# G: 0.919747, D: 0.642262, ALL: 0.781004
# EarlyStoper count: 02
# In epoch:009|batch:0000, train_loss:0.250525, train_ap:0.9084, train_acc:0.8901, train_auc:0.9619
# In epoch:009|batch:0010, train_loss:0.255705, train_ap:0.8929, train_acc:0.8789, train_auc:0.9636
# In epoch:009|batch:0020, train_loss:0.254711, train_ap:0.8860, train_acc:0.8730, train_auc:0.9552
# In epoch:009|batch:0030, train_loss:0.256462, train_ap:0.8911, train_acc:0.8843, train_auc:0.9622
# In epoch:009|batch:0040, train_loss:0.256506, train_ap:0.8754, train_acc:0.8804, train_auc:0.9599
# In epoch:009|batch:0050, train_loss:0.255872, train_ap:0.9087, train_acc:0.8848, train_auc:0.9624
# In epoch:009|batch:0060, train_loss:0.255544, train_ap:0.8704, train_acc:0.8638, train_auc:0.9546
# In epoch:009|batch:0070, train_loss:0.256168, train_ap:0.8918, train_acc:0.8789, train_auc:0.9568
# In epoch:009|batch:0080, train_loss:0.255865, train_ap:0.9047, train_acc:0.8926, train_auc:0.9648
# In epoch:009|batch:0090, train_loss:0.255961, train_ap:0.8844, train_acc:0.8706, train_auc:0.9582
# In epoch:009|batch:0100, train_loss:0.256283, train_ap:0.8831, train_acc:0.8794, train_auc:0.9580
# In epoch:009|batch:0110, train_loss:0.256008, train_ap:0.8861, train_acc:0.8706, train_auc:0.9602
# In epoch:009|batch:0120, train_loss:0.256116, train_ap:0.8845, train_acc:0.8779, train_auc:0.9574
# In epoch:009|batch:0130, train_loss:0.256195, train_ap:0.9038, train_acc:0.8887, train_auc:0.9615
# In epoch:009|batch:0140, train_loss:0.256435, train_ap:0.9005, train_acc:0.8813, train_auc:0.9601
# In epoch:009|batch:0150, train_loss:0.256589, train_ap:0.8945, train_acc:0.8799, train_auc:0.9617
# In epoch:009|batch:0160, train_loss:0.256835, train_ap:0.8669, train_acc:0.8672, train_auc:0.9511
# In epoch:009|batch:0170, train_loss:0.256951, train_ap:0.8907, train_acc:0.8774, train_auc:0.9568
# In epoch:009|batch:0000, val_loss:0.000117, val_ap:0.8928, val_acc:0.8901, val_auc:0.9625
# In epoch:009|batch:0010, val_loss:0.000120, val_ap:0.8897, val_acc:0.8813, val_auc:0.9611
# In epoch:009|batch:0020, val_loss:0.000122, val_ap:0.9075, val_acc:0.8887, val_auc:0.9621
# In epoch:009|batch:0030, val_loss:0.000122, val_ap:0.8905, val_acc:0.8745, val_auc:0.9566
# In epoch:009|batch:0040, val_loss:0.000122, val_ap:0.8901, val_acc:0.8760, val_auc:0.9610
# G: 0.920954, D: 0.648826, ALL: 0.784890
# In epoch:010|batch:0000, train_loss:0.244879, train_ap:0.9029, train_acc:0.8901, train_auc:0.9630
# In epoch:010|batch:0010, train_loss:0.244867, train_ap:0.8920, train_acc:0.8838, train_auc:0.9589
# In epoch:010|batch:0020, train_loss:0.250392, train_ap:0.8914, train_acc:0.8667, train_auc:0.9593
# In epoch:010|batch:0030, train_loss:0.252027, train_ap:0.8982, train_acc:0.8765, train_auc:0.9596
# In epoch:010|batch:0040, train_loss:0.252180, train_ap:0.8854, train_acc:0.8794, train_auc:0.9527
# In epoch:010|batch:0050, train_loss:0.251393, train_ap:0.8972, train_acc:0.8911, train_auc:0.9657
# In epoch:010|batch:0060, train_loss:0.253889, train_ap:0.8851, train_acc:0.8745, train_auc:0.9548
# In epoch:010|batch:0070, train_loss:0.254839, train_ap:0.8803, train_acc:0.8726, train_auc:0.9558
# In epoch:010|batch:0080, train_loss:0.255487, train_ap:0.8973, train_acc:0.8789, train_auc:0.9604
# In epoch:010|batch:0090, train_loss:0.255573, train_ap:0.8833, train_acc:0.8789, train_auc:0.9543
# In epoch:010|batch:0100, train_loss:0.255566, train_ap:0.8694, train_acc:0.8647, train_auc:0.9524
# In epoch:010|batch:0110, train_loss:0.255531, train_ap:0.9077, train_acc:0.8735, train_auc:0.9656
# In epoch:010|batch:0120, train_loss:0.255566, train_ap:0.8877, train_acc:0.8770, train_auc:0.9567
# In epoch:010|batch:0130, train_loss:0.255890, train_ap:0.8893, train_acc:0.8843, train_auc:0.9600
# In epoch:010|batch:0140, train_loss:0.256109, train_ap:0.8862, train_acc:0.8770, train_auc:0.9554
# In epoch:010|batch:0150, train_loss:0.255791, train_ap:0.8880, train_acc:0.8862, train_auc:0.9583
# In epoch:010|batch:0160, train_loss:0.255971, train_ap:0.8907, train_acc:0.8809, train_auc:0.9631
# In epoch:010|batch:0170, train_loss:0.256184, train_ap:0.8867, train_acc:0.8843, train_auc:0.9608
# In epoch:010|batch:0000, val_loss:0.000129, val_ap:0.8840, val_acc:0.8740, val_auc:0.9570
# In epoch:010|batch:0010, val_loss:0.000123, val_ap:0.8845, val_acc:0.8657, val_auc:0.9524
# In epoch:010|batch:0020, val_loss:0.000121, val_ap:0.9136, val_acc:0.8887, val_auc:0.9674
# In epoch:010|batch:0030, val_loss:0.000122, val_ap:0.8768, val_acc:0.8770, val_auc:0.9558
# In epoch:010|batch:0040, val_loss:0.000122, val_ap:0.8977, val_acc:0.8652, val_auc:0.9567
# G: 0.920594, D: 0.648195, ALL: 0.784394
# EarlyStoper count: 01
# In epoch:011|batch:0000, train_loss:0.277818, train_ap:0.8805, train_acc:0.8652, train_auc:0.9526
# In epoch:011|batch:0010, train_loss:0.256687, train_ap:0.8977, train_acc:0.8813, train_auc:0.9620
# In epoch:011|batch:0020, train_loss:0.255262, train_ap:0.8978, train_acc:0.8779, train_auc:0.9619
# In epoch:011|batch:0030, train_loss:0.255031, train_ap:0.8992, train_acc:0.8760, train_auc:0.9590
# In epoch:011|batch:0040, train_loss:0.257128, train_ap:0.8841, train_acc:0.8750, train_auc:0.9556
# In epoch:011|batch:0050, train_loss:0.256910, train_ap:0.8860, train_acc:0.8721, train_auc:0.9577
# In epoch:011|batch:0060, train_loss:0.255921, train_ap:0.9148, train_acc:0.8730, train_auc:0.9661
# In epoch:011|batch:0070, train_loss:0.256071, train_ap:0.9136, train_acc:0.8965, train_auc:0.9694
# In epoch:011|batch:0080, train_loss:0.255920, train_ap:0.8625, train_acc:0.8691, train_auc:0.9468
# In epoch:011|batch:0090, train_loss:0.256515, train_ap:0.8896, train_acc:0.8779, train_auc:0.9586
# In epoch:011|batch:0100, train_loss:0.256534, train_ap:0.8816, train_acc:0.8789, train_auc:0.9541
# In epoch:011|batch:0110, train_loss:0.255924, train_ap:0.8928, train_acc:0.8828, train_auc:0.9635
# In epoch:011|batch:0120, train_loss:0.255944, train_ap:0.8666, train_acc:0.8745, train_auc:0.9501
# In epoch:011|batch:0130, train_loss:0.256395, train_ap:0.9000, train_acc:0.8789, train_auc:0.9585
# In epoch:011|batch:0140, train_loss:0.256863, train_ap:0.8930, train_acc:0.8579, train_auc:0.9549
# In epoch:011|batch:0150, train_loss:0.256892, train_ap:0.8774, train_acc:0.8657, train_auc:0.9568
# In epoch:011|batch:0160, train_loss:0.256673, train_ap:0.8943, train_acc:0.8862, train_auc:0.9564
# In epoch:011|batch:0170, train_loss:0.256856, train_ap:0.8998, train_acc:0.8862, train_auc:0.9604
# In epoch:011|batch:0000, val_loss:0.000123, val_ap:0.8893, val_acc:0.8926, val_auc:0.9604
# In epoch:011|batch:0010, val_loss:0.000122, val_ap:0.9101, val_acc:0.8848, val_auc:0.9620
# In epoch:011|batch:0020, val_loss:0.000121, val_ap:0.8872, val_acc:0.8789, val_auc:0.9604
# In epoch:011|batch:0030, val_loss:0.000122, val_ap:0.9109, val_acc:0.8994, val_auc:0.9641
# In epoch:011|batch:0040, val_loss:0.000122, val_ap:0.8834, val_acc:0.8750, val_auc:0.9548
# G: 0.921255, D: 0.651687, ALL: 0.786471
# In epoch:012|batch:0000, train_loss:0.231434, train_ap:0.9109, train_acc:0.8896, train_auc:0.9657
# In epoch:012|batch:0010, train_loss:0.257280, train_ap:0.9057, train_acc:0.8965, train_auc:0.9633
# In epoch:012|batch:0020, train_loss:0.254567, train_ap:0.9123, train_acc:0.8931, train_auc:0.9642
# In epoch:012|batch:0030, train_loss:0.252768, train_ap:0.8780, train_acc:0.8770, train_auc:0.9563
# In epoch:012|batch:0040, train_loss:0.252910, train_ap:0.8954, train_acc:0.8818, train_auc:0.9568
# In epoch:012|batch:0050, train_loss:0.254502, train_ap:0.8633, train_acc:0.8687, train_auc:0.9545
# In epoch:012|batch:0060, train_loss:0.254257, train_ap:0.8941, train_acc:0.8755, train_auc:0.9597
# In epoch:012|batch:0070, train_loss:0.254820, train_ap:0.8903, train_acc:0.8652, train_auc:0.9574
# In epoch:012|batch:0080, train_loss:0.255585, train_ap:0.8985, train_acc:0.8789, train_auc:0.9630
# In epoch:012|batch:0090, train_loss:0.255838, train_ap:0.9072, train_acc:0.8970, train_auc:0.9661
# In epoch:012|batch:0100, train_loss:0.255681, train_ap:0.8681, train_acc:0.8770, train_auc:0.9521
# In epoch:012|batch:0110, train_loss:0.256020, train_ap:0.9016, train_acc:0.8887, train_auc:0.9612
# In epoch:012|batch:0120, train_loss:0.256851, train_ap:0.8950, train_acc:0.8687, train_auc:0.9566
# In epoch:012|batch:0130, train_loss:0.257097, train_ap:0.8834, train_acc:0.8721, train_auc:0.9543
# In epoch:012|batch:0140, train_loss:0.256951, train_ap:0.8798, train_acc:0.8696, train_auc:0.9527
# In epoch:012|batch:0150, train_loss:0.256197, train_ap:0.9094, train_acc:0.8853, train_auc:0.9652
# In epoch:012|batch:0160, train_loss:0.256256, train_ap:0.8968, train_acc:0.8979, train_auc:0.9600
# In epoch:012|batch:0170, train_loss:0.256276, train_ap:0.8985, train_acc:0.8770, train_auc:0.9568
# In epoch:012|batch:0000, val_loss:0.000140, val_ap:0.8783, val_acc:0.8770, val_auc:0.9514
# In epoch:012|batch:0010, val_loss:0.000121, val_ap:0.9097, val_acc:0.8779, val_auc:0.9639
# In epoch:012|batch:0020, val_loss:0.000121, val_ap:0.9020, val_acc:0.8872, val_auc:0.9610
# In epoch:012|batch:0030, val_loss:0.000121, val_ap:0.8922, val_acc:0.8779, val_auc:0.9585
# In epoch:012|batch:0040, val_loss:0.000122, val_ap:0.8933, val_acc:0.8760, val_auc:0.9592
# G: 0.920792, D: 0.649836, ALL: 0.785314
# EarlyStoper count: 01
# In epoch:013|batch:0000, train_loss:0.253317, train_ap:0.9011, train_acc:0.8853, train_auc:0.9595
# In epoch:013|batch:0010, train_loss:0.255496, train_ap:0.8878, train_acc:0.8833, train_auc:0.9586
# In epoch:013|batch:0020, train_loss:0.256816, train_ap:0.8706, train_acc:0.8643, train_auc:0.9537
# In epoch:013|batch:0030, train_loss:0.256691, train_ap:0.8869, train_acc:0.8794, train_auc:0.9601
# In epoch:013|batch:0040, train_loss:0.256649, train_ap:0.9012, train_acc:0.8818, train_auc:0.9591
# In epoch:013|batch:0050, train_loss:0.255832, train_ap:0.9117, train_acc:0.8853, train_auc:0.9662
# In epoch:013|batch:0060, train_loss:0.256524, train_ap:0.8939, train_acc:0.8896, train_auc:0.9613
# In epoch:013|batch:0070, train_loss:0.256590, train_ap:0.9007, train_acc:0.8838, train_auc:0.9603
# In epoch:013|batch:0080, train_loss:0.256432, train_ap:0.8880, train_acc:0.8770, train_auc:0.9560
# In epoch:013|batch:0090, train_loss:0.255911, train_ap:0.8777, train_acc:0.8740, train_auc:0.9560
# In epoch:013|batch:0100, train_loss:0.256113, train_ap:0.8776, train_acc:0.8750, train_auc:0.9578
# In epoch:013|batch:0110, train_loss:0.256176, train_ap:0.8762, train_acc:0.8750, train_auc:0.9539
# In epoch:013|batch:0120, train_loss:0.255852, train_ap:0.8774, train_acc:0.8745, train_auc:0.9560
# In epoch:013|batch:0130, train_loss:0.255680, train_ap:0.8865, train_acc:0.8823, train_auc:0.9576
# In epoch:013|batch:0140, train_loss:0.255628, train_ap:0.8920, train_acc:0.8882, train_auc:0.9616
# In epoch:013|batch:0150, train_loss:0.255905, train_ap:0.8781, train_acc:0.8784, train_auc:0.9552
# In epoch:013|batch:0160, train_loss:0.255309, train_ap:0.9032, train_acc:0.8896, train_auc:0.9602
# In epoch:013|batch:0170, train_loss:0.254970, train_ap:0.9080, train_acc:0.8809, train_auc:0.9634
# In epoch:013|batch:0000, val_loss:0.000120, val_ap:0.8915, val_acc:0.8872, val_auc:0.9616
# In epoch:013|batch:0010, val_loss:0.000122, val_ap:0.8905, val_acc:0.8838, val_auc:0.9600
# In epoch:013|batch:0020, val_loss:0.000122, val_ap:0.8984, val_acc:0.8867, val_auc:0.9639
# In epoch:013|batch:0030, val_loss:0.000122, val_ap:0.9126, val_acc:0.8965, val_auc:0.9657
# In epoch:013|batch:0040, val_loss:0.000122, val_ap:0.8976, val_acc:0.8838, val_auc:0.9632
# G: 0.921694, D: 0.651182, ALL: 0.786438
# EarlyStoper count: 02
# In epoch:014|batch:0000, train_loss:0.247980, train_ap:0.8961, train_acc:0.8921, train_auc:0.9615
# In epoch:014|batch:0010, train_loss:0.258089, train_ap:0.8931, train_acc:0.8872, train_auc:0.9615
# In epoch:014|batch:0020, train_loss:0.250192, train_ap:0.8945, train_acc:0.8887, train_auc:0.9623
# In epoch:014|batch:0030, train_loss:0.253232, train_ap:0.8869, train_acc:0.8638, train_auc:0.9576
# In epoch:014|batch:0040, train_loss:0.252536, train_ap:0.9056, train_acc:0.8931, train_auc:0.9627
# In epoch:014|batch:0050, train_loss:0.253430, train_ap:0.8781, train_acc:0.8696, train_auc:0.9559
# In epoch:014|batch:0060, train_loss:0.253190, train_ap:0.8932, train_acc:0.8730, train_auc:0.9556
# In epoch:014|batch:0070, train_loss:0.253176, train_ap:0.9141, train_acc:0.8760, train_auc:0.9646
# In epoch:014|batch:0080, train_loss:0.253068, train_ap:0.8896, train_acc:0.8784, train_auc:0.9590
# In epoch:014|batch:0090, train_loss:0.253549, train_ap:0.8892, train_acc:0.8872, train_auc:0.9596
# In epoch:014|batch:0100, train_loss:0.253552, train_ap:0.8781, train_acc:0.8784, train_auc:0.9586
# In epoch:014|batch:0110, train_loss:0.253466, train_ap:0.9002, train_acc:0.8662, train_auc:0.9610
# In epoch:014|batch:0120, train_loss:0.253503, train_ap:0.8851, train_acc:0.8784, train_auc:0.9589
# In epoch:014|batch:0130, train_loss:0.253378, train_ap:0.8979, train_acc:0.8833, train_auc:0.9597
# In epoch:014|batch:0140, train_loss:0.253650, train_ap:0.8977, train_acc:0.8750, train_auc:0.9595
# In epoch:014|batch:0150, train_loss:0.253539, train_ap:0.9080, train_acc:0.8789, train_auc:0.9616
# In epoch:014|batch:0160, train_loss:0.253757, train_ap:0.8857, train_acc:0.8745, train_auc:0.9543
# In epoch:014|batch:0170, train_loss:0.253736, train_ap:0.8836, train_acc:0.8853, train_auc:0.9565
# In epoch:014|batch:0000, val_loss:0.000117, val_ap:0.8977, val_acc:0.8760, val_auc:0.9625
# In epoch:014|batch:0010, val_loss:0.000119, val_ap:0.8936, val_acc:0.8779, val_auc:0.9562
# In epoch:014|batch:0020, val_loss:0.000120, val_ap:0.8836, val_acc:0.8804, val_auc:0.9567
# In epoch:014|batch:0030, val_loss:0.000121, val_ap:0.8902, val_acc:0.8838, val_auc:0.9588
# In epoch:014|batch:0040, val_loss:0.000121, val_ap:0.8598, val_acc:0.8770, val_auc:0.9523
# G: 0.921426, D: 0.651056, ALL: 0.786241
# EarlyStoper count: 03
# In epoch:015|batch:0000, train_loss:0.262816, train_ap:0.8840, train_acc:0.8779, train_auc:0.9557
# In epoch:015|batch:0010, train_loss:0.247842, train_ap:0.8940, train_acc:0.8936, train_auc:0.9629
# In epoch:015|batch:0020, train_loss:0.251039, train_ap:0.9085, train_acc:0.8901, train_auc:0.9647
# In epoch:015|batch:0030, train_loss:0.250136, train_ap:0.9004, train_acc:0.8833, train_auc:0.9626
# In epoch:015|batch:0040, train_loss:0.249870, train_ap:0.8963, train_acc:0.8760, train_auc:0.9596
# In epoch:015|batch:0050, train_loss:0.250835, train_ap:0.8771, train_acc:0.8813, train_auc:0.9571
# In epoch:015|batch:0060, train_loss:0.251240, train_ap:0.8845, train_acc:0.8794, train_auc:0.9502
# In epoch:015|batch:0070, train_loss:0.251426, train_ap:0.8907, train_acc:0.8843, train_auc:0.9616
# In epoch:015|batch:0080, train_loss:0.251355, train_ap:0.8881, train_acc:0.8770, train_auc:0.9565
# In epoch:015|batch:0090, train_loss:0.252613, train_ap:0.8737, train_acc:0.8687, train_auc:0.9538
# In epoch:015|batch:0100, train_loss:0.252878, train_ap:0.9122, train_acc:0.8867, train_auc:0.9631
# In epoch:015|batch:0110, train_loss:0.253134, train_ap:0.8853, train_acc:0.8608, train_auc:0.9541
# In epoch:015|batch:0120, train_loss:0.252842, train_ap:0.8982, train_acc:0.8804, train_auc:0.9614
# In epoch:015|batch:0130, train_loss:0.252694, train_ap:0.8991, train_acc:0.8779, train_auc:0.9618
# In epoch:015|batch:0140, train_loss:0.252979, train_ap:0.8872, train_acc:0.8760, train_auc:0.9619
# In epoch:015|batch:0150, train_loss:0.253114, train_ap:0.8969, train_acc:0.8721, train_auc:0.9590
# In epoch:015|batch:0160, train_loss:0.253332, train_ap:0.9067, train_acc:0.8833, train_auc:0.9615
# In epoch:015|batch:0170, train_loss:0.253079, train_ap:0.8923, train_acc:0.8789, train_auc:0.9611
# In epoch:015|batch:0000, val_loss:0.000135, val_ap:0.8867, val_acc:0.8696, val_auc:0.9506
# In epoch:015|batch:0010, val_loss:0.000124, val_ap:0.8928, val_acc:0.8740, val_auc:0.9600
# In epoch:015|batch:0020, val_loss:0.000122, val_ap:0.8885, val_acc:0.8745, val_auc:0.9567
# In epoch:015|batch:0030, val_loss:0.000122, val_ap:0.9003, val_acc:0.8804, val_auc:0.9624
# In epoch:015|batch:0040, val_loss:0.000122, val_ap:0.8797, val_acc:0.8799, val_auc:0.9533
# G: 0.921313, D: 0.651603, ALL: 0.786458
# EarlyStoper count: 04
# In epoch:016|batch:0000, train_loss:0.245489, train_ap:0.8900, train_acc:0.8848, train_auc:0.9597
# In epoch:016|batch:0010, train_loss:0.251081, train_ap:0.8853, train_acc:0.8711, train_auc:0.9567
# In epoch:016|batch:0020, train_loss:0.255392, train_ap:0.9038, train_acc:0.8774, train_auc:0.9555
# In epoch:016|batch:0030, train_loss:0.255482, train_ap:0.8893, train_acc:0.8882, train_auc:0.9622
# In epoch:016|batch:0040, train_loss:0.253859, train_ap:0.8954, train_acc:0.8779, train_auc:0.9592
# In epoch:016|batch:0050, train_loss:0.253018, train_ap:0.8958, train_acc:0.8789, train_auc:0.9610
# In epoch:016|batch:0060, train_loss:0.253637, train_ap:0.8745, train_acc:0.8760, train_auc:0.9548
# In epoch:016|batch:0070, train_loss:0.253939, train_ap:0.8898, train_acc:0.8789, train_auc:0.9598
# In epoch:016|batch:0080, train_loss:0.253640, train_ap:0.8804, train_acc:0.8804, train_auc:0.9561
# In epoch:016|batch:0090, train_loss:0.253099, train_ap:0.8969, train_acc:0.8784, train_auc:0.9586
# In epoch:016|batch:0100, train_loss:0.253546, train_ap:0.8950, train_acc:0.8818, train_auc:0.9586
# In epoch:016|batch:0110, train_loss:0.254177, train_ap:0.9019, train_acc:0.8926, train_auc:0.9661
# In epoch:016|batch:0120, train_loss:0.253926, train_ap:0.8956, train_acc:0.8867, train_auc:0.9602
# In epoch:016|batch:0130, train_loss:0.253918, train_ap:0.8972, train_acc:0.8877, train_auc:0.9617
# In epoch:016|batch:0140, train_loss:0.253796, train_ap:0.9083, train_acc:0.8848, train_auc:0.9629
# In epoch:016|batch:0150, train_loss:0.253689, train_ap:0.8996, train_acc:0.8892, train_auc:0.9621
# In epoch:016|batch:0160, train_loss:0.253406, train_ap:0.8871, train_acc:0.8833, train_auc:0.9578
# In epoch:016|batch:0170, train_loss:0.253104, train_ap:0.8916, train_acc:0.8765, train_auc:0.9591
# In epoch:016|batch:0000, val_loss:0.000124, val_ap:0.8850, val_acc:0.8848, val_auc:0.9581
# In epoch:016|batch:0010, val_loss:0.000123, val_ap:0.9071, val_acc:0.8911, val_auc:0.9600
# In epoch:016|batch:0020, val_loss:0.000123, val_ap:0.8898, val_acc:0.8833, val_auc:0.9569
# In epoch:016|batch:0030, val_loss:0.000122, val_ap:0.9029, val_acc:0.8960, val_auc:0.9643
# In epoch:016|batch:0040, val_loss:0.000121, val_ap:0.8993, val_acc:0.8901, val_auc:0.9627
# G: 0.921865, D: 0.654464, ALL: 0.788165
# In epoch:017|batch:0000, train_loss:0.242455, train_ap:0.9122, train_acc:0.8848, train_auc:0.9630
# In epoch:017|batch:0010, train_loss:0.256451, train_ap:0.8845, train_acc:0.8701, train_auc:0.9519
# In epoch:017|batch:0020, train_loss:0.256362, train_ap:0.8892, train_acc:0.8750, train_auc:0.9558
# In epoch:017|batch:0030, train_loss:0.253346, train_ap:0.8867, train_acc:0.8853, train_auc:0.9578
# In epoch:017|batch:0040, train_loss:0.252624, train_ap:0.9128, train_acc:0.8872, train_auc:0.9674
# In epoch:017|batch:0050, train_loss:0.252448, train_ap:0.8878, train_acc:0.8828, train_auc:0.9605
# In epoch:017|batch:0060, train_loss:0.251854, train_ap:0.8954, train_acc:0.8896, train_auc:0.9612
# In epoch:017|batch:0070, train_loss:0.251700, train_ap:0.8869, train_acc:0.8730, train_auc:0.9587
# In epoch:017|batch:0080, train_loss:0.251702, train_ap:0.8881, train_acc:0.8745, train_auc:0.9573
# In epoch:017|batch:0090, train_loss:0.251887, train_ap:0.9126, train_acc:0.8804, train_auc:0.9649
# In epoch:017|batch:0100, train_loss:0.252038, train_ap:0.8903, train_acc:0.8745, train_auc:0.9559
# In epoch:017|batch:0110, train_loss:0.252378, train_ap:0.8914, train_acc:0.8696, train_auc:0.9593
# In epoch:017|batch:0120, train_loss:0.252036, train_ap:0.9097, train_acc:0.8862, train_auc:0.9661
# In epoch:017|batch:0130, train_loss:0.252476, train_ap:0.8855, train_acc:0.8779, train_auc:0.9564
# In epoch:017|batch:0140, train_loss:0.252482, train_ap:0.8833, train_acc:0.8789, train_auc:0.9559
# In epoch:017|batch:0150, train_loss:0.252672, train_ap:0.8945, train_acc:0.8794, train_auc:0.9584
# In epoch:017|batch:0160, train_loss:0.252779, train_ap:0.8865, train_acc:0.8872, train_auc:0.9594
# In epoch:017|batch:0170, train_loss:0.252413, train_ap:0.9136, train_acc:0.8848, train_auc:0.9657
# In epoch:017|batch:0000, val_loss:0.000112, val_ap:0.9040, val_acc:0.8931, val_auc:0.9653
# In epoch:017|batch:0010, val_loss:0.000116, val_ap:0.8901, val_acc:0.8882, val_auc:0.9620
# In epoch:017|batch:0020, val_loss:0.000119, val_ap:0.8889, val_acc:0.8789, val_auc:0.9618
# In epoch:017|batch:0030, val_loss:0.000120, val_ap:0.9017, val_acc:0.8809, val_auc:0.9618
# In epoch:017|batch:0040, val_loss:0.000120, val_ap:0.9016, val_acc:0.8809, val_auc:0.9608
# G: 0.922800, D: 0.655853, ALL: 0.789326
# In epoch:018|batch:0000, train_loss:0.275917, train_ap:0.8828, train_acc:0.8784, train_auc:0.9531
# In epoch:018|batch:0010, train_loss:0.248794, train_ap:0.8926, train_acc:0.8794, train_auc:0.9617
# In epoch:018|batch:0020, train_loss:0.251045, train_ap:0.8932, train_acc:0.8691, train_auc:0.9597
# In epoch:018|batch:0030, train_loss:0.248829, train_ap:0.8850, train_acc:0.8853, train_auc:0.9577
# In epoch:018|batch:0040, train_loss:0.248443, train_ap:0.9029, train_acc:0.8813, train_auc:0.9610
# In epoch:018|batch:0050, train_loss:0.248344, train_ap:0.9013, train_acc:0.8892, train_auc:0.9605
# In epoch:018|batch:0060, train_loss:0.247877, train_ap:0.8987, train_acc:0.8921, train_auc:0.9618
# In epoch:018|batch:0070, train_loss:0.248679, train_ap:0.8880, train_acc:0.8765, train_auc:0.9557
# In epoch:018|batch:0080, train_loss:0.248800, train_ap:0.9082, train_acc:0.8848, train_auc:0.9629
# In epoch:018|batch:0090, train_loss:0.249930, train_ap:0.8967, train_acc:0.8799, train_auc:0.9583
# In epoch:018|batch:0100, train_loss:0.249857, train_ap:0.9090, train_acc:0.8843, train_auc:0.9648
# In epoch:018|batch:0110, train_loss:0.250116, train_ap:0.8912, train_acc:0.8838, train_auc:0.9574
# In epoch:018|batch:0120, train_loss:0.249987, train_ap:0.9142, train_acc:0.8784, train_auc:0.9652
# In epoch:018|batch:0130, train_loss:0.249729, train_ap:0.8863, train_acc:0.8853, train_auc:0.9577
# In epoch:018|batch:0140, train_loss:0.250130, train_ap:0.8738, train_acc:0.8784, train_auc:0.9512
# In epoch:018|batch:0150, train_loss:0.250073, train_ap:0.9000, train_acc:0.8794, train_auc:0.9609
# In epoch:018|batch:0160, train_loss:0.250092, train_ap:0.8854, train_acc:0.8887, train_auc:0.9612
# In epoch:018|batch:0170, train_loss:0.250211, train_ap:0.8691, train_acc:0.8701, train_auc:0.9529
# In epoch:018|batch:0000, val_loss:0.000112, val_ap:0.9017, val_acc:0.8950, val_auc:0.9659
# In epoch:018|batch:0010, val_loss:0.000119, val_ap:0.9075, val_acc:0.8862, val_auc:0.9620
# In epoch:018|batch:0020, val_loss:0.000121, val_ap:0.8917, val_acc:0.8750, val_auc:0.9589
# In epoch:018|batch:0030, val_loss:0.000121, val_ap:0.9054, val_acc:0.8896, val_auc:0.9655
# In epoch:018|batch:0040, val_loss:0.000121, val_ap:0.8942, val_acc:0.8687, val_auc:0.9551
# G: 0.922199, D: 0.654044, ALL: 0.788121
# EarlyStoper count: 01
# In epoch:019|batch:0000, train_loss:0.256093, train_ap:0.8768, train_acc:0.8774, train_auc:0.9568
# In epoch:019|batch:0010, train_loss:0.246729, train_ap:0.8896, train_acc:0.8828, train_auc:0.9585
# In epoch:019|batch:0020, train_loss:0.246636, train_ap:0.8961, train_acc:0.8926, train_auc:0.9636
# In epoch:019|batch:0030, train_loss:0.245943, train_ap:0.9045, train_acc:0.8828, train_auc:0.9615
# In epoch:019|batch:0040, train_loss:0.247160, train_ap:0.8852, train_acc:0.8862, train_auc:0.9625
# In epoch:019|batch:0050, train_loss:0.248017, train_ap:0.8994, train_acc:0.8794, train_auc:0.9610
# In epoch:019|batch:0060, train_loss:0.247895, train_ap:0.8934, train_acc:0.8901, train_auc:0.9606
# In epoch:019|batch:0070, train_loss:0.248013, train_ap:0.8926, train_acc:0.8862, train_auc:0.9599
# In epoch:019|batch:0080, train_loss:0.247970, train_ap:0.8906, train_acc:0.8823, train_auc:0.9584
# In epoch:019|batch:0090, train_loss:0.248380, train_ap:0.9012, train_acc:0.8931, train_auc:0.9605
# In epoch:019|batch:0100, train_loss:0.247914, train_ap:0.9149, train_acc:0.8892, train_auc:0.9644
# In epoch:019|batch:0110, train_loss:0.247870, train_ap:0.9009, train_acc:0.8828, train_auc:0.9632
# In epoch:019|batch:0120, train_loss:0.248033, train_ap:0.8597, train_acc:0.8584, train_auc:0.9483
# In epoch:019|batch:0130, train_loss:0.248501, train_ap:0.8835, train_acc:0.8750, train_auc:0.9586
# In epoch:019|batch:0140, train_loss:0.249282, train_ap:0.9123, train_acc:0.8892, train_auc:0.9644
# In epoch:019|batch:0150, train_loss:0.249146, train_ap:0.9090, train_acc:0.8936, train_auc:0.9653
# In epoch:019|batch:0160, train_loss:0.249405, train_ap:0.8905, train_acc:0.8750, train_auc:0.9559
# In epoch:019|batch:0170, train_loss:0.249489, train_ap:0.8953, train_acc:0.8818, train_auc:0.9575
# In epoch:019|batch:0000, val_loss:0.000122, val_ap:0.8899, val_acc:0.8813, val_auc:0.9610
# In epoch:019|batch:0010, val_loss:0.000121, val_ap:0.8892, val_acc:0.8804, val_auc:0.9584
# In epoch:019|batch:0020, val_loss:0.000120, val_ap:0.8879, val_acc:0.8794, val_auc:0.9599
# In epoch:019|batch:0030, val_loss:0.000121, val_ap:0.8982, val_acc:0.8784, val_auc:0.9607
# In epoch:019|batch:0040, val_loss:0.000121, val_ap:0.8890, val_acc:0.8730, val_auc:0.9538
# G: 0.922523, D: 0.656568, ALL: 0.789546
# In epoch:020|batch:0000, train_loss:0.248811, train_ap:0.8876, train_acc:0.8867, train_auc:0.9604
# In epoch:020|batch:0010, train_loss:0.251074, train_ap:0.8871, train_acc:0.8745, train_auc:0.9567
# In epoch:020|batch:0020, train_loss:0.250659, train_ap:0.8873, train_acc:0.8804, train_auc:0.9548
# In epoch:020|batch:0030, train_loss:0.251448, train_ap:0.9113, train_acc:0.8896, train_auc:0.9644
# In epoch:020|batch:0040, train_loss:0.250185, train_ap:0.8937, train_acc:0.8804, train_auc:0.9587
# In epoch:020|batch:0050, train_loss:0.249814, train_ap:0.8913, train_acc:0.8818, train_auc:0.9598
# In epoch:020|batch:0060, train_loss:0.249226, train_ap:0.9140, train_acc:0.8853, train_auc:0.9648
# In epoch:020|batch:0070, train_loss:0.249342, train_ap:0.9092, train_acc:0.8794, train_auc:0.9628
# In epoch:020|batch:0080, train_loss:0.249031, train_ap:0.9150, train_acc:0.8960, train_auc:0.9657
# In epoch:020|batch:0090, train_loss:0.249609, train_ap:0.8810, train_acc:0.8770, train_auc:0.9550
# In epoch:020|batch:0100, train_loss:0.249731, train_ap:0.9041, train_acc:0.8862, train_auc:0.9641
# In epoch:020|batch:0110, train_loss:0.250021, train_ap:0.9012, train_acc:0.8872, train_auc:0.9659
# In epoch:020|batch:0120, train_loss:0.249769, train_ap:0.8849, train_acc:0.8794, train_auc:0.9561
# In epoch:020|batch:0130, train_loss:0.250021, train_ap:0.8963, train_acc:0.8892, train_auc:0.9614
# In epoch:020|batch:0140, train_loss:0.250135, train_ap:0.8791, train_acc:0.8770, train_auc:0.9582
# In epoch:020|batch:0150, train_loss:0.250010, train_ap:0.8754, train_acc:0.8774, train_auc:0.9561
# In epoch:020|batch:0160, train_loss:0.249766, train_ap:0.8980, train_acc:0.8921, train_auc:0.9626
# In epoch:020|batch:0170, train_loss:0.249832, train_ap:0.9018, train_acc:0.8740, train_auc:0.9579
# In epoch:020|batch:0000, val_loss:0.000118, val_ap:0.9041, val_acc:0.8872, val_auc:0.9640
# In epoch:020|batch:0010, val_loss:0.000122, val_ap:0.8839, val_acc:0.8853, val_auc:0.9585
# In epoch:020|batch:0020, val_loss:0.000122, val_ap:0.8980, val_acc:0.8823, val_auc:0.9596
# In epoch:020|batch:0030, val_loss:0.000121, val_ap:0.9153, val_acc:0.8955, val_auc:0.9669
# In epoch:020|batch:0040, val_loss:0.000121, val_ap:0.9131, val_acc:0.8906, val_auc:0.9670
# G: 0.922225, D: 0.655516, ALL: 0.788871
# EarlyStoper count: 01
# In epoch:021|batch:0000, train_loss:0.244152, train_ap:0.9047, train_acc:0.8892, train_auc:0.9634
# In epoch:021|batch:0010, train_loss:0.243432, train_ap:0.9126, train_acc:0.8818, train_auc:0.9644
# In epoch:021|batch:0020, train_loss:0.246719, train_ap:0.8950, train_acc:0.8853, train_auc:0.9619
# ...
# In epoch:032|batch:0100, train_loss:0.238369, train_ap:0.9050, train_acc:0.8970, train_auc:0.9621
# In epoch:032|batch:0110, train_loss:0.238518, train_ap:0.8926, train_acc:0.8848, train_auc:0.9622
# In epoch:032|batch:0120, train_loss:0.238786, train_ap:0.9018, train_acc:0.8862, train_auc:0.9617
# In epoch:032|batch:0130, train_loss:0.238787, train_ap:0.9130, train_acc:0.8989, train_auc:0.9680
# In epoch:032|batch:0140, train_loss:0.238898, train_ap:0.9081, train_acc:0.8838, train_auc:0.9629
# In epoch:032|batch:0150, train_loss:0.239380, train_ap:0.9002, train_acc:0.8755, train_auc:0.9619
# In epoch:032|batch:0160, train_loss:0.239978, train_ap:0.8967, train_acc:0.8779, train_auc:0.9611
# In epoch:032|batch:0170, train_loss:0.239932, train_ap:0.9048, train_acc:0.8877, train_auc:0.9645
# In epoch:032|batch:0000, val_loss:0.000132, val_ap:0.8871, val_acc:0.8765, val_auc:0.9541
# In epoch:032|batch:0010, val_loss:0.000125, val_ap:0.9036, val_acc:0.8955, val_auc:0.9655
# In epoch:032|batch:0020, val_loss:0.000124, val_ap:0.9038, val_acc:0.8950, val_auc:0.9646
# In epoch:032|batch:0030, val_loss:0.000124, val_ap:0.8921, val_acc:0.8750, val_auc:0.9587
# In epoch:032|batch:0040, val_loss:0.000124, val_ap:0.8890, val_acc:0.8765, val_auc:0.9581
# G: 0.918716, D: 0.651546, ALL: 0.785131
# EarlyStoper count: 06
# In epoch:033|batch:0000, train_loss:0.242221, train_ap:0.8987, train_acc:0.8882, train_auc:0.9629
# In epoch:033|batch:0010, train_loss:0.233476, train_ap:0.9065, train_acc:0.8901, train_auc:0.9653
# In epoch:033|batch:0020, train_loss:0.233127, train_ap:0.8875, train_acc:0.8828, train_auc:0.9603
# In epoch:033|batch:0030, train_loss:0.233240, train_ap:0.9220, train_acc:0.9009, train_auc:0.9686
# In epoch:033|batch:0040, train_loss:0.237073, train_ap:0.9018, train_acc:0.8833, train_auc:0.9625
# In epoch:033|batch:0050, train_loss:0.237194, train_ap:0.9062, train_acc:0.8818, train_auc:0.9615
# In epoch:033|batch:0060, train_loss:0.238497, train_ap:0.9030, train_acc:0.8857, train_auc:0.9625
# In epoch:033|batch:0070, train_loss:0.238941, train_ap:0.8949, train_acc:0.8735, train_auc:0.9611
# In epoch:033|batch:0080, train_loss:0.238559, train_ap:0.9074, train_acc:0.8887, train_auc:0.9641
# In epoch:033|batch:0090, train_loss:0.238457, train_ap:0.9070, train_acc:0.8892, train_auc:0.9648
# In epoch:033|batch:0100, train_loss:0.238667, train_ap:0.8902, train_acc:0.8779, train_auc:0.9604
# In epoch:033|batch:0110, train_loss:0.238980, train_ap:0.9091, train_acc:0.9043, train_auc:0.9704
# In epoch:033|batch:0120, train_loss:0.238800, train_ap:0.9193, train_acc:0.8892, train_auc:0.9691
# In epoch:033|batch:0130, train_loss:0.239537, train_ap:0.9005, train_acc:0.8804, train_auc:0.9590
# In epoch:033|batch:0140, train_loss:0.239875, train_ap:0.8786, train_acc:0.8823, train_auc:0.9559
# In epoch:033|batch:0150, train_loss:0.239899, train_ap:0.8827, train_acc:0.8799, train_auc:0.9577
# In epoch:033|batch:0160, train_loss:0.239985, train_ap:0.9018, train_acc:0.8916, train_auc:0.9637
# In epoch:033|batch:0170, train_loss:0.240075, train_ap:0.9103, train_acc:0.8892, train_auc:0.9668
# In epoch:033|batch:0000, val_loss:0.000129, val_ap:0.8863, val_acc:0.8828, val_auc:0.9564
# In epoch:033|batch:0010, val_loss:0.000124, val_ap:0.9107, val_acc:0.8950, val_auc:0.9654
# In epoch:033|batch:0020, val_loss:0.000124, val_ap:0.8921, val_acc:0.8833, val_auc:0.9594
# In epoch:033|batch:0030, val_loss:0.000125, val_ap:0.9210, val_acc:0.8921, val_auc:0.9701
# In epoch:033|batch:0040, val_loss:0.000125, val_ap:0.8808, val_acc:0.8701, val_auc:0.9539
# G: 0.918722, D: 0.651799, ALL: 0.785261
# EarlyStoper count: 07
# In epoch:034|batch:0000, train_loss:0.224286, train_ap:0.9281, train_acc:0.8857, train_auc:0.9691
# In epoch:034|batch:0010, train_loss:0.231527, train_ap:0.9170, train_acc:0.9009, train_auc:0.9690
# In epoch:034|batch:0020, train_loss:0.234796, train_ap:0.9200, train_acc:0.8970, train_auc:0.9689
# In epoch:034|batch:0030, train_loss:0.237252, train_ap:0.8988, train_acc:0.8789, train_auc:0.9607
# In epoch:034|batch:0040, train_loss:0.238736, train_ap:0.8957, train_acc:0.8813, train_auc:0.9609
# In epoch:034|batch:0050, train_loss:0.237794, train_ap:0.9153, train_acc:0.8955, train_auc:0.9661
# In epoch:034|batch:0060, train_loss:0.238654, train_ap:0.8886, train_acc:0.8906, train_auc:0.9639
# In epoch:034|batch:0070, train_loss:0.238661, train_ap:0.9010, train_acc:0.8823, train_auc:0.9658
# In epoch:034|batch:0080, train_loss:0.238911, train_ap:0.9074, train_acc:0.8848, train_auc:0.9612
# In epoch:034|batch:0090, train_loss:0.238873, train_ap:0.9050, train_acc:0.8867, train_auc:0.9633
# In epoch:034|batch:0100, train_loss:0.239109, train_ap:0.8750, train_acc:0.8711, train_auc:0.9566
# In epoch:034|batch:0110, train_loss:0.238775, train_ap:0.9040, train_acc:0.8984, train_auc:0.9654
# In epoch:034|batch:0120, train_loss:0.238916, train_ap:0.8953, train_acc:0.8779, train_auc:0.9603
# In epoch:034|batch:0130, train_loss:0.238729, train_ap:0.9111, train_acc:0.8955, train_auc:0.9666
# In epoch:034|batch:0140, train_loss:0.238516, train_ap:0.8901, train_acc:0.8809, train_auc:0.9606
# In epoch:034|batch:0150, train_loss:0.239119, train_ap:0.8878, train_acc:0.8794, train_auc:0.9585
# In epoch:034|batch:0160, train_loss:0.239095, train_ap:0.8917, train_acc:0.8794, train_auc:0.9569
# In epoch:034|batch:0170, train_loss:0.239216, train_ap:0.8869, train_acc:0.8706, train_auc:0.9548
# In epoch:034|batch:0000, val_loss:0.000137, val_ap:0.8759, val_acc:0.8662, val_auc:0.9525
# In epoch:034|batch:0010, val_loss:0.000124, val_ap:0.8951, val_acc:0.8867, val_auc:0.9621
# In epoch:034|batch:0020, val_loss:0.000125, val_ap:0.9059, val_acc:0.8867, val_auc:0.9659
# In epoch:034|batch:0030, val_loss:0.000124, val_ap:0.9066, val_acc:0.8770, val_auc:0.9609
# In epoch:034|batch:0040, val_loss:0.000125, val_ap:0.8806, val_acc:0.8701, val_auc:0.9522
# G: 0.918710, D: 0.652977, ALL: 0.785844
# EarlyStoper count: 08
# In epoch:035|batch:0000, train_loss:0.253882, train_ap:0.8896, train_acc:0.8770, train_auc:0.9589
# In epoch:035|batch:0010, train_loss:0.234667, train_ap:0.9103, train_acc:0.8921, train_auc:0.9645
# In epoch:035|batch:0020, train_loss:0.232901, train_ap:0.9179, train_acc:0.8838, train_auc:0.9687
# In epoch:035|batch:0030, train_loss:0.234674, train_ap:0.9052, train_acc:0.8945, train_auc:0.9666
# In epoch:035|batch:0040, train_loss:0.236971, train_ap:0.8853, train_acc:0.8901, train_auc:0.9618
# In epoch:035|batch:0050, train_loss:0.237554, train_ap:0.9135, train_acc:0.8926, train_auc:0.9660
# In epoch:035|batch:0060, train_loss:0.237271, train_ap:0.9068, train_acc:0.8916, train_auc:0.9654
# In epoch:035|batch:0070, train_loss:0.237504, train_ap:0.9241, train_acc:0.8994, train_auc:0.9708
# In epoch:035|batch:0080, train_loss:0.237768, train_ap:0.8900, train_acc:0.8711, train_auc:0.9585
# In epoch:035|batch:0090, train_loss:0.238342, train_ap:0.9080, train_acc:0.8901, train_auc:0.9648
# In epoch:035|batch:0100, train_loss:0.237745, train_ap:0.9006, train_acc:0.8936, train_auc:0.9663
# In epoch:035|batch:0110, train_loss:0.238294, train_ap:0.8859, train_acc:0.8784, train_auc:0.9569
# In epoch:035|batch:0120, train_loss:0.238406, train_ap:0.8876, train_acc:0.8823, train_auc:0.9558
# In epoch:035|batch:0130, train_loss:0.239003, train_ap:0.8829, train_acc:0.8838, train_auc:0.9568
# In epoch:035|batch:0140, train_loss:0.238948, train_ap:0.8968, train_acc:0.8823, train_auc:0.9624
# In epoch:035|batch:0150, train_loss:0.238882, train_ap:0.8755, train_acc:0.8774, train_auc:0.9578
# In epoch:035|batch:0160, train_loss:0.238892, train_ap:0.9009, train_acc:0.8911, train_auc:0.9661
# In epoch:035|batch:0170, train_loss:0.239227, train_ap:0.8993, train_acc:0.8901, train_auc:0.9626
# In epoch:035|batch:0000, val_loss:0.000113, val_ap:0.9102, val_acc:0.8906, val_auc:0.9652
# In epoch:035|batch:0010, val_loss:0.000123, val_ap:0.8996, val_acc:0.8779, val_auc:0.9632
# In epoch:035|batch:0020, val_loss:0.000124, val_ap:0.8804, val_acc:0.8745, val_auc:0.9523
# In epoch:035|batch:0030, val_loss:0.000125, val_ap:0.8901, val_acc:0.8779, val_auc:0.9572
# In epoch:035|batch:0040, val_loss:0.000125, val_ap:0.8893, val_acc:0.8833, val_auc:0.9596
# G: 0.918666, D: 0.651967, ALL: 0.785317
# EarlyStoper count: 09
# In epoch:036|batch:0000, train_loss:0.241831, train_ap:0.9082, train_acc:0.8853, train_auc:0.9633
# In epoch:036|batch:0010, train_loss:0.237101, train_ap:0.9059, train_acc:0.8936, train_auc:0.9663
# In epoch:036|batch:0020, train_loss:0.236554, train_ap:0.9025, train_acc:0.8940, train_auc:0.9650
# In epoch:036|batch:0030, train_loss:0.237666, train_ap:0.8962, train_acc:0.8789, train_auc:0.9596
# In epoch:036|batch:0040, train_loss:0.239150, train_ap:0.8941, train_acc:0.8838, train_auc:0.9615
# In epoch:036|batch:0050, train_loss:0.238895, train_ap:0.8883, train_acc:0.8921, train_auc:0.9625
# In epoch:036|batch:0060, train_loss:0.238766, train_ap:0.9200, train_acc:0.8955, train_auc:0.9712
# In epoch:036|batch:0070, train_loss:0.238551, train_ap:0.9019, train_acc:0.8867, train_auc:0.9605
# In epoch:036|batch:0080, train_loss:0.238097, train_ap:0.8916, train_acc:0.8901, train_auc:0.9600
# In epoch:036|batch:0090, train_loss:0.237426, train_ap:0.9040, train_acc:0.8901, train_auc:0.9660
# In epoch:036|batch:0100, train_loss:0.237559, train_ap:0.8857, train_acc:0.8882, train_auc:0.9627
# In epoch:036|batch:0110, train_loss:0.237781, train_ap:0.8898, train_acc:0.8921, train_auc:0.9630
# In epoch:036|batch:0120, train_loss:0.238082, train_ap:0.8955, train_acc:0.8799, train_auc:0.9579
# In epoch:036|batch:0130, train_loss:0.238365, train_ap:0.9025, train_acc:0.8940, train_auc:0.9636
# In epoch:036|batch:0140, train_loss:0.238354, train_ap:0.9036, train_acc:0.8887, train_auc:0.9655
# In epoch:036|batch:0150, train_loss:0.238656, train_ap:0.8798, train_acc:0.8794, train_auc:0.9531
# In epoch:036|batch:0160, train_loss:0.238460, train_ap:0.9093, train_acc:0.8892, train_auc:0.9637
# In epoch:036|batch:0170, train_loss:0.238457, train_ap:0.9048, train_acc:0.8911, train_auc:0.9649
# In epoch:036|batch:0000, val_loss:0.000124, val_ap:0.8813, val_acc:0.8857, val_auc:0.9582
# In epoch:036|batch:0010, val_loss:0.000124, val_ap:0.8847, val_acc:0.8755, val_auc:0.9580
# In epoch:036|batch:0020, val_loss:0.000124, val_ap:0.9185, val_acc:0.8892, val_auc:0.9675
# In epoch:036|batch:0030, val_loss:0.000124, val_ap:0.8975, val_acc:0.8867, val_auc:0.9599
# In epoch:036|batch:0040, val_loss:0.000124, val_ap:0.9097, val_acc:0.9009, val_auc:0.9658
# G: 0.918746, D: 0.650410, ALL: 0.784578
# EarlyStoper count: 10
# In epoch:037|batch:0000, train_loss:0.236627, train_ap:0.9063, train_acc:0.8848, train_auc:0.9644
# In epoch:037|batch:0010, train_loss:0.239268, train_ap:0.9019, train_acc:0.8901, train_auc:0.9624
# In epoch:037|batch:0020, train_loss:0.237259, train_ap:0.9073, train_acc:0.8931, train_auc:0.9643
# In epoch:037|batch:0030, train_loss:0.237947, train_ap:0.8962, train_acc:0.8887, train_auc:0.9623
# In epoch:037|batch:0040, train_loss:0.237182, train_ap:0.8888, train_acc:0.8892, train_auc:0.9616
# In epoch:037|batch:0050, train_loss:0.236680, train_ap:0.9114, train_acc:0.8916, train_auc:0.9653
# In epoch:037|batch:0060, train_loss:0.236235, train_ap:0.9099, train_acc:0.8950, train_auc:0.9631
# In epoch:037|batch:0070, train_loss:0.236783, train_ap:0.9044, train_acc:0.8804, train_auc:0.9633
# In epoch:037|batch:0080, train_loss:0.236574, train_ap:0.9165, train_acc:0.8911, train_auc:0.9659
# In epoch:037|batch:0090, train_loss:0.236367, train_ap:0.8984, train_acc:0.8799, train_auc:0.9602
# In epoch:037|batch:0100, train_loss:0.236326, train_ap:0.8888, train_acc:0.8901, train_auc:0.9631
# In epoch:037|batch:0110, train_loss:0.236811, train_ap:0.9025, train_acc:0.8877, train_auc:0.9636
# In epoch:037|batch:0120, train_loss:0.237247, train_ap:0.8963, train_acc:0.8843, train_auc:0.9574
# In epoch:037|batch:0130, train_loss:0.237773, train_ap:0.8815, train_acc:0.8799, train_auc:0.9561
# In epoch:037|batch:0140, train_loss:0.237962, train_ap:0.9072, train_acc:0.8945, train_auc:0.9649
# In epoch:037|batch:0150, train_loss:0.237806, train_ap:0.9221, train_acc:0.8892, train_auc:0.9707
# In epoch:037|batch:0160, train_loss:0.238120, train_ap:0.9081, train_acc:0.8882, train_auc:0.9664
# In epoch:037|batch:0170, train_loss:0.238567, train_ap:0.8891, train_acc:0.8789, train_auc:0.9625
# In epoch:037|batch:0000, val_loss:0.000137, val_ap:0.8680, val_acc:0.8779, val_auc:0.9506
# In epoch:037|batch:0010, val_loss:0.000124, val_ap:0.8919, val_acc:0.8789, val_auc:0.9605
# In epoch:037|batch:0020, val_loss:0.000124, val_ap:0.9033, val_acc:0.8779, val_auc:0.9594
# In epoch:037|batch:0030, val_loss:0.000124, val_ap:0.9086, val_acc:0.8901, val_auc:0.9623
# In epoch:037|batch:0040, val_loss:0.000124, val_ap:0.8927, val_acc:0.8853, val_auc:0.9587
# G: 0.918702, D: 0.650789, ALL: 0.784745
# EarlyStoper count: 11
# In epoch:038|batch:0000, train_loss:0.253524, train_ap:0.8909, train_acc:0.8696, train_auc:0.9601
# In epoch:038|batch:0010, train_loss:0.235527, train_ap:0.9082, train_acc:0.8857, train_auc:0.9662
# In epoch:038|batch:0020, train_loss:0.238439, train_ap:0.8974, train_acc:0.8843, train_auc:0.9623
# In epoch:038|batch:0030, train_loss:0.237175, train_ap:0.8935, train_acc:0.8926, train_auc:0.9666
# In epoch:038|batch:0040, train_loss:0.237498, train_ap:0.8854, train_acc:0.8813, train_auc:0.9619
# In epoch:038|batch:0050, train_loss:0.236829, train_ap:0.9235, train_acc:0.8965, train_auc:0.9690
# In epoch:038|batch:0060, train_loss:0.238228, train_ap:0.9053, train_acc:0.9023, train_auc:0.9688
# In epoch:038|batch:0070, train_loss:0.238803, train_ap:0.8932, train_acc:0.8843, train_auc:0.9620
# In epoch:038|batch:0080, train_loss:0.238283, train_ap:0.9013, train_acc:0.8955, train_auc:0.9654
# In epoch:038|batch:0090, train_loss:0.238067, train_ap:0.8951, train_acc:0.8896, train_auc:0.9594
# In epoch:038|batch:0100, train_loss:0.237762, train_ap:0.9230, train_acc:0.8965, train_auc:0.9712
# In epoch:038|batch:0110, train_loss:0.237660, train_ap:0.9088, train_acc:0.9009, train_auc:0.9677
# In epoch:038|batch:0120, train_loss:0.238120, train_ap:0.9058, train_acc:0.8901, train_auc:0.9652
# In epoch:038|batch:0130, train_loss:0.238372, train_ap:0.8990, train_acc:0.8901, train_auc:0.9665
# In epoch:038|batch:0140, train_loss:0.238313, train_ap:0.9127, train_acc:0.8970, train_auc:0.9692
# In epoch:038|batch:0150, train_loss:0.238526, train_ap:0.9111, train_acc:0.8892, train_auc:0.9661
# In epoch:038|batch:0160, train_loss:0.238684, train_ap:0.8952, train_acc:0.8813, train_auc:0.9622
# In epoch:038|batch:0170, train_loss:0.238702, train_ap:0.9227, train_acc:0.8960, train_auc:0.9711
# In epoch:038|batch:0000, val_loss:0.000119, val_ap:0.8887, val_acc:0.8877, val_auc:0.9619
# In epoch:038|batch:0010, val_loss:0.000124, val_ap:0.8764, val_acc:0.8877, val_auc:0.9574
# In epoch:038|batch:0020, val_loss:0.000125, val_ap:0.9203, val_acc:0.9014, val_auc:0.9681
# In epoch:038|batch:0030, val_loss:0.000125, val_ap:0.8904, val_acc:0.8691, val_auc:0.9584
# In epoch:038|batch:0040, val_loss:0.000125, val_ap:0.8739, val_acc:0.8726, val_auc:0.9534
# G: 0.918666, D: 0.651336, ALL: 0.785001
# EarlyStoper count: 12
# Early Stopping!
# Best val_metric is: 0.7860616
# In test batch:0000
# In test batch:0010
# In test batch:0020
# In test batch:0030
# In test batch:0040
# In test batch:0050
# In test batch:0060
# In test batch:0070
# In test batch:0080
# In test batch:0090
# In test batch:0100
# In test batch:0110
# In test batch:0120
# In test batch:0130
# In test batch:0140
# In test batch:0150
# In test batch:0160
# In test batch:0170
# In test batch:0180
# In test batch:0190
# In test batch:0200
# In test batch:0210
# In test batch:0220
# In test batch:0230
# In test batch:0240
# In test batch:0250
# In test batch:0260
# In test batch:0270
# In test batch:0280
# In test batch:0290
# In test batch:0300
# In test batch:0310
# In test batch:0320
# In test batch:0330
# In test batch:0340
# In test batch:0350
# In test batch:0360
# In test batch:0370
# In test batch:0380
# In test batch:0390
# In test batch:0400
# In test batch:0410
# In test batch:0420
# In test batch:0430
# In test batch:0440
# In test batch:0450
# NN out of fold AP is: 0.8949473814635063

# %%
sub = pd.DataFrame({'customer_ID': test.index,
                    'prediction': torch.softmax(test_nn_0, dim=-1)[:, 1].cpu().numpy()})
sub.to_csv('submission_mlp_delete_na_pytorch.csv', index=False)
display(sub)
# Out:
#                                               customer_ID  prediction
# 0       00000469ba478561f23a92a868bd366de6f6527a684c9a...    0.054498
# 1       00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...    0.002326
# 2       0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...    0.035608
# 3       00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...    0.536465
# 4       00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...    0.946569
# ...                                                   ...         ...
# 924616  ffff952c631f2c911b8a2a8ca56ea6e656309a83d2f64c...    0.044288
# 924617  ffffcf5df59e5e0bba2a5ac4578a34e2b5aa64a1546cd3...    0.901485
# 924618  ffffd61f098cc056dbd7d2a21380c4804bbfe60856f475...    0.839519
# 924619  ffffddef1fc3643ea179c93245b68dca0f36941cd83977...    0.559453
# 924620  fffffa7cf7e453e1acc6a1426475d5cb9400859f82ff61...    0.109672
#
# [924621 rows x 2 columns]
