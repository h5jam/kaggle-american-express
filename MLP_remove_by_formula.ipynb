# %%
import pandas as pd
import numpy as np
import pickle
from matplotlib import pyplot as plt
import random
import datetime
import math
from matplotlib.ticker import MaxNLocator
from colorama import Fore, Back, Style
import gc
import copy

from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler, QuantileTransformer, OneHotEncoder
from sklearn.metrics import roc_curve, roc_auc_score, average_precision_score

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import MultiStepLR

INFERENCE = True

# %%
def amex_metric(y_true, y_pred, return_components=False) -> float:
    """Amex metric for ndarrays"""
    def top_four_percent_captured(df) -> float:
        """Corresponds to the recall for a threshold of 4 %"""
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        four_pct_cutoff = int(0.04 * df['weight'].sum())
        df['weight_cumsum'] = df['weight'].cumsum()
        df_cutoff = df.loc[df['weight_cumsum'] <= four_pct_cutoff]
        return (df_cutoff['target'] == 1).sum() / (df['target'] == 1).sum()
        
    def weighted_gini(df) -> float:
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        df['random'] = (df['weight'] / df['weight'].sum()).cumsum()
        total_pos = (df['target'] * df['weight']).sum()
        df['cum_pos_found'] = (df['target'] * df['weight']).cumsum()
        df['lorentz'] = df['cum_pos_found'] / total_pos
        df['gini'] = (df['lorentz'] - df['random']) * df['weight']
        return df['gini'].sum()

    def normalized_weighted_gini(df) -> float:
        """Corresponds to 2 * AUC - 1"""
        df2 = pd.DataFrame({'target': df.target, 'prediction': df.target})
        df2.sort_values('prediction', ascending=False, inplace=True)
        return weighted_gini(df) / weighted_gini(df2)

    df = pd.DataFrame({'target': y_true.ravel(), 'prediction': y_pred.ravel()})
    df.sort_values('prediction', ascending=False, inplace=True)
    g = normalized_weighted_gini(df)
    d = top_four_percent_captured(df)
    print("G: {:.6f}, D: {:.6f}, ALL: {:6f}".format(g, d, 0.5*(g+d)))
    if return_components: return g, d, 0.5 * (g + d)
    return 0.5 * (g + d)

# %%
# %%time
features_avg = ['B_11', 'B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_2', 
                'B_20', 'B_28', 'B_29', 'B_3', 'B_33', 'B_36', 'B_37', 'B_4', 'B_42', 
                'B_5', 'B_8', 'B_9', 'D_102', 'D_103', 'D_105', 'D_111', 'D_112', 'D_113', 
                'D_115', 'D_118', 'D_119', 'D_121', 'D_124', 'D_128', 'D_129', 'D_131', 
                'D_132', 'D_133', 'D_139', 'D_140', 'D_141', 'D_143', 'D_144', 'D_145', 
                'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 
                'D_49', 'D_50', 'D_51', 'D_52', 'D_56', 'D_58', 'D_62', 'D_70', 'D_71', 
                'D_72', 'D_74', 'D_75', 'D_79', 'D_81', 'D_83', 'D_84', 'D_88', 'D_91', 
                'P_2', 'P_3', 'R_1', 'R_10', 'R_11', 'R_13', 'R_18', 'R_19', 'R_2', 'R_26', 
                'R_27', 'R_28', 'R_3', 'S_11', 'S_12', 'S_22', 'S_23', 'S_24', 'S_26', 
                'S_27', 'S_5', 'S_7', 'S_8', ]
features_min = ['B_13', 'B_14', 'B_15', 'B_16', 'B_17', 'B_19', 'B_2', 'B_20', 'B_22', 
                'B_24', 'B_27', 'B_28', 'B_29', 'B_3', 'B_33', 'B_36', 'B_4', 'B_42', 
                'B_5', 'B_9', 'D_102', 'D_103', 'D_107', 'D_109', 'D_110', 'D_111', 
                'D_112', 'D_113', 'D_115', 'D_118', 'D_119', 'D_121', 'D_122', 'D_128', 
                'D_129', 'D_132', 'D_133', 'D_139', 'D_140', 'D_141', 'D_143', 'D_144', 
                'D_145', 'D_39', 'D_41', 'D_42', 'D_45', 'D_46', 'D_48', 'D_50', 'D_51', 
                'D_53', 'D_54', 'D_55', 'D_56', 'D_58', 'D_59', 'D_60', 'D_62', 'D_70', 
                'D_71', 'D_74', 'D_75', 'D_78', 'D_79', 'D_81', 'D_83', 'D_84', 'D_86', 
                'D_88', 'D_96', 'P_2', 'P_3', 'P_4', 'R_1', 'R_11', 'R_13', 'R_17', 'R_19', 
                'R_2', 'R_27', 'R_28', 'R_4', 'R_5', 'R_8', 'S_11', 'S_12', 'S_23', 'S_25', 
                'S_3', 'S_5', 'S_7', 'S_9', ]
features_max = ['B_1', 'B_11', 'B_13', 'B_15', 'B_16', 'B_17', 'B_18', 'B_19', 'B_2', 
                'B_22', 'B_24', 'B_27', 'B_28', 'B_29', 'B_3', 'B_31', 'B_33', 'B_36', 
                'B_4', 'B_42', 'B_5', 'B_7', 'B_9', 'D_102', 'D_103', 'D_105', 'D_109', 
                'D_110', 'D_112', 'D_113', 'D_115', 'D_121', 'D_124', 'D_128', 'D_129', 
                'D_131', 'D_139', 'D_141', 'D_144', 'D_145', 'D_39', 'D_41', 'D_42', 
                'D_43', 'D_44', 'D_45', 'D_46', 'D_47', 'D_48', 'D_50', 'D_51', 'D_52', 
                'D_53', 'D_56', 'D_58', 'D_59', 'D_60', 'D_62', 'D_70', 'D_72', 'D_74', 
                'D_75', 'D_79', 'D_81', 'D_83', 'D_84', 'D_88', 'D_89', 'P_2', 'P_3', 
                'R_1', 'R_10', 'R_11', 'R_26', 'R_28', 'R_3', 'R_4', 'R_5', 'R_7', 'R_8', 
                'S_11', 'S_12', 'S_23', 'S_25', 'S_26', 'S_27', 'S_3', 'S_5', 'S_7', 'S_8', ]
features_last = ['B_1', 'B_11', 'B_12', 'B_13', 'B_14', 'B_16', 'B_18', 'B_19', 'B_2', 
                 'B_20', 'B_21', 'B_24', 'B_27', 'B_28', 'B_29', 'B_3', 'B_30', 'B_31', 
                 'B_33', 'B_36', 'B_37', 'B_38', 'B_39', 'B_4', 'B_40', 'B_42', 'B_5', 
                 'B_8', 'B_9', 'D_102', 'D_105', 'D_106', 'D_107', 'D_108', 'D_110', 
                 'D_111', 'D_112', 'D_113', 'D_114', 'D_115', 'D_116', 'D_117', 'D_118', 
                 'D_119', 'D_120', 'D_121', 'D_124', 'D_126', 'D_128', 'D_129', 'D_131', 
                 'D_132', 'D_133', 'D_137', 'D_138', 'D_139', 'D_140', 'D_141', 'D_142', 
                 'D_143', 'D_144', 'D_145', 'D_39', 'D_41', 'D_42', 'D_43', 'D_44', 'D_45', 
                 'D_46', 'D_47', 'D_48', 'D_49', 'D_50', 'D_51', 'D_52', 'D_53', 'D_55', 
                 'D_56', 'D_59', 'D_60', 'D_62', 'D_63', 'D_64', 'D_66', 'D_68', 'D_70', 
                 'D_71', 'D_72', 'D_73', 'D_74', 'D_75', 'D_77', 'D_78', 'D_81', 'D_82', 
                 'D_83', 'D_84', 'D_88', 'D_89', 'D_91', 'D_94', 'D_96', 'P_2', 'P_3', 
                 'P_4', 'R_1', 'R_10', 'R_11', 'R_12', 'R_13', 'R_16', 'R_17', 'R_18', 
                 'R_19', 'R_25', 'R_28', 'R_3', 'R_4', 'R_5', 'R_8', 'S_11', 'S_12', 
                 'S_23', 'S_25', 'S_26', 'S_27', 'S_3', 'S_5', 'S_7', 'S_8', 'S_9', ]
features_categorical = ['B_30_last', 'B_38_last', 'D_114_last', 'D_116_last',
                        'D_117_last', 'D_120_last', 'D_126_last',
                        'D_63_last', 'D_64_last', 'D_66_last', 'D_68_last']

features_avg = list(set(features_avg) - set(['B_11', 'B_18', 'B_28', 'B_4', 'B_7', 'D_47', 'D_58', 'D_60', 'S_11']))

for i in [0, 1] if INFERENCE else [0]:
    # i == 0 -> process the train data
    # i == 1 -> process the test data
    df = pd.read_feather(['train_data.ftr',
                          'test_data.ftr'][i])
    cid = pd.Categorical(df.pop('customer_ID'), ordered=True)
    last = (cid != np.roll(cid, -1)) # mask for last statement of every customer
    if i == 0: # train
        target = df.loc[last, 'target']
    print('Read', i)
    gc.collect()
    df_avg = (df
              .groupby(cid)
              .mean()[features_avg]
              .rename(columns={f: f"{f}_avg" for f in features_avg})
             )
    print('Computed avg', i)
    gc.collect()
    df_max = (df
              .groupby(cid)
              .max()[features_max]
              .rename(columns={f: f"{f}_max" for f in features_max})
             )
    print('Computed max', i)
    gc.collect()
    df_min = (df
              .groupby(cid)
              .min()[features_min]
              .rename(columns={f: f"{f}_min" for f in features_min})
             )
    print('Computed min', i)
    gc.collect()
    df_last = (df.loc[last, features_last]
               .rename(columns={f: f"{f}_last" for f in features_last})
               .set_index(np.asarray(cid[last]))
              )
    df = None # we no longer need the original data
    print('Computed last', i)
    
    df_categorical = df_last[features_categorical].astype(object)
    features_not_cat = [f for f in df_last.columns if f not in features_categorical]
    if i == 0: # train
        ohe = OneHotEncoder(drop='first', sparse=False, dtype=np.float32, handle_unknown='ignore')
        ohe.fit(df_categorical)
        with open("ohe.pickle", 'wb') as f: pickle.dump(ohe, f)
    df_categorical = pd.DataFrame(ohe.transform(df_categorical).astype(np.float16),
                                  index=df_categorical.index).rename(columns=str)
    print('Computed categorical', i)
    
    df = pd.concat([df_last[features_not_cat], df_categorical, df_avg, df_min, df_max], axis=1)
    
    # Impute missing values
    df.fillna(value=0, inplace=True)
    
    del df_avg, df_max, df_min, df_last, df_categorical, cid, last, features_not_cat
    
    if i == 0: # train
        # Free the memory
        df.reset_index(drop=True, inplace=True) # frees 0.2 GByte
        df.to_feather('train_processed.ftr')
        df = None
        gc.collect()

train = pd.read_feather('train_processed.ftr')
test = df
del df, ohe

print('Shapes:', train.shape, target.shape)
# Out:
# Read 0
# Computed avg 0
# <timed exec>:72: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
# Computed max 0
# <timed exec>:79: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
# Computed min 0
# Computed last 0
# Computed categorical 0
# Read 1
# Computed avg 1
# <timed exec>:72: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
# Computed max 1
# <timed exec>:79: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
# Computed min 1
# Computed last 1
# Computed categorical 1
# Shapes: (458913, 428) (458913,)
# CPU times: user 2min 4s, sys: 35.1 s, total: 2min 39s
# Wall time: 2min 6s

# %%
class my_model(nn.Module):
    def __init__(self, in_feat, hid_dim=256, activation=nn.ReLU(), dropout=0.1):
        super(my_model, self).__init__()
        self.encode = nn.Linear(in_feat, hid_dim)
        self.activation = activation
        self.hidden1 = nn.Linear(hid_dim, 64)
        self.hidden2 = nn.Linear(64, 64)
        self.drop = nn.Dropout(dropout)
        self.hidden3 = nn.Linear(64+hid_dim, 16)
        self.pred = nn.Linear(16, 2)
    
    def forward(self, x):
        h0 = self.activation(self.encode(x))
        h1 = self.activation(self.hidden2(self.activation(self.hidden1(h0))))
        h = self.drop(torch.concat([h0, h1], dim=-1))
        h = self.activation(self.hidden3(h))
        return self.pred(h)

# %%
class early_stopper(object):
    def __init__(self, patience=12, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.delta = delta
        self.best_value = None
        self.best_cv = None
        self.is_earlystop = False
        self.count = 0
        self.best_model = None
        #self.val_preds = []
        #self.val_logits = []

    def earlystop(self, loss, value, model=None):#, preds, logits):
        """
        value: evaluation value on valiation dataset
        """
        cv = value
        if self.best_value is None:
            self.best_value = value
            self.best_cv = cv
            self.best_model = copy.deepcopy(model).to('cpu')
            #self.val_preds = preds
            #self.val_logits = logits
        elif value < self.best_value + self.delta:
            self.count += 1
            if self.verbose:
                print('EarlyStoper count: {:02d}'.format(self.count))
            if self.count >= self.patience:
                self.is_earlystop = True
        else:
            self.best_value = value
            self.best_cv = cv
            self.best_model = copy.deepcopy(model).to('cpu')
            #self.val_preds = preds
            #self.val_logits = logits
            self.count = 0

# %%
def fit_model(train_nn, train_y, test_nn, params):
    device = params['device']
    oof_predictions = torch.from_numpy(np.zeros([len(train_nn), 2])).float().to(device)
    test_predictions = torch.from_numpy(np.zeros([len(test_nn), 2])).float().to(device)
    kfold = StratifiedKFold(n_splits=params['n_fold'], shuffle=True, random_state=params['seed'])
    features_numerical = [f for f in train_nn.columns if f != 'target' and f != 'customer_ID']
    y_target = train_y.target.values
    num_feat = train_nn[features_numerical]
    y = train_y.target
    labels = torch.from_numpy(y.values).long().to(device)
    loss_fn = nn.CrossEntropyLoss(weight=torch.from_numpy(np.array([118828, 340085])).float()).to(device)
    for fold, (trn_idx, val_idx) in enumerate(kfold.split(train_nn, y_target)):
        print(f'Training fold {fold + 1}')
        x_train, x_val = num_feat.iloc[trn_idx], num_feat.iloc[val_idx]
        scaler = StandardScaler()
        x_train = torch.from_numpy(scaler.fit_transform(x_train)).float().to(device)
        x_val = torch.from_numpy(scaler.transform(x_val)).float().to(device)
        y_train, y_val = labels[trn_idx], labels[val_idx]
        train_sample_strategy = torch.utils.data.sampler.WeightedRandomSampler(np.ones(len(trn_idx)),
                                                                               num_samples=len(trn_idx), replacement=False)
        train_dataloader = torch.utils.data.DataLoader(np.array(range(len(trn_idx))), batch_size=params['batch_size'], num_workers=0,
                                                       sampler=train_sample_strategy, drop_last=False)
        val_sample_strategy = torch.utils.data.sampler.WeightedRandomSampler(np.ones(len(val_idx)),
                                                                             num_samples=len(val_idx), replacement=False)
        val_dataloader = torch.utils.data.DataLoader(np.array(range(len(val_idx))), batch_size=params['batch_size'], num_workers=0,
                                                     sampler=val_sample_strategy, drop_last=False)
        model = eval(params['model'])(x_train.shape[1]).to(device)
        lr = params['lr'] * np.sqrt(params['batch_size']/2048)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=params['wd'])
        lr_scheduler = MultiStepLR(optimizer=optimizer, milestones=[800, 1600, 2400, 3200, 4000, 4800, 5600, 6400, 7200], gamma=0.6)
        earlystoper = early_stopper(patience=params['early_stopping'], verbose=True)
        start_epoch = 0
        for epoch in range(start_epoch, params['max_epochs']):
            train_loss_list = []
            # train_acc_list = []
            model.train()
            for step, input_seeds in enumerate(train_dataloader):
                batch_inputs = x_train[input_seeds].to(device)
                batch_labels = y_train[input_seeds].to(device)
                train_batch_logits = model(batch_inputs)
                train_loss = loss_fn(train_batch_logits, batch_labels)
                # backward
                optimizer.zero_grad()
                train_loss.backward()
                optimizer.step()
                lr_scheduler.step()
                train_loss_list.append(train_loss.cpu().detach().numpy())
                
                #tr_batch_pred = None

                if step % 10 == 0:
                    tr_batch_pred = torch.sum(torch.argmax(train_batch_logits.clone().detach(), dim=1) == batch_labels) / batch_labels.shape[0]
                    score = torch.softmax(train_batch_logits.clone().detach(), dim=1)[:, 1].cpu().numpy()
                    print('In epoch:{:03d}|batch:{:04d}, train_loss:{:4f}, '
                          'train_ap:{:.4f}, train_acc:{:.4f}, train_auc:{:.4f}'.format(epoch,step,
                                                                                       np.mean(train_loss_list),
                                                                                       average_precision_score(batch_labels.cpu().numpy(), score), 
                                                                                       tr_batch_pred.detach(),
                                                                                       roc_auc_score(batch_labels.cpu().numpy(), score)))
        
            # mini-batch for validation
            val_loss_list = 0
            val_acc_list = 0
            #val_correct_list = 0
            val_all_list = 0
            model.eval()
            with torch.no_grad():
                for step, input_seeds in enumerate(val_dataloader):
                    batch_inputs = x_val[input_seeds].to(device)
                    batch_labels = y_val[input_seeds].to(device)
                    val_batch_logits = model(batch_inputs)
                    oof_predictions[val_idx[input_seeds]] = val_batch_logits
                    val_loss_list = val_loss_list + loss_fn(val_batch_logits, batch_labels)
                    val_batch_pred = torch.sum(torch.argmax(val_batch_logits, dim=1) == batch_labels) / torch.tensor(batch_labels.shape[0])
                    val_acc_list = val_acc_list + val_batch_pred * torch.tensor(batch_labels.shape[0])
                    val_all_list = val_all_list + batch_labels.shape[0]
                    if step % 10 == 0:
                        score = torch.softmax(val_batch_logits.clone().detach(), dim=1)[:, 1].cpu().numpy()
                        print('In epoch:{:03d}|batch:{:04d}, val_loss:{:4f}, val_ap:{:.4f}, '
                              'val_acc:{:.4f}, val_auc:{:.4f}'.format(epoch,
                                                                      step,
                                                                      val_loss_list/val_all_list,
                                                                      average_precision_score(batch_labels.cpu().numpy(), score), 
                                                                      val_batch_pred.detach(),
                                                                      roc_auc_score(batch_labels.cpu().numpy(), score)))
                #tmp_predictions = model(test_feature).cpu().numpy()
            #infold_preds[fold] = tmp_predictions
            #test_predictions += tmp_predictions / params['n_fold']
            val_predictions = torch.softmax(oof_predictions[val_idx, :].detach(), dim=-1)[:, 1].cpu().numpy()
            earlystoper.earlystop(val_loss_list, amex_metric(y_val.float().cpu().numpy(), val_predictions), model)
            if earlystoper.is_earlystop:
                print("Early Stopping!")
                break
        print("Best val_metric is: {:.7f}".format(earlystoper.best_cv))
        test_sample_strategy = torch.utils.data.sampler.WeightedRandomSampler(np.ones(len(test_nn)),
                                                                              num_samples=len(test_nn), replacement=False)
        test_dataloader = torch.utils.data.DataLoader(np.array(range(len(test_nn))), batch_size=params['batch_size'], num_workers=0,
                                                      sampler=test_sample_strategy, drop_last=False)
        test_num_feat = torch.from_numpy(scaler.transform(test_nn[features_numerical])).float().to(device)
        b_model = earlystoper.best_model.to(device)
        b_model.eval()
        with torch.no_grad():
            for step, input_seeds in enumerate(test_dataloader):
                batch_inputs = test_num_feat[input_seeds].to(device)
                test_batch_logits = b_model(batch_inputs)
                test_predictions[input_seeds] = test_batch_logits
                #test_batch_pred = torch.sum(torch.argmax(test_batch_logits, dim=1) == batch_labels) / torch.tensor(batch_labels.shape[0])
                if step % 10 == 0:
                    print('In test batch:{:04d}'.format(step))
    #my_acc = acc(y, oof_predictions)
    my_ap = average_precision_score(y_target, torch.softmax(oof_predictions, dim=1).cpu()[:, 1])
    print("NN out of fold AP is:", my_ap)
    return earlystoper.best_model.to('cpu'), oof_predictions, test_predictions

# %%
params = {
    'model': 'my_model',
    'batch_size': 2048,
    'lr': 0.01,
    'wd': 4e-4,
    #'device': 'cpu',
    'device': 'cuda:0',
    'early_stopping': 12,
    'n_fold': 5,
    'seed': 2021,
    'max_epochs': 200,
}

b_models, val_nn_0, test_nn_0 = fit_model(train_nn=train,
                                          train_y=pd.DataFrame(target), 
                                          test_nn=test,
                                          params=params)
# Out:
# Training fold 1
# In epoch:000|batch:0000, train_loss:0.710817, train_ap:0.1960, train_acc:0.6025, train_auc:0.2787
# In epoch:000|batch:0010, train_loss:0.363708, train_ap:0.8567, train_acc:0.8623, train_auc:0.9461
# In epoch:000|batch:0020, train_loss:0.324311, train_ap:0.8616, train_acc:0.8594, train_auc:0.9481
# In epoch:000|batch:0030, train_loss:0.307622, train_ap:0.8830, train_acc:0.8687, train_auc:0.9590
# In epoch:000|batch:0040, train_loss:0.298238, train_ap:0.8820, train_acc:0.8711, train_auc:0.9555
# In epoch:000|batch:0050, train_loss:0.290917, train_ap:0.8761, train_acc:0.8677, train_auc:0.9538
# In epoch:000|batch:0060, train_loss:0.287313, train_ap:0.8874, train_acc:0.8804, train_auc:0.9582
# In epoch:000|batch:0070, train_loss:0.283884, train_ap:0.8860, train_acc:0.8726, train_auc:0.9604
# In epoch:000|batch:0080, train_loss:0.280950, train_ap:0.8728, train_acc:0.8774, train_auc:0.9532
# In epoch:000|batch:0090, train_loss:0.278844, train_ap:0.9005, train_acc:0.8848, train_auc:0.9614
# In epoch:000|batch:0100, train_loss:0.276735, train_ap:0.8885, train_acc:0.8633, train_auc:0.9549
# In epoch:000|batch:0110, train_loss:0.276097, train_ap:0.8692, train_acc:0.8613, train_auc:0.9527
# In epoch:000|batch:0120, train_loss:0.275337, train_ap:0.8799, train_acc:0.8652, train_auc:0.9510
# In epoch:000|batch:0130, train_loss:0.274757, train_ap:0.9009, train_acc:0.8696, train_auc:0.9624
# In epoch:000|batch:0140, train_loss:0.273986, train_ap:0.8951, train_acc:0.8848, train_auc:0.9610
# In epoch:000|batch:0150, train_loss:0.273497, train_ap:0.8790, train_acc:0.8760, train_auc:0.9534
# In epoch:000|batch:0160, train_loss:0.272911, train_ap:0.8689, train_acc:0.8613, train_auc:0.9527
# In epoch:000|batch:0170, train_loss:0.272734, train_ap:0.8766, train_acc:0.8804, train_auc:0.9563
# In epoch:000|batch:0000, val_loss:0.000124, val_ap:0.9031, val_acc:0.8784, val_auc:0.9615
# In epoch:000|batch:0010, val_loss:0.000127, val_ap:0.8988, val_acc:0.8799, val_auc:0.9578
# In epoch:000|batch:0020, val_loss:0.000126, val_ap:0.8985, val_acc:0.8853, val_auc:0.9625
# In epoch:000|batch:0030, val_loss:0.000127, val_ap:0.9068, val_acc:0.8823, val_auc:0.9615
# In epoch:000|batch:0040, val_loss:0.000126, val_ap:0.8969, val_acc:0.8716, val_auc:0.9584
# G: 0.915837, D: 0.635656, ALL: 0.775746
# In epoch:001|batch:0000, train_loss:0.266006, train_ap:0.8967, train_acc:0.8838, train_auc:0.9574
# In epoch:001|batch:0010, train_loss:0.266785, train_ap:0.8755, train_acc:0.8662, train_auc:0.9524
# In epoch:001|batch:0020, train_loss:0.271175, train_ap:0.9008, train_acc:0.8799, train_auc:0.9613
# In epoch:001|batch:0030, train_loss:0.267917, train_ap:0.8686, train_acc:0.8545, train_auc:0.9529
# In epoch:001|batch:0040, train_loss:0.267686, train_ap:0.8674, train_acc:0.8711, train_auc:0.9531
# In epoch:001|batch:0050, train_loss:0.266400, train_ap:0.8992, train_acc:0.8779, train_auc:0.9613
# In epoch:001|batch:0060, train_loss:0.265544, train_ap:0.8811, train_acc:0.8682, train_auc:0.9579
# In epoch:001|batch:0070, train_loss:0.265680, train_ap:0.8854, train_acc:0.8721, train_auc:0.9542
# In epoch:001|batch:0080, train_loss:0.265391, train_ap:0.8959, train_acc:0.8774, train_auc:0.9596
# In epoch:001|batch:0090, train_loss:0.264948, train_ap:0.8837, train_acc:0.8735, train_auc:0.9561
# In epoch:001|batch:0100, train_loss:0.265396, train_ap:0.8577, train_acc:0.8730, train_auc:0.9436
# In epoch:001|batch:0110, train_loss:0.265779, train_ap:0.8714, train_acc:0.8730, train_auc:0.9526
# In epoch:001|batch:0120, train_loss:0.265426, train_ap:0.8816, train_acc:0.8760, train_auc:0.9547
# In epoch:001|batch:0130, train_loss:0.265528, train_ap:0.8705, train_acc:0.8613, train_auc:0.9465
# In epoch:001|batch:0140, train_loss:0.264892, train_ap:0.8914, train_acc:0.8687, train_auc:0.9579
# In epoch:001|batch:0150, train_loss:0.265186, train_ap:0.8828, train_acc:0.8745, train_auc:0.9532
# In epoch:001|batch:0160, train_loss:0.265102, train_ap:0.8634, train_acc:0.8765, train_auc:0.9513
# In epoch:001|batch:0170, train_loss:0.264735, train_ap:0.8918, train_acc:0.8872, train_auc:0.9624
# In epoch:001|batch:0000, val_loss:0.000126, val_ap:0.8959, val_acc:0.8623, val_auc:0.9595
# In epoch:001|batch:0010, val_loss:0.000125, val_ap:0.8845, val_acc:0.8735, val_auc:0.9552
# In epoch:001|batch:0020, val_loss:0.000125, val_ap:0.8841, val_acc:0.8730, val_auc:0.9582
# In epoch:001|batch:0030, val_loss:0.000125, val_ap:0.8984, val_acc:0.8760, val_auc:0.9591
# In epoch:001|batch:0040, val_loss:0.000125, val_ap:0.8884, val_acc:0.8828, val_auc:0.9611
# G: 0.917565, D: 0.643440, ALL: 0.780503
# In epoch:002|batch:0000, train_loss:0.279066, train_ap:0.8747, train_acc:0.8662, train_auc:0.9521
# In epoch:002|batch:0010, train_loss:0.258096, train_ap:0.8559, train_acc:0.8716, train_auc:0.9550
# In epoch:002|batch:0020, train_loss:0.261838, train_ap:0.8858, train_acc:0.8906, train_auc:0.9594
# In epoch:002|batch:0030, train_loss:0.264611, train_ap:0.8816, train_acc:0.8638, train_auc:0.9547
# In epoch:002|batch:0040, train_loss:0.264548, train_ap:0.8888, train_acc:0.8730, train_auc:0.9535
# In epoch:002|batch:0050, train_loss:0.265679, train_ap:0.8823, train_acc:0.8799, train_auc:0.9537
# In epoch:002|batch:0060, train_loss:0.266608, train_ap:0.8733, train_acc:0.8691, train_auc:0.9533
# In epoch:002|batch:0070, train_loss:0.267251, train_ap:0.8684, train_acc:0.8667, train_auc:0.9497
# In epoch:002|batch:0080, train_loss:0.266981, train_ap:0.8797, train_acc:0.8789, train_auc:0.9542
# In epoch:002|batch:0090, train_loss:0.266236, train_ap:0.8775, train_acc:0.8618, train_auc:0.9514
# In epoch:002|batch:0100, train_loss:0.265314, train_ap:0.8975, train_acc:0.8931, train_auc:0.9619
# In epoch:002|batch:0110, train_loss:0.265185, train_ap:0.8860, train_acc:0.8682, train_auc:0.9576
# In epoch:002|batch:0120, train_loss:0.265166, train_ap:0.8746, train_acc:0.8848, train_auc:0.9547
# In epoch:002|batch:0130, train_loss:0.264687, train_ap:0.8903, train_acc:0.8813, train_auc:0.9597
# In epoch:002|batch:0140, train_loss:0.264964, train_ap:0.8792, train_acc:0.8550, train_auc:0.9522
# In epoch:002|batch:0150, train_loss:0.264771, train_ap:0.8816, train_acc:0.8784, train_auc:0.9539
# In epoch:002|batch:0160, train_loss:0.264611, train_ap:0.8863, train_acc:0.8682, train_auc:0.9528
# In epoch:002|batch:0170, train_loss:0.264357, train_ap:0.8723, train_acc:0.8765, train_auc:0.9545
# In epoch:002|batch:0000, val_loss:0.000123, val_ap:0.8966, val_acc:0.8760, val_auc:0.9600
# In epoch:002|batch:0010, val_loss:0.000125, val_ap:0.8963, val_acc:0.8813, val_auc:0.9617
# In epoch:002|batch:0020, val_loss:0.000125, val_ap:0.8834, val_acc:0.8799, val_auc:0.9598
# In epoch:002|batch:0030, val_loss:0.000125, val_ap:0.8875, val_acc:0.8784, val_auc:0.9580
# In epoch:002|batch:0040, val_loss:0.000125, val_ap:0.8925, val_acc:0.8701, val_auc:0.9620
# G: 0.916816, D: 0.636371, ALL: 0.776593
# EarlyStoper count: 01
# In epoch:003|batch:0000, train_loss:0.260737, train_ap:0.8809, train_acc:0.8657, train_auc:0.9567
# In epoch:003|batch:0010, train_loss:0.263644, train_ap:0.8676, train_acc:0.8740, train_auc:0.9549
# In epoch:003|batch:0020, train_loss:0.260011, train_ap:0.8779, train_acc:0.8872, train_auc:0.9563
# In epoch:003|batch:0030, train_loss:0.261895, train_ap:0.8833, train_acc:0.8813, train_auc:0.9571
# In epoch:003|batch:0040, train_loss:0.262512, train_ap:0.8784, train_acc:0.8721, train_auc:0.9553
# In epoch:003|batch:0050, train_loss:0.264861, train_ap:0.8829, train_acc:0.8555, train_auc:0.9516
# In epoch:003|batch:0060, train_loss:0.263622, train_ap:0.8757, train_acc:0.8770, train_auc:0.9568
# In epoch:003|batch:0070, train_loss:0.262794, train_ap:0.8908, train_acc:0.8853, train_auc:0.9579
# In epoch:003|batch:0080, train_loss:0.261872, train_ap:0.8959, train_acc:0.8882, train_auc:0.9628
# In epoch:003|batch:0090, train_loss:0.262205, train_ap:0.8899, train_acc:0.8628, train_auc:0.9601
# In epoch:003|batch:0100, train_loss:0.263557, train_ap:0.8636, train_acc:0.8691, train_auc:0.9506
# In epoch:003|batch:0110, train_loss:0.263757, train_ap:0.8933, train_acc:0.8779, train_auc:0.9587
# In epoch:003|batch:0120, train_loss:0.264115, train_ap:0.8594, train_acc:0.8691, train_auc:0.9500
# In epoch:003|batch:0130, train_loss:0.263857, train_ap:0.9106, train_acc:0.8804, train_auc:0.9647
# In epoch:003|batch:0140, train_loss:0.263866, train_ap:0.8846, train_acc:0.8662, train_auc:0.9558
# In epoch:003|batch:0150, train_loss:0.264026, train_ap:0.8759, train_acc:0.8760, train_auc:0.9519
# In epoch:003|batch:0160, train_loss:0.263935, train_ap:0.8771, train_acc:0.8843, train_auc:0.9564
# In epoch:003|batch:0170, train_loss:0.263945, train_ap:0.8953, train_acc:0.8823, train_auc:0.9614
# In epoch:003|batch:0000, val_loss:0.000131, val_ap:0.8861, val_acc:0.8774, val_auc:0.9559
# In epoch:003|batch:0010, val_loss:0.000125, val_ap:0.8995, val_acc:0.8799, val_auc:0.9605
# In epoch:003|batch:0020, val_loss:0.000125, val_ap:0.8907, val_acc:0.8799, val_auc:0.9593
# In epoch:003|batch:0030, val_loss:0.000126, val_ap:0.8908, val_acc:0.8789, val_auc:0.9613
# In epoch:003|batch:0040, val_loss:0.000126, val_ap:0.8875, val_acc:0.8774, val_auc:0.9598
# G: 0.917122, D: 0.639822, ALL: 0.778472
# EarlyStoper count: 02
# In epoch:004|batch:0000, train_loss:0.259397, train_ap:0.8855, train_acc:0.8760, train_auc:0.9582
# In epoch:004|batch:0010, train_loss:0.266507, train_ap:0.8749, train_acc:0.8760, train_auc:0.9573
# In epoch:004|batch:0020, train_loss:0.266528, train_ap:0.8680, train_acc:0.8828, train_auc:0.9521
# In epoch:004|batch:0030, train_loss:0.265176, train_ap:0.8921, train_acc:0.8823, train_auc:0.9590
# In epoch:004|batch:0040, train_loss:0.264131, train_ap:0.8868, train_acc:0.8784, train_auc:0.9581
# In epoch:004|batch:0050, train_loss:0.264392, train_ap:0.8977, train_acc:0.8726, train_auc:0.9559
# In epoch:004|batch:0060, train_loss:0.265011, train_ap:0.9030, train_acc:0.8828, train_auc:0.9615
# In epoch:004|batch:0070, train_loss:0.264240, train_ap:0.8853, train_acc:0.8647, train_auc:0.9543
# In epoch:004|batch:0080, train_loss:0.264188, train_ap:0.8833, train_acc:0.8774, train_auc:0.9544
# In epoch:004|batch:0090, train_loss:0.263613, train_ap:0.8796, train_acc:0.8838, train_auc:0.9556
# In epoch:004|batch:0100, train_loss:0.262836, train_ap:0.9021, train_acc:0.8735, train_auc:0.9598
# In epoch:004|batch:0110, train_loss:0.262439, train_ap:0.8856, train_acc:0.8809, train_auc:0.9584
# In epoch:004|batch:0120, train_loss:0.262395, train_ap:0.8950, train_acc:0.8823, train_auc:0.9608
# In epoch:004|batch:0130, train_loss:0.262084, train_ap:0.8990, train_acc:0.8770, train_auc:0.9593
# In epoch:004|batch:0140, train_loss:0.261983, train_ap:0.9124, train_acc:0.8916, train_auc:0.9664
# In epoch:004|batch:0150, train_loss:0.261803, train_ap:0.8978, train_acc:0.8799, train_auc:0.9595
# In epoch:004|batch:0160, train_loss:0.261713, train_ap:0.8811, train_acc:0.8682, train_auc:0.9519
# In epoch:004|batch:0170, train_loss:0.261955, train_ap:0.8847, train_acc:0.8779, train_auc:0.9569
# In epoch:004|batch:0000, val_loss:0.000125, val_ap:0.8869, val_acc:0.8804, val_auc:0.9586
# In epoch:004|batch:0010, val_loss:0.000124, val_ap:0.9094, val_acc:0.8838, val_auc:0.9641
# In epoch:004|batch:0020, val_loss:0.000123, val_ap:0.8914, val_acc:0.8711, val_auc:0.9609
# In epoch:004|batch:0030, val_loss:0.000125, val_ap:0.8840, val_acc:0.8770, val_auc:0.9546
# In epoch:004|batch:0040, val_loss:0.000124, val_ap:0.9195, val_acc:0.8921, val_auc:0.9682
# G: 0.919805, D: 0.650173, ALL: 0.784989
# In epoch:005|batch:0000, train_loss:0.269193, train_ap:0.8764, train_acc:0.8740, train_auc:0.9541
# In epoch:005|batch:0010, train_loss:0.262251, train_ap:0.8947, train_acc:0.8877, train_auc:0.9622
# In epoch:005|batch:0020, train_loss:0.260064, train_ap:0.8712, train_acc:0.8672, train_auc:0.9531
# In epoch:005|batch:0030, train_loss:0.258091, train_ap:0.8957, train_acc:0.8823, train_auc:0.9599
# In epoch:005|batch:0040, train_loss:0.257926, train_ap:0.8737, train_acc:0.8809, train_auc:0.9561
# In epoch:005|batch:0050, train_loss:0.259654, train_ap:0.8733, train_acc:0.8730, train_auc:0.9562
# In epoch:005|batch:0060, train_loss:0.259046, train_ap:0.8858, train_acc:0.8716, train_auc:0.9573
# In epoch:005|batch:0070, train_loss:0.259360, train_ap:0.8783, train_acc:0.8730, train_auc:0.9497
# In epoch:005|batch:0080, train_loss:0.259244, train_ap:0.8924, train_acc:0.8770, train_auc:0.9576
# In epoch:005|batch:0090, train_loss:0.258871, train_ap:0.8823, train_acc:0.8730, train_auc:0.9570
# In epoch:005|batch:0100, train_loss:0.259273, train_ap:0.8891, train_acc:0.8745, train_auc:0.9576
# In epoch:005|batch:0110, train_loss:0.259762, train_ap:0.8656, train_acc:0.8647, train_auc:0.9484
# In epoch:005|batch:0120, train_loss:0.259734, train_ap:0.8802, train_acc:0.8765, train_auc:0.9543
# In epoch:005|batch:0130, train_loss:0.260191, train_ap:0.8752, train_acc:0.8711, train_auc:0.9552
# In epoch:005|batch:0140, train_loss:0.260623, train_ap:0.8779, train_acc:0.8604, train_auc:0.9530
# In epoch:005|batch:0150, train_loss:0.260582, train_ap:0.8906, train_acc:0.8882, train_auc:0.9593
# In epoch:005|batch:0160, train_loss:0.260371, train_ap:0.8988, train_acc:0.8760, train_auc:0.9611
# In epoch:005|batch:0170, train_loss:0.260342, train_ap:0.8832, train_acc:0.8716, train_auc:0.9574
# In epoch:005|batch:0000, val_loss:0.000129, val_ap:0.8655, val_acc:0.8774, val_auc:0.9534
# In epoch:005|batch:0010, val_loss:0.000124, val_ap:0.8983, val_acc:0.8755, val_auc:0.9595
# In epoch:005|batch:0020, val_loss:0.000124, val_ap:0.9021, val_acc:0.8862, val_auc:0.9585
# In epoch:005|batch:0030, val_loss:0.000124, val_ap:0.8848, val_acc:0.8726, val_auc:0.9565
# In epoch:005|batch:0040, val_loss:0.000123, val_ap:0.8981, val_acc:0.8828, val_auc:0.9621
# G: 0.919361, D: 0.647185, ALL: 0.783273
# EarlyStoper count: 01
# In epoch:006|batch:0000, train_loss:0.230584, train_ap:0.9154, train_acc:0.9014, train_auc:0.9671
# In epoch:006|batch:0010, train_loss:0.259183, train_ap:0.8819, train_acc:0.8706, train_auc:0.9573
# In epoch:006|batch:0020, train_loss:0.260906, train_ap:0.8668, train_acc:0.8638, train_auc:0.9460
# In epoch:006|batch:0030, train_loss:0.261181, train_ap:0.8999, train_acc:0.8813, train_auc:0.9638
# In epoch:006|batch:0040, train_loss:0.260246, train_ap:0.8945, train_acc:0.8882, train_auc:0.9609
# In epoch:006|batch:0050, train_loss:0.259916, train_ap:0.8758, train_acc:0.8662, train_auc:0.9545
# In epoch:006|batch:0060, train_loss:0.260837, train_ap:0.8885, train_acc:0.8799, train_auc:0.9574
# In epoch:006|batch:0070, train_loss:0.260372, train_ap:0.8899, train_acc:0.8623, train_auc:0.9591
# In epoch:006|batch:0080, train_loss:0.260002, train_ap:0.8893, train_acc:0.8667, train_auc:0.9590
# In epoch:006|batch:0090, train_loss:0.259336, train_ap:0.8672, train_acc:0.8740, train_auc:0.9519
# In epoch:006|batch:0100, train_loss:0.259554, train_ap:0.8815, train_acc:0.8828, train_auc:0.9570
# In epoch:006|batch:0110, train_loss:0.259423, train_ap:0.8756, train_acc:0.8779, train_auc:0.9588
# In epoch:006|batch:0120, train_loss:0.259609, train_ap:0.8829, train_acc:0.8755, train_auc:0.9563
# In epoch:006|batch:0130, train_loss:0.259396, train_ap:0.9114, train_acc:0.8950, train_auc:0.9650
# In epoch:006|batch:0140, train_loss:0.259435, train_ap:0.8972, train_acc:0.8818, train_auc:0.9613
# In epoch:006|batch:0150, train_loss:0.259564, train_ap:0.8781, train_acc:0.8667, train_auc:0.9498
# In epoch:006|batch:0160, train_loss:0.259849, train_ap:0.8894, train_acc:0.8794, train_auc:0.9561
# In epoch:006|batch:0170, train_loss:0.259546, train_ap:0.8893, train_acc:0.8691, train_auc:0.9548
# In epoch:006|batch:0000, val_loss:0.000119, val_ap:0.9089, val_acc:0.8706, val_auc:0.9631
# In epoch:006|batch:0010, val_loss:0.000125, val_ap:0.8778, val_acc:0.8638, val_auc:0.9528
# In epoch:006|batch:0020, val_loss:0.000125, val_ap:0.8673, val_acc:0.8672, val_auc:0.9538
# In epoch:006|batch:0030, val_loss:0.000125, val_ap:0.9036, val_acc:0.8789, val_auc:0.9608
# In epoch:006|batch:0040, val_loss:0.000124, val_ap:0.8865, val_acc:0.8794, val_auc:0.9636
# G: 0.919166, D: 0.644450, ALL: 0.781808
# EarlyStoper count: 02
# In epoch:007|batch:0000, train_loss:0.244638, train_ap:0.8998, train_acc:0.8774, train_auc:0.9630
# In epoch:007|batch:0010, train_loss:0.263765, train_ap:0.8992, train_acc:0.8804, train_auc:0.9607
# In epoch:007|batch:0020, train_loss:0.260901, train_ap:0.8926, train_acc:0.8823, train_auc:0.9589
# In epoch:007|batch:0030, train_loss:0.260564, train_ap:0.8761, train_acc:0.8882, train_auc:0.9576
# In epoch:007|batch:0040, train_loss:0.259032, train_ap:0.8941, train_acc:0.8823, train_auc:0.9622
# In epoch:007|batch:0050, train_loss:0.259193, train_ap:0.8852, train_acc:0.8730, train_auc:0.9522
# In epoch:007|batch:0060, train_loss:0.260099, train_ap:0.8636, train_acc:0.8740, train_auc:0.9521
# In epoch:007|batch:0070, train_loss:0.259168, train_ap:0.8818, train_acc:0.8711, train_auc:0.9582
# In epoch:007|batch:0080, train_loss:0.259427, train_ap:0.8899, train_acc:0.8789, train_auc:0.9590
# In epoch:007|batch:0090, train_loss:0.259797, train_ap:0.8831, train_acc:0.8760, train_auc:0.9547
# In epoch:007|batch:0100, train_loss:0.259854, train_ap:0.9052, train_acc:0.8882, train_auc:0.9642
# In epoch:007|batch:0110, train_loss:0.260365, train_ap:0.9014, train_acc:0.8818, train_auc:0.9605
# In epoch:007|batch:0120, train_loss:0.260059, train_ap:0.8853, train_acc:0.8726, train_auc:0.9562
# In epoch:007|batch:0130, train_loss:0.259702, train_ap:0.8866, train_acc:0.8823, train_auc:0.9600
# In epoch:007|batch:0140, train_loss:0.259698, train_ap:0.8906, train_acc:0.8696, train_auc:0.9592
# In epoch:007|batch:0150, train_loss:0.259586, train_ap:0.8885, train_acc:0.8745, train_auc:0.9546
# In epoch:007|batch:0160, train_loss:0.259576, train_ap:0.8836, train_acc:0.8784, train_auc:0.9575
# In epoch:007|batch:0170, train_loss:0.259912, train_ap:0.8892, train_acc:0.8721, train_auc:0.9578
# In epoch:007|batch:0000, val_loss:0.000128, val_ap:0.8913, val_acc:0.8647, val_auc:0.9560
# In epoch:007|batch:0010, val_loss:0.000127, val_ap:0.8895, val_acc:0.8823, val_auc:0.9581
# In epoch:007|batch:0020, val_loss:0.000124, val_ap:0.8958, val_acc:0.8789, val_auc:0.9629
# In epoch:007|batch:0030, val_loss:0.000123, val_ap:0.8978, val_acc:0.8745, val_auc:0.9617
# In epoch:007|batch:0040, val_loss:0.000124, val_ap:0.8953, val_acc:0.8901, val_auc:0.9601
# G: 0.919080, D: 0.644450, ALL: 0.781765
# EarlyStoper count: 03
# In epoch:008|batch:0000, train_loss:0.254061, train_ap:0.8828, train_acc:0.8774, train_auc:0.9578
# In epoch:008|batch:0010, train_loss:0.257933, train_ap:0.8877, train_acc:0.8779, train_auc:0.9570
# In epoch:008|batch:0020, train_loss:0.258039, train_ap:0.8945, train_acc:0.8799, train_auc:0.9573
# In epoch:008|batch:0030, train_loss:0.258128, train_ap:0.8939, train_acc:0.8853, train_auc:0.9610
# In epoch:008|batch:0040, train_loss:0.257445, train_ap:0.8829, train_acc:0.8711, train_auc:0.9569
# In epoch:008|batch:0050, train_loss:0.259108, train_ap:0.8804, train_acc:0.8604, train_auc:0.9529
# In epoch:008|batch:0060, train_loss:0.258292, train_ap:0.8845, train_acc:0.8843, train_auc:0.9602
# In epoch:008|batch:0070, train_loss:0.259137, train_ap:0.8748, train_acc:0.8667, train_auc:0.9554
# In epoch:008|batch:0080, train_loss:0.259179, train_ap:0.8822, train_acc:0.8823, train_auc:0.9545
# In epoch:008|batch:0090, train_loss:0.259513, train_ap:0.8832, train_acc:0.8804, train_auc:0.9575
# In epoch:008|batch:0100, train_loss:0.259405, train_ap:0.8794, train_acc:0.8672, train_auc:0.9544
# In epoch:008|batch:0110, train_loss:0.259167, train_ap:0.8842, train_acc:0.8857, train_auc:0.9568
# In epoch:008|batch:0120, train_loss:0.259093, train_ap:0.8927, train_acc:0.8823, train_auc:0.9590
# In epoch:008|batch:0130, train_loss:0.258975, train_ap:0.8872, train_acc:0.8784, train_auc:0.9585
# In epoch:008|batch:0140, train_loss:0.258792, train_ap:0.8887, train_acc:0.8726, train_auc:0.9550
# In epoch:008|batch:0150, train_loss:0.258637, train_ap:0.8821, train_acc:0.8687, train_auc:0.9562
# In epoch:008|batch:0160, train_loss:0.259227, train_ap:0.8915, train_acc:0.8740, train_auc:0.9564
# In epoch:008|batch:0170, train_loss:0.259386, train_ap:0.8674, train_acc:0.8638, train_auc:0.9490
# In epoch:008|batch:0000, val_loss:0.000118, val_ap:0.9096, val_acc:0.8862, val_auc:0.9636
# In epoch:008|batch:0010, val_loss:0.000125, val_ap:0.9085, val_acc:0.8857, val_auc:0.9623
# In epoch:008|batch:0020, val_loss:0.000122, val_ap:0.8968, val_acc:0.8950, val_auc:0.9609
# In epoch:008|batch:0030, val_loss:0.000122, val_ap:0.8908, val_acc:0.8799, val_auc:0.9582
# In epoch:008|batch:0040, val_loss:0.000122, val_ap:0.8981, val_acc:0.8843, val_auc:0.9607
# G: 0.920331, D: 0.645586, ALL: 0.782959
# EarlyStoper count: 04
# In epoch:009|batch:0000, train_loss:0.255251, train_ap:0.8897, train_acc:0.8687, train_auc:0.9585
# In epoch:009|batch:0010, train_loss:0.259535, train_ap:0.8844, train_acc:0.8750, train_auc:0.9585
# In epoch:009|batch:0020, train_loss:0.256049, train_ap:0.8835, train_acc:0.8804, train_auc:0.9580
# In epoch:009|batch:0030, train_loss:0.257098, train_ap:0.8773, train_acc:0.8706, train_auc:0.9538
# In epoch:009|batch:0040, train_loss:0.257415, train_ap:0.8860, train_acc:0.8770, train_auc:0.9561
# In epoch:009|batch:0050, train_loss:0.257266, train_ap:0.8869, train_acc:0.8687, train_auc:0.9552
# In epoch:009|batch:0060, train_loss:0.258054, train_ap:0.8993, train_acc:0.8804, train_auc:0.9618
# In epoch:009|batch:0070, train_loss:0.257924, train_ap:0.9004, train_acc:0.8877, train_auc:0.9633
# In epoch:009|batch:0080, train_loss:0.257663, train_ap:0.9172, train_acc:0.8940, train_auc:0.9674
# In epoch:009|batch:0090, train_loss:0.257852, train_ap:0.8851, train_acc:0.8774, train_auc:0.9550
# In epoch:009|batch:0100, train_loss:0.257975, train_ap:0.8930, train_acc:0.8740, train_auc:0.9576
# In epoch:009|batch:0110, train_loss:0.257788, train_ap:0.8979, train_acc:0.8906, train_auc:0.9624
# In epoch:009|batch:0120, train_loss:0.257500, train_ap:0.9022, train_acc:0.8774, train_auc:0.9582
# In epoch:009|batch:0130, train_loss:0.257359, train_ap:0.8948, train_acc:0.8804, train_auc:0.9598
# In epoch:009|batch:0140, train_loss:0.257827, train_ap:0.8831, train_acc:0.8823, train_auc:0.9579
# In epoch:009|batch:0150, train_loss:0.257269, train_ap:0.8858, train_acc:0.8774, train_auc:0.9565
# In epoch:009|batch:0160, train_loss:0.257325, train_ap:0.9002, train_acc:0.8755, train_auc:0.9636
# In epoch:009|batch:0170, train_loss:0.257149, train_ap:0.9024, train_acc:0.8823, train_auc:0.9623
# In epoch:009|batch:0000, val_loss:0.000113, val_ap:0.9056, val_acc:0.8843, val_auc:0.9652
# In epoch:009|batch:0010, val_loss:0.000121, val_ap:0.8983, val_acc:0.8657, val_auc:0.9593
# In epoch:009|batch:0020, val_loss:0.000122, val_ap:0.8901, val_acc:0.8813, val_auc:0.9576
# In epoch:009|batch:0030, val_loss:0.000122, val_ap:0.9027, val_acc:0.8799, val_auc:0.9624
# In epoch:009|batch:0040, val_loss:0.000123, val_ap:0.9025, val_acc:0.8916, val_auc:0.9629
# G: 0.919943, D: 0.648994, ALL: 0.784468
# EarlyStoper count: 05
# In epoch:010|batch:0000, train_loss:0.250694, train_ap:0.8873, train_acc:0.8750, train_auc:0.9596
# In epoch:010|batch:0010, train_loss:0.254732, train_ap:0.8838, train_acc:0.8770, train_auc:0.9549
# In epoch:010|batch:0020, train_loss:0.254534, train_ap:0.8793, train_acc:0.8750, train_auc:0.9544
# In epoch:010|batch:0030, train_loss:0.252366, train_ap:0.9067, train_acc:0.8843, train_auc:0.9634
# In epoch:010|batch:0040, train_loss:0.254195, train_ap:0.8829, train_acc:0.8809, train_auc:0.9561
# In epoch:010|batch:0050, train_loss:0.254425, train_ap:0.8916, train_acc:0.8755, train_auc:0.9610
# In epoch:010|batch:0060, train_loss:0.254877, train_ap:0.9123, train_acc:0.8867, train_auc:0.9654
# In epoch:010|batch:0070, train_loss:0.255314, train_ap:0.8870, train_acc:0.8848, train_auc:0.9576
# In epoch:010|batch:0080, train_loss:0.256096, train_ap:0.8842, train_acc:0.8691, train_auc:0.9565
# In epoch:010|batch:0090, train_loss:0.255917, train_ap:0.9015, train_acc:0.8765, train_auc:0.9611
# In epoch:010|batch:0100, train_loss:0.256347, train_ap:0.8820, train_acc:0.8525, train_auc:0.9515
# In epoch:010|batch:0110, train_loss:0.256433, train_ap:0.8724, train_acc:0.8618, train_auc:0.9531
# In epoch:010|batch:0120, train_loss:0.256456, train_ap:0.8988, train_acc:0.8770, train_auc:0.9612
# In epoch:010|batch:0130, train_loss:0.256737, train_ap:0.8751, train_acc:0.8608, train_auc:0.9527
# In epoch:010|batch:0140, train_loss:0.256559, train_ap:0.8956, train_acc:0.8887, train_auc:0.9628
# In epoch:010|batch:0150, train_loss:0.256669, train_ap:0.8790, train_acc:0.8828, train_auc:0.9574
# In epoch:010|batch:0160, train_loss:0.256520, train_ap:0.8957, train_acc:0.8735, train_auc:0.9564
# In epoch:010|batch:0170, train_loss:0.256819, train_ap:0.8800, train_acc:0.8794, train_auc:0.9568
# In epoch:010|batch:0000, val_loss:0.000122, val_ap:0.8976, val_acc:0.8784, val_auc:0.9604
# In epoch:010|batch:0010, val_loss:0.000124, val_ap:0.8827, val_acc:0.8789, val_auc:0.9562
# In epoch:010|batch:0020, val_loss:0.000123, val_ap:0.8684, val_acc:0.8687, val_auc:0.9536
# In epoch:010|batch:0030, val_loss:0.000122, val_ap:0.9044, val_acc:0.8794, val_auc:0.9652
# In epoch:010|batch:0040, val_loss:0.000123, val_ap:0.8937, val_acc:0.8770, val_auc:0.9579
# G: 0.920851, D: 0.649752, ALL: 0.785301
# In epoch:011|batch:0000, train_loss:0.251572, train_ap:0.8845, train_acc:0.8823, train_auc:0.9584
# In epoch:011|batch:0010, train_loss:0.254281, train_ap:0.8911, train_acc:0.8721, train_auc:0.9576
# In epoch:011|batch:0020, train_loss:0.255713, train_ap:0.8757, train_acc:0.8633, train_auc:0.9480
# In epoch:011|batch:0030, train_loss:0.256032, train_ap:0.8963, train_acc:0.8853, train_auc:0.9613
# In epoch:011|batch:0040, train_loss:0.256336, train_ap:0.8980, train_acc:0.8809, train_auc:0.9635
# In epoch:011|batch:0050, train_loss:0.256477, train_ap:0.8793, train_acc:0.8657, train_auc:0.9513
# In epoch:011|batch:0060, train_loss:0.255720, train_ap:0.8913, train_acc:0.8804, train_auc:0.9612
# In epoch:011|batch:0070, train_loss:0.255136, train_ap:0.9021, train_acc:0.8848, train_auc:0.9630
# In epoch:011|batch:0080, train_loss:0.255983, train_ap:0.8824, train_acc:0.8784, train_auc:0.9537
# In epoch:011|batch:0090, train_loss:0.256270, train_ap:0.8893, train_acc:0.8799, train_auc:0.9598
# In epoch:011|batch:0100, train_loss:0.256530, train_ap:0.8790, train_acc:0.8721, train_auc:0.9559
# In epoch:011|batch:0110, train_loss:0.256244, train_ap:0.8873, train_acc:0.8687, train_auc:0.9602
# In epoch:011|batch:0120, train_loss:0.256208, train_ap:0.8918, train_acc:0.8818, train_auc:0.9594
# In epoch:011|batch:0130, train_loss:0.256046, train_ap:0.8778, train_acc:0.8931, train_auc:0.9597
# In epoch:011|batch:0140, train_loss:0.256525, train_ap:0.8810, train_acc:0.8716, train_auc:0.9542
# In epoch:011|batch:0150, train_loss:0.256472, train_ap:0.8784, train_acc:0.8726, train_auc:0.9587
# In epoch:011|batch:0160, train_loss:0.256356, train_ap:0.8818, train_acc:0.8662, train_auc:0.9546
# In epoch:011|batch:0170, train_loss:0.256258, train_ap:0.8787, train_acc:0.8735, train_auc:0.9568
# In epoch:011|batch:0000, val_loss:0.000121, val_ap:0.8902, val_acc:0.8843, val_auc:0.9604
# In epoch:011|batch:0010, val_loss:0.000122, val_ap:0.9222, val_acc:0.8989, val_auc:0.9699
# In epoch:011|batch:0020, val_loss:0.000123, val_ap:0.8971, val_acc:0.8779, val_auc:0.9593
# In epoch:011|batch:0030, val_loss:0.000123, val_ap:0.8807, val_acc:0.8833, val_auc:0.9589
# In epoch:011|batch:0040, val_loss:0.000123, val_ap:0.9078, val_acc:0.8857, val_auc:0.9651
# G: 0.920230, D: 0.647438, ALL: 0.783834
# EarlyStoper count: 01
# In epoch:012|batch:0000, train_loss:0.264429, train_ap:0.8894, train_acc:0.8755, train_auc:0.9572
# In epoch:012|batch:0010, train_loss:0.263859, train_ap:0.8931, train_acc:0.8921, train_auc:0.9576
# In epoch:012|batch:0020, train_loss:0.258083, train_ap:0.9050, train_acc:0.8750, train_auc:0.9617
# In epoch:012|batch:0030, train_loss:0.255249, train_ap:0.8853, train_acc:0.8691, train_auc:0.9568
# In epoch:012|batch:0040, train_loss:0.256685, train_ap:0.8781, train_acc:0.8765, train_auc:0.9523
# In epoch:012|batch:0050, train_loss:0.256593, train_ap:0.8940, train_acc:0.8828, train_auc:0.9586
# In epoch:012|batch:0060, train_loss:0.256100, train_ap:0.9020, train_acc:0.8711, train_auc:0.9596
# In epoch:012|batch:0070, train_loss:0.256149, train_ap:0.8886, train_acc:0.8813, train_auc:0.9594
# In epoch:012|batch:0080, train_loss:0.255691, train_ap:0.9025, train_acc:0.8794, train_auc:0.9636
# In epoch:012|batch:0090, train_loss:0.255718, train_ap:0.8865, train_acc:0.8706, train_auc:0.9559
# In epoch:012|batch:0100, train_loss:0.255286, train_ap:0.8941, train_acc:0.8872, train_auc:0.9637
# In epoch:012|batch:0110, train_loss:0.255141, train_ap:0.9107, train_acc:0.8950, train_auc:0.9652
# In epoch:012|batch:0120, train_loss:0.254796, train_ap:0.8886, train_acc:0.8862, train_auc:0.9610
# In epoch:012|batch:0130, train_loss:0.255267, train_ap:0.8889, train_acc:0.8696, train_auc:0.9549
# In epoch:012|batch:0140, train_loss:0.255457, train_ap:0.8728, train_acc:0.8701, train_auc:0.9534
# In epoch:012|batch:0150, train_loss:0.255284, train_ap:0.9049, train_acc:0.8872, train_auc:0.9610
# In epoch:012|batch:0160, train_loss:0.255676, train_ap:0.8880, train_acc:0.8799, train_auc:0.9605
# In epoch:012|batch:0170, train_loss:0.255574, train_ap:0.9061, train_acc:0.8818, train_auc:0.9634
# In epoch:012|batch:0000, val_loss:0.000121, val_ap:0.8960, val_acc:0.8706, val_auc:0.9628
# In epoch:012|batch:0010, val_loss:0.000123, val_ap:0.8946, val_acc:0.8706, val_auc:0.9632
# In epoch:012|batch:0020, val_loss:0.000124, val_ap:0.8899, val_acc:0.8770, val_auc:0.9572
# In epoch:012|batch:0030, val_loss:0.000123, val_ap:0.8912, val_acc:0.8618, val_auc:0.9597
# In epoch:012|batch:0040, val_loss:0.000123, val_ap:0.8953, val_acc:0.8716, val_auc:0.9628
# G: 0.920787, D: 0.652318, ALL: 0.786553
# In epoch:013|batch:0000, train_loss:0.255672, train_ap:0.8973, train_acc:0.8667, train_auc:0.9590
# In epoch:013|batch:0010, train_loss:0.255725, train_ap:0.8923, train_acc:0.8882, train_auc:0.9604
# In epoch:013|batch:0020, train_loss:0.252385, train_ap:0.9103, train_acc:0.8896, train_auc:0.9647
# In epoch:013|batch:0030, train_loss:0.252559, train_ap:0.8951, train_acc:0.8848, train_auc:0.9560
# In epoch:013|batch:0040, train_loss:0.252698, train_ap:0.9009, train_acc:0.8711, train_auc:0.9591
# In epoch:013|batch:0050, train_loss:0.252452, train_ap:0.8811, train_acc:0.8818, train_auc:0.9578
# In epoch:013|batch:0060, train_loss:0.252546, train_ap:0.9125, train_acc:0.8853, train_auc:0.9642
# In epoch:013|batch:0070, train_loss:0.252766, train_ap:0.8774, train_acc:0.8823, train_auc:0.9594
# In epoch:013|batch:0080, train_loss:0.252500, train_ap:0.8953, train_acc:0.8872, train_auc:0.9650
# In epoch:013|batch:0090, train_loss:0.252633, train_ap:0.9025, train_acc:0.8779, train_auc:0.9631
# In epoch:013|batch:0100, train_loss:0.253256, train_ap:0.9008, train_acc:0.8794, train_auc:0.9621
# In epoch:013|batch:0110, train_loss:0.253007, train_ap:0.8929, train_acc:0.8818, train_auc:0.9653
# In epoch:013|batch:0120, train_loss:0.252904, train_ap:0.9055, train_acc:0.8857, train_auc:0.9638
# In epoch:013|batch:0130, train_loss:0.253599, train_ap:0.8782, train_acc:0.8784, train_auc:0.9536
# In epoch:013|batch:0140, train_loss:0.253643, train_ap:0.9002, train_acc:0.8789, train_auc:0.9627
# In epoch:013|batch:0150, train_loss:0.254196, train_ap:0.8810, train_acc:0.8750, train_auc:0.9538
# In epoch:013|batch:0160, train_loss:0.254568, train_ap:0.8931, train_acc:0.8799, train_auc:0.9574
# In epoch:013|batch:0170, train_loss:0.254494, train_ap:0.8981, train_acc:0.8721, train_auc:0.9596
# In epoch:013|batch:0000, val_loss:0.000129, val_ap:0.8921, val_acc:0.8662, val_auc:0.9577
# In epoch:013|batch:0010, val_loss:0.000122, val_ap:0.9061, val_acc:0.8740, val_auc:0.9628
# In epoch:013|batch:0020, val_loss:0.000122, val_ap:0.9024, val_acc:0.8813, val_auc:0.9630
# In epoch:013|batch:0030, val_loss:0.000122, val_ap:0.9009, val_acc:0.8779, val_auc:0.9622
# In epoch:013|batch:0040, val_loss:0.000122, val_ap:0.8982, val_acc:0.8745, val_auc:0.9619
# G: 0.921916, D: 0.656021, ALL: 0.788969
# In epoch:014|batch:0000, train_loss:0.265837, train_ap:0.8879, train_acc:0.8638, train_auc:0.9561
# In epoch:014|batch:0010, train_loss:0.250661, train_ap:0.8898, train_acc:0.8721, train_auc:0.9553
# In epoch:014|batch:0020, train_loss:0.252406, train_ap:0.8946, train_acc:0.8804, train_auc:0.9597
# In epoch:014|batch:0030, train_loss:0.253703, train_ap:0.9071, train_acc:0.8833, train_auc:0.9652
# In epoch:014|batch:0040, train_loss:0.253936, train_ap:0.8974, train_acc:0.8853, train_auc:0.9600
# In epoch:014|batch:0050, train_loss:0.253710, train_ap:0.8736, train_acc:0.8701, train_auc:0.9585
# In epoch:014|batch:0060, train_loss:0.253830, train_ap:0.9109, train_acc:0.8750, train_auc:0.9607
# In epoch:014|batch:0070, train_loss:0.253421, train_ap:0.8847, train_acc:0.8774, train_auc:0.9595
# In epoch:014|batch:0080, train_loss:0.254338, train_ap:0.8954, train_acc:0.8745, train_auc:0.9589
# In epoch:014|batch:0090, train_loss:0.253252, train_ap:0.8800, train_acc:0.8877, train_auc:0.9592
# In epoch:014|batch:0100, train_loss:0.253011, train_ap:0.8879, train_acc:0.8750, train_auc:0.9598
# In epoch:014|batch:0110, train_loss:0.253845, train_ap:0.8881, train_acc:0.8926, train_auc:0.9627
# In epoch:014|batch:0120, train_loss:0.253670, train_ap:0.8926, train_acc:0.8906, train_auc:0.9617
# In epoch:014|batch:0130, train_loss:0.253576, train_ap:0.8977, train_acc:0.8916, train_auc:0.9623
# In epoch:014|batch:0140, train_loss:0.253672, train_ap:0.8774, train_acc:0.8823, train_auc:0.9578
# In epoch:014|batch:0150, train_loss:0.253237, train_ap:0.8849, train_acc:0.8823, train_auc:0.9601
# In epoch:014|batch:0160, train_loss:0.253245, train_ap:0.9036, train_acc:0.8716, train_auc:0.9592
# In epoch:014|batch:0170, train_loss:0.253807, train_ap:0.8952, train_acc:0.8789, train_auc:0.9605
# In epoch:014|batch:0000, val_loss:0.000122, val_ap:0.9011, val_acc:0.8687, val_auc:0.9605
# In epoch:014|batch:0010, val_loss:0.000124, val_ap:0.8922, val_acc:0.8691, val_auc:0.9557
# In epoch:014|batch:0020, val_loss:0.000121, val_ap:0.9057, val_acc:0.8804, val_auc:0.9619
# In epoch:014|batch:0030, val_loss:0.000122, val_ap:0.8809, val_acc:0.8750, val_auc:0.9590
# In epoch:014|batch:0040, val_loss:0.000122, val_ap:0.9063, val_acc:0.8794, val_auc:0.9628
# G: 0.922216, D: 0.656316, ALL: 0.789266
# In epoch:015|batch:0000, train_loss:0.270333, train_ap:0.8777, train_acc:0.8647, train_auc:0.9521
# In epoch:015|batch:0010, train_loss:0.251861, train_ap:0.9105, train_acc:0.8887, train_auc:0.9641
# In epoch:015|batch:0020, train_loss:0.251542, train_ap:0.9054, train_acc:0.8774, train_auc:0.9641
# In epoch:015|batch:0030, train_loss:0.250152, train_ap:0.8782, train_acc:0.8823, train_auc:0.9553
# In epoch:015|batch:0040, train_loss:0.250626, train_ap:0.8909, train_acc:0.8892, train_auc:0.9581
# In epoch:015|batch:0050, train_loss:0.252496, train_ap:0.8858, train_acc:0.8813, train_auc:0.9574
# In epoch:015|batch:0060, train_loss:0.251864, train_ap:0.8868, train_acc:0.8760, train_auc:0.9606
# In epoch:015|batch:0070, train_loss:0.251431, train_ap:0.8860, train_acc:0.8730, train_auc:0.9535
# In epoch:015|batch:0080, train_loss:0.252590, train_ap:0.8870, train_acc:0.8872, train_auc:0.9560
# In epoch:015|batch:0090, train_loss:0.252671, train_ap:0.8856, train_acc:0.8853, train_auc:0.9584
# In epoch:015|batch:0100, train_loss:0.252318, train_ap:0.8983, train_acc:0.8779, train_auc:0.9595
# In epoch:015|batch:0110, train_loss:0.252735, train_ap:0.8736, train_acc:0.8691, train_auc:0.9561
# In epoch:015|batch:0120, train_loss:0.252795, train_ap:0.8802, train_acc:0.8750, train_auc:0.9564
# In epoch:015|batch:0130, train_loss:0.252461, train_ap:0.9007, train_acc:0.8828, train_auc:0.9588
# In epoch:015|batch:0140, train_loss:0.252214, train_ap:0.8923, train_acc:0.8716, train_auc:0.9624
# In epoch:015|batch:0150, train_loss:0.252690, train_ap:0.8910, train_acc:0.8765, train_auc:0.9562
# In epoch:015|batch:0160, train_loss:0.252999, train_ap:0.8894, train_acc:0.8770, train_auc:0.9584
# In epoch:015|batch:0170, train_loss:0.252899, train_ap:0.9027, train_acc:0.8828, train_auc:0.9659
# In epoch:015|batch:0000, val_loss:0.000118, val_ap:0.8989, val_acc:0.8838, val_auc:0.9632
# In epoch:015|batch:0010, val_loss:0.000121, val_ap:0.8871, val_acc:0.8901, val_auc:0.9639
# In epoch:015|batch:0020, val_loss:0.000123, val_ap:0.9007, val_acc:0.8931, val_auc:0.9626
# In epoch:015|batch:0030, val_loss:0.000122, val_ap:0.8894, val_acc:0.8809, val_auc:0.9586
# In epoch:015|batch:0040, val_loss:0.000122, val_ap:0.8879, val_acc:0.8867, val_auc:0.9550
# G: 0.922114, D: 0.656568, ALL: 0.789341
# In epoch:016|batch:0000, train_loss:0.260287, train_ap:0.8880, train_acc:0.8716, train_auc:0.9578
# In epoch:016|batch:0010, train_loss:0.252792, train_ap:0.9031, train_acc:0.8804, train_auc:0.9652
# In epoch:016|batch:0020, train_loss:0.253410, train_ap:0.8622, train_acc:0.8774, train_auc:0.9527
# In epoch:016|batch:0030, train_loss:0.253566, train_ap:0.8975, train_acc:0.8765, train_auc:0.9607
# In epoch:016|batch:0040, train_loss:0.252916, train_ap:0.9149, train_acc:0.8857, train_auc:0.9652
# In epoch:016|batch:0050, train_loss:0.253238, train_ap:0.8812, train_acc:0.8760, train_auc:0.9550
# In epoch:016|batch:0060, train_loss:0.252888, train_ap:0.8934, train_acc:0.8774, train_auc:0.9594
# In epoch:016|batch:0070, train_loss:0.253577, train_ap:0.9046, train_acc:0.8931, train_auc:0.9625
# In epoch:016|batch:0080, train_loss:0.253082, train_ap:0.9011, train_acc:0.8862, train_auc:0.9640
# In epoch:016|batch:0090, train_loss:0.252550, train_ap:0.8829, train_acc:0.8750, train_auc:0.9560
# In epoch:016|batch:0100, train_loss:0.252876, train_ap:0.8769, train_acc:0.8745, train_auc:0.9570
# In epoch:016|batch:0110, train_loss:0.252764, train_ap:0.8940, train_acc:0.8721, train_auc:0.9592
# In epoch:016|batch:0120, train_loss:0.252985, train_ap:0.8849, train_acc:0.8726, train_auc:0.9561
# In epoch:016|batch:0130, train_loss:0.253405, train_ap:0.8945, train_acc:0.8853, train_auc:0.9610
# In epoch:016|batch:0140, train_loss:0.253301, train_ap:0.8963, train_acc:0.8735, train_auc:0.9623
# In epoch:016|batch:0150, train_loss:0.253237, train_ap:0.8938, train_acc:0.8794, train_auc:0.9601
# In epoch:016|batch:0160, train_loss:0.253017, train_ap:0.9058, train_acc:0.8877, train_auc:0.9628
# In epoch:016|batch:0170, train_loss:0.252877, train_ap:0.8885, train_acc:0.8872, train_auc:0.9626
# In epoch:016|batch:0000, val_loss:0.000123, val_ap:0.8844, val_acc:0.8818, val_auc:0.9614
# In epoch:016|batch:0010, val_loss:0.000122, val_ap:0.8980, val_acc:0.8804, val_auc:0.9589
# In epoch:016|batch:0020, val_loss:0.000121, val_ap:0.8839, val_acc:0.8799, val_auc:0.9611
# In epoch:016|batch:0030, val_loss:0.000121, val_ap:0.8968, val_acc:0.8877, val_auc:0.9629
# In epoch:016|batch:0040, val_loss:0.000122, val_ap:0.8896, val_acc:0.8799, val_auc:0.9590
# G: 0.921772, D: 0.655979, ALL: 0.788876
# EarlyStoper count: 01
# In epoch:017|batch:0000, train_loss:0.246819, train_ap:0.9036, train_acc:0.8799, train_auc:0.9628
# In epoch:017|batch:0010, train_loss:0.243767, train_ap:0.9001, train_acc:0.8896, train_auc:0.9626
# In epoch:017|batch:0020, train_loss:0.245434, train_ap:0.9034, train_acc:0.8838, train_auc:0.9613
# In epoch:017|batch:0030, train_loss:0.247551, train_ap:0.8793, train_acc:0.8799, train_auc:0.9550
# In epoch:017|batch:0040, train_loss:0.249170, train_ap:0.8998, train_acc:0.8882, train_auc:0.9597
# In epoch:017|batch:0050, train_loss:0.251199, train_ap:0.8873, train_acc:0.8691, train_auc:0.9518
# In epoch:017|batch:0060, train_loss:0.251836, train_ap:0.9070, train_acc:0.8804, train_auc:0.9589
# In epoch:017|batch:0070, train_loss:0.251561, train_ap:0.9081, train_acc:0.8828, train_auc:0.9641
# In epoch:017|batch:0080, train_loss:0.251437, train_ap:0.8941, train_acc:0.8789, train_auc:0.9597
# In epoch:017|batch:0090, train_loss:0.251074, train_ap:0.8903, train_acc:0.8755, train_auc:0.9591
# In epoch:017|batch:0100, train_loss:0.251158, train_ap:0.9050, train_acc:0.8804, train_auc:0.9639
# In epoch:017|batch:0110, train_loss:0.251499, train_ap:0.9097, train_acc:0.8848, train_auc:0.9611
# In epoch:017|batch:0120, train_loss:0.251903, train_ap:0.8728, train_acc:0.8735, train_auc:0.9534
# In epoch:017|batch:0130, train_loss:0.252446, train_ap:0.8982, train_acc:0.8813, train_auc:0.9605
# In epoch:017|batch:0140, train_loss:0.252691, train_ap:0.8794, train_acc:0.8647, train_auc:0.9511
# In epoch:017|batch:0150, train_loss:0.252228, train_ap:0.8953, train_acc:0.8784, train_auc:0.9578
# In epoch:017|batch:0160, train_loss:0.252263, train_ap:0.9057, train_acc:0.8896, train_auc:0.9658
# In epoch:017|batch:0170, train_loss:0.252849, train_ap:0.8619, train_acc:0.8667, train_auc:0.9500
# In epoch:017|batch:0000, val_loss:0.000113, val_ap:0.9107, val_acc:0.8936, val_auc:0.9661
# In epoch:017|batch:0010, val_loss:0.000121, val_ap:0.8816, val_acc:0.8823, val_auc:0.9585
# In epoch:017|batch:0020, val_loss:0.000122, val_ap:0.9051, val_acc:0.8892, val_auc:0.9639
# In epoch:017|batch:0030, val_loss:0.000121, val_ap:0.9060, val_acc:0.8828, val_auc:0.9644
# In epoch:017|batch:0040, val_loss:0.000121, val_ap:0.8981, val_acc:0.8789, val_auc:0.9591
# G: 0.922022, D: 0.654675, ALL: 0.788348
# EarlyStoper count: 02
# In epoch:018|batch:0000, train_loss:0.246917, train_ap:0.8935, train_acc:0.8774, train_auc:0.9612
# In epoch:018|batch:0010, train_loss:0.249376, train_ap:0.8700, train_acc:0.8677, train_auc:0.9556
# In epoch:018|batch:0020, train_loss:0.245973, train_ap:0.9079, train_acc:0.8950, train_auc:0.9668
# In epoch:018|batch:0030, train_loss:0.247439, train_ap:0.9062, train_acc:0.8843, train_auc:0.9649
# In epoch:018|batch:0040, train_loss:0.247612, train_ap:0.8978, train_acc:0.8745, train_auc:0.9608
# In epoch:018|batch:0050, train_loss:0.248298, train_ap:0.8850, train_acc:0.8794, train_auc:0.9578
# In epoch:018|batch:0060, train_loss:0.248966, train_ap:0.8902, train_acc:0.8804, train_auc:0.9622
# In epoch:018|batch:0070, train_loss:0.248595, train_ap:0.9132, train_acc:0.8872, train_auc:0.9630
# In epoch:018|batch:0080, train_loss:0.247870, train_ap:0.9109, train_acc:0.8872, train_auc:0.9632
# In epoch:018|batch:0090, train_loss:0.248152, train_ap:0.9085, train_acc:0.8916, train_auc:0.9655
# In epoch:018|batch:0100, train_loss:0.248791, train_ap:0.8900, train_acc:0.8745, train_auc:0.9575
# In epoch:018|batch:0110, train_loss:0.249126, train_ap:0.8904, train_acc:0.8862, train_auc:0.9587
# In epoch:018|batch:0120, train_loss:0.249756, train_ap:0.9142, train_acc:0.8901, train_auc:0.9672
# In epoch:018|batch:0130, train_loss:0.250461, train_ap:0.8927, train_acc:0.8862, train_auc:0.9597
# In epoch:018|batch:0140, train_loss:0.250567, train_ap:0.8952, train_acc:0.8662, train_auc:0.9555
# In epoch:018|batch:0150, train_loss:0.250229, train_ap:0.8853, train_acc:0.8887, train_auc:0.9605
# In epoch:018|batch:0160, train_loss:0.250083, train_ap:0.8895, train_acc:0.8809, train_auc:0.9592
# In epoch:018|batch:0170, train_loss:0.250153, train_ap:0.8633, train_acc:0.8647, train_auc:0.9468
# In epoch:018|batch:0000, val_loss:0.000124, val_ap:0.8899, val_acc:0.8882, val_auc:0.9590
# In epoch:018|batch:0010, val_loss:0.000122, val_ap:0.9160, val_acc:0.8906, val_auc:0.9645
# In epoch:018|batch:0020, val_loss:0.000120, val_ap:0.9040, val_acc:0.8872, val_auc:0.9642
# In epoch:018|batch:0030, val_loss:0.000120, val_ap:0.9110, val_acc:0.8906, val_auc:0.9672
# In epoch:018|batch:0040, val_loss:0.000121, val_ap:0.8890, val_acc:0.8887, val_auc:0.9629
# G: 0.922229, D: 0.655306, ALL: 0.788768
# EarlyStoper count: 03
# In epoch:019|batch:0000, train_loss:0.245649, train_ap:0.8987, train_acc:0.8828, train_auc:0.9624
# In epoch:019|batch:0010, train_loss:0.251943, train_ap:0.9029, train_acc:0.8779, train_auc:0.9601
# In epoch:019|batch:0020, train_loss:0.247389, train_ap:0.9064, train_acc:0.8794, train_auc:0.9631
# In epoch:019|batch:0030, train_loss:0.247452, train_ap:0.8933, train_acc:0.8853, train_auc:0.9602
# In epoch:019|batch:0040, train_loss:0.248405, train_ap:0.8820, train_acc:0.8726, train_auc:0.9510
# In epoch:019|batch:0050, train_loss:0.248666, train_ap:0.8910, train_acc:0.8804, train_auc:0.9580
# In epoch:019|batch:0060, train_loss:0.249009, train_ap:0.9102, train_acc:0.8882, train_auc:0.9666
# In epoch:019|batch:0070, train_loss:0.249178, train_ap:0.8836, train_acc:0.8701, train_auc:0.9593
# In epoch:019|batch:0080, train_loss:0.249195, train_ap:0.9080, train_acc:0.8716, train_auc:0.9635
# In epoch:019|batch:0090, train_loss:0.248605, train_ap:0.8987, train_acc:0.8848, train_auc:0.9609
# In epoch:019|batch:0100, train_loss:0.248636, train_ap:0.8980, train_acc:0.8867, train_auc:0.9612
# In epoch:019|batch:0110, train_loss:0.248415, train_ap:0.8762, train_acc:0.8721, train_auc:0.9569
# In epoch:019|batch:0120, train_loss:0.248348, train_ap:0.8928, train_acc:0.8760, train_auc:0.9566
# In epoch:019|batch:0130, train_loss:0.249142, train_ap:0.8962, train_acc:0.8809, train_auc:0.9604
# In epoch:019|batch:0140, train_loss:0.249022, train_ap:0.9079, train_acc:0.8774, train_auc:0.9604
# In epoch:019|batch:0150, train_loss:0.248780, train_ap:0.8911, train_acc:0.8794, train_auc:0.9602
# In epoch:019|batch:0160, train_loss:0.249323, train_ap:0.8873, train_acc:0.8804, train_auc:0.9618
# In epoch:019|batch:0170, train_loss:0.249377, train_ap:0.8951, train_acc:0.8799, train_auc:0.9590
# In epoch:019|batch:0000, val_loss:0.000120, val_ap:0.9026, val_acc:0.8745, val_auc:0.9621
# In epoch:019|batch:0010, val_loss:0.000121, val_ap:0.8815, val_acc:0.8818, val_auc:0.9599
# In epoch:019|batch:0020, val_loss:0.000120, val_ap:0.9041, val_acc:0.8711, val_auc:0.9619
# In epoch:019|batch:0030, val_loss:0.000120, val_ap:0.9213, val_acc:0.8926, val_auc:0.9688
# In epoch:019|batch:0040, val_loss:0.000121, val_ap:0.8610, val_acc:0.8623, val_auc:0.9495
# G: 0.922940, D: 0.657831, ALL: 0.790385
# In epoch:020|batch:0000, train_loss:0.257763, train_ap:0.8731, train_acc:0.8848, train_auc:0.9558
# In epoch:020|batch:0010, train_loss:0.246507, train_ap:0.9044, train_acc:0.8877, train_auc:0.9651
# In epoch:020|batch:0020, train_loss:0.245476, train_ap:0.8940, train_acc:0.8892, train_auc:0.9619
# In epoch:020|batch:0030, train_loss:0.246326, train_ap:0.9095, train_acc:0.8857, train_auc:0.9617
# In epoch:020|batch:0040, train_loss:0.247474, train_ap:0.8766, train_acc:0.8740, train_auc:0.9565
# In epoch:020|batch:0050, train_loss:0.247609, train_ap:0.8891, train_acc:0.8770, train_auc:0.9587
# In epoch:020|batch:0060, train_loss:0.248074, train_ap:0.8929, train_acc:0.8809, train_auc:0.9611
# In epoch:020|batch:0070, train_loss:0.247896, train_ap:0.8895, train_acc:0.8745, train_auc:0.9562
# In epoch:020|batch:0080, train_loss:0.248364, train_ap:0.8972, train_acc:0.8833, train_auc:0.9614
# In epoch:020|batch:0090, train_loss:0.248527, train_ap:0.9054, train_acc:0.8804, train_auc:0.9631
# In epoch:020|batch:0100, train_loss:0.248671, train_ap:0.9038, train_acc:0.8809, train_auc:0.9638
# In epoch:020|batch:0110, train_loss:0.248386, train_ap:0.8976, train_acc:0.8887, train_auc:0.9639
# In epoch:020|batch:0120, train_loss:0.248807, train_ap:0.8900, train_acc:0.8799, train_auc:0.9595
# In epoch:020|batch:0130, train_loss:0.248406, train_ap:0.8848, train_acc:0.8755, train_auc:0.9586
# In epoch:020|batch:0140, train_loss:0.248422, train_ap:0.8961, train_acc:0.8867, train_auc:0.9628
# In epoch:020|batch:0150, train_loss:0.249075, train_ap:0.9130, train_acc:0.8784, train_auc:0.9664
# In epoch:020|batch:0160, train_loss:0.249153, train_ap:0.8923, train_acc:0.8823, train_auc:0.9588
# In epoch:020|batch:0170, train_loss:0.249550, train_ap:0.8779, train_acc:0.8872, train_auc:0.9587
# In epoch:020|batch:0000, val_loss:0.000112, val_ap:0.9091, val_acc:0.8931, val_auc:0.9674
# In epoch:020|batch:0010, val_loss:0.000119, val_ap:0.9058, val_acc:0.8901, val_auc:0.9630
# In epoch:020|batch:0020, val_loss:0.000120, val_ap:0.8889, val_acc:0.8740, val_auc:0.9529
# In epoch:020|batch:0030, val_loss:0.000121, val_ap:0.9119, val_acc:0.8892, val_auc:0.9638
# In epoch:020|batch:0040, val_loss:0.000120, val_ap:0.8955, val_acc:0.8779, val_auc:0.9601
# G: 0.922432, D: 0.654086, ALL: 0.788259
# EarlyStoper count: 01
# In epoch:021|batch:0000, train_loss:0.255605, train_ap:0.8982, train_acc:0.8784, train_auc:0.9586
# In epoch:021|batch:0010, train_loss:0.246315, train_ap:0.8988, train_acc:0.8789, train_auc:0.9630
# In epoch:021|batch:0020, train_loss:0.247353, train_ap:0.8856, train_acc:0.8823, train_auc:0.9596
# ...
# In epoch:032|batch:0100, train_loss:0.236420, train_ap:0.9173, train_acc:0.8989, train_auc:0.9708
# In epoch:032|batch:0110, train_loss:0.236121, train_ap:0.8956, train_acc:0.8853, train_auc:0.9609
# In epoch:032|batch:0120, train_loss:0.236181, train_ap:0.8886, train_acc:0.8872, train_auc:0.9584
# In epoch:032|batch:0130, train_loss:0.236727, train_ap:0.8967, train_acc:0.8906, train_auc:0.9613
# In epoch:032|batch:0140, train_loss:0.236898, train_ap:0.9103, train_acc:0.8833, train_auc:0.9640
# In epoch:032|batch:0150, train_loss:0.236649, train_ap:0.9171, train_acc:0.9033, train_auc:0.9704
# In epoch:032|batch:0160, train_loss:0.236981, train_ap:0.8974, train_acc:0.8921, train_auc:0.9616
# In epoch:032|batch:0170, train_loss:0.236644, train_ap:0.9003, train_acc:0.8979, train_auc:0.9667
# In epoch:032|batch:0000, val_loss:0.000126, val_ap:0.8762, val_acc:0.8843, val_auc:0.9564
# In epoch:032|batch:0010, val_loss:0.000124, val_ap:0.9018, val_acc:0.8853, val_auc:0.9655
# In epoch:032|batch:0020, val_loss:0.000125, val_ap:0.9036, val_acc:0.8838, val_auc:0.9623
# In epoch:032|batch:0030, val_loss:0.000125, val_ap:0.9010, val_acc:0.8911, val_auc:0.9600
# In epoch:032|batch:0040, val_loss:0.000125, val_ap:0.8903, val_acc:0.8823, val_auc:0.9580
# G: 0.918099, D: 0.651883, ALL: 0.784991
# EarlyStoper count: 06
# In epoch:033|batch:0000, train_loss:0.256749, train_ap:0.8965, train_acc:0.8774, train_auc:0.9595
# In epoch:033|batch:0010, train_loss:0.241615, train_ap:0.9009, train_acc:0.8940, train_auc:0.9629
# In epoch:033|batch:0020, train_loss:0.239241, train_ap:0.9023, train_acc:0.8979, train_auc:0.9687
# In epoch:033|batch:0030, train_loss:0.235759, train_ap:0.8929, train_acc:0.8843, train_auc:0.9581
# In epoch:033|batch:0040, train_loss:0.236003, train_ap:0.9246, train_acc:0.8984, train_auc:0.9690
# In epoch:033|batch:0050, train_loss:0.235611, train_ap:0.8761, train_acc:0.8809, train_auc:0.9544
# In epoch:033|batch:0060, train_loss:0.236260, train_ap:0.8851, train_acc:0.8774, train_auc:0.9583
# In epoch:033|batch:0070, train_loss:0.236997, train_ap:0.9108, train_acc:0.8975, train_auc:0.9683
# In epoch:033|batch:0080, train_loss:0.237496, train_ap:0.8901, train_acc:0.8809, train_auc:0.9600
# In epoch:033|batch:0090, train_loss:0.237288, train_ap:0.8894, train_acc:0.8843, train_auc:0.9594
# In epoch:033|batch:0100, train_loss:0.236879, train_ap:0.9192, train_acc:0.9067, train_auc:0.9703
# In epoch:033|batch:0110, train_loss:0.236627, train_ap:0.9205, train_acc:0.8945, train_auc:0.9674
# In epoch:033|batch:0120, train_loss:0.236504, train_ap:0.9212, train_acc:0.8960, train_auc:0.9665
# In epoch:033|batch:0130, train_loss:0.236787, train_ap:0.9126, train_acc:0.8809, train_auc:0.9650
# In epoch:033|batch:0140, train_loss:0.237174, train_ap:0.9090, train_acc:0.8892, train_auc:0.9662
# In epoch:033|batch:0150, train_loss:0.236820, train_ap:0.9094, train_acc:0.8887, train_auc:0.9639
# In epoch:033|batch:0160, train_loss:0.236460, train_ap:0.9209, train_acc:0.8955, train_auc:0.9728
# In epoch:033|batch:0170, train_loss:0.236409, train_ap:0.8797, train_acc:0.8833, train_auc:0.9553
# In epoch:033|batch:0000, val_loss:0.000132, val_ap:0.8894, val_acc:0.8818, val_auc:0.9552
# In epoch:033|batch:0010, val_loss:0.000127, val_ap:0.8952, val_acc:0.8799, val_auc:0.9563
# In epoch:033|batch:0020, val_loss:0.000127, val_ap:0.8830, val_acc:0.8862, val_auc:0.9555
# In epoch:033|batch:0030, val_loss:0.000127, val_ap:0.8942, val_acc:0.8838, val_auc:0.9595
# In epoch:033|batch:0040, val_loss:0.000126, val_ap:0.8865, val_acc:0.8755, val_auc:0.9584
# G: 0.917775, D: 0.650705, ALL: 0.784240
# EarlyStoper count: 07
# In epoch:034|batch:0000, train_loss:0.249733, train_ap:0.8930, train_acc:0.8823, train_auc:0.9594
# In epoch:034|batch:0010, train_loss:0.240011, train_ap:0.8942, train_acc:0.8760, train_auc:0.9590
# In epoch:034|batch:0020, train_loss:0.238120, train_ap:0.9037, train_acc:0.8887, train_auc:0.9646
# In epoch:034|batch:0030, train_loss:0.237767, train_ap:0.9080, train_acc:0.8892, train_auc:0.9656
# In epoch:034|batch:0040, train_loss:0.238823, train_ap:0.8986, train_acc:0.8887, train_auc:0.9616
# In epoch:034|batch:0050, train_loss:0.238295, train_ap:0.9044, train_acc:0.8853, train_auc:0.9632
# In epoch:034|batch:0060, train_loss:0.237160, train_ap:0.8926, train_acc:0.8916, train_auc:0.9633
# In epoch:034|batch:0070, train_loss:0.237393, train_ap:0.9131, train_acc:0.8872, train_auc:0.9649
# In epoch:034|batch:0080, train_loss:0.237230, train_ap:0.8849, train_acc:0.8794, train_auc:0.9597
# In epoch:034|batch:0090, train_loss:0.236636, train_ap:0.9087, train_acc:0.8877, train_auc:0.9645
# In epoch:034|batch:0100, train_loss:0.236408, train_ap:0.8932, train_acc:0.8901, train_auc:0.9656
# In epoch:034|batch:0110, train_loss:0.236495, train_ap:0.9080, train_acc:0.8994, train_auc:0.9690
# In epoch:034|batch:0120, train_loss:0.236590, train_ap:0.9049, train_acc:0.8853, train_auc:0.9650
# In epoch:034|batch:0130, train_loss:0.236408, train_ap:0.9152, train_acc:0.8901, train_auc:0.9658
# In epoch:034|batch:0140, train_loss:0.235748, train_ap:0.9155, train_acc:0.8970, train_auc:0.9656
# In epoch:034|batch:0150, train_loss:0.235571, train_ap:0.9168, train_acc:0.8960, train_auc:0.9667
# In epoch:034|batch:0160, train_loss:0.235472, train_ap:0.8901, train_acc:0.8921, train_auc:0.9630
# In epoch:034|batch:0170, train_loss:0.235648, train_ap:0.9096, train_acc:0.8872, train_auc:0.9666
# In epoch:034|batch:0000, val_loss:0.000128, val_ap:0.8861, val_acc:0.8838, val_auc:0.9558
# In epoch:034|batch:0010, val_loss:0.000124, val_ap:0.8705, val_acc:0.8799, val_auc:0.9528
# In epoch:034|batch:0020, val_loss:0.000125, val_ap:0.8808, val_acc:0.8730, val_auc:0.9551
# In epoch:034|batch:0030, val_loss:0.000126, val_ap:0.8986, val_acc:0.8896, val_auc:0.9620
# In epoch:034|batch:0040, val_loss:0.000126, val_ap:0.9009, val_acc:0.8936, val_auc:0.9631
# G: 0.917619, D: 0.648517, ALL: 0.783068
# EarlyStoper count: 08
# In epoch:035|batch:0000, train_loss:0.267770, train_ap:0.8773, train_acc:0.8853, train_auc:0.9540
# In epoch:035|batch:0010, train_loss:0.234656, train_ap:0.8873, train_acc:0.8843, train_auc:0.9617
# In epoch:035|batch:0020, train_loss:0.232894, train_ap:0.9047, train_acc:0.8882, train_auc:0.9643
# In epoch:035|batch:0030, train_loss:0.234395, train_ap:0.9044, train_acc:0.8887, train_auc:0.9672
# In epoch:035|batch:0040, train_loss:0.233618, train_ap:0.9226, train_acc:0.9023, train_auc:0.9731
# In epoch:035|batch:0050, train_loss:0.234164, train_ap:0.8810, train_acc:0.8926, train_auc:0.9607
# In epoch:035|batch:0060, train_loss:0.234181, train_ap:0.8925, train_acc:0.8877, train_auc:0.9645
# In epoch:035|batch:0070, train_loss:0.235532, train_ap:0.8898, train_acc:0.8818, train_auc:0.9563
# In epoch:035|batch:0080, train_loss:0.235282, train_ap:0.9278, train_acc:0.9028, train_auc:0.9735
# In epoch:035|batch:0090, train_loss:0.235148, train_ap:0.8901, train_acc:0.8901, train_auc:0.9626
# In epoch:035|batch:0100, train_loss:0.235334, train_ap:0.9101, train_acc:0.8970, train_auc:0.9672
# In epoch:035|batch:0110, train_loss:0.235389, train_ap:0.9169, train_acc:0.8896, train_auc:0.9659
# In epoch:035|batch:0120, train_loss:0.235366, train_ap:0.9127, train_acc:0.9043, train_auc:0.9663
# In epoch:035|batch:0130, train_loss:0.235217, train_ap:0.8970, train_acc:0.8838, train_auc:0.9589
# In epoch:035|batch:0140, train_loss:0.234909, train_ap:0.9166, train_acc:0.9014, train_auc:0.9683
# In epoch:035|batch:0150, train_loss:0.235426, train_ap:0.8930, train_acc:0.8848, train_auc:0.9609
# In epoch:035|batch:0160, train_loss:0.235154, train_ap:0.9108, train_acc:0.8960, train_auc:0.9687
# In epoch:035|batch:0170, train_loss:0.235356, train_ap:0.8914, train_acc:0.8813, train_auc:0.9576
# In epoch:035|batch:0000, val_loss:0.000117, val_ap:0.8912, val_acc:0.8887, val_auc:0.9633
# In epoch:035|batch:0010, val_loss:0.000122, val_ap:0.8877, val_acc:0.8765, val_auc:0.9565
# In epoch:035|batch:0020, val_loss:0.000124, val_ap:0.8926, val_acc:0.8813, val_auc:0.9568
# In epoch:035|batch:0030, val_loss:0.000125, val_ap:0.9133, val_acc:0.8843, val_auc:0.9673
# In epoch:035|batch:0040, val_loss:0.000125, val_ap:0.8885, val_acc:0.8755, val_auc:0.9551
# G: 0.917853, D: 0.650158, ALL: 0.784005
# EarlyStoper count: 09
# In epoch:036|batch:0000, train_loss:0.249780, train_ap:0.8946, train_acc:0.8882, train_auc:0.9606
# In epoch:036|batch:0010, train_loss:0.238116, train_ap:0.9240, train_acc:0.8984, train_auc:0.9695
# In epoch:036|batch:0020, train_loss:0.235170, train_ap:0.8912, train_acc:0.8989, train_auc:0.9645
# In epoch:036|batch:0030, train_loss:0.234036, train_ap:0.9024, train_acc:0.9009, train_auc:0.9639
# In epoch:036|batch:0040, train_loss:0.234227, train_ap:0.9045, train_acc:0.8887, train_auc:0.9629
# In epoch:036|batch:0050, train_loss:0.233754, train_ap:0.9186, train_acc:0.9023, train_auc:0.9714
# In epoch:036|batch:0060, train_loss:0.233418, train_ap:0.9029, train_acc:0.8970, train_auc:0.9659
# In epoch:036|batch:0070, train_loss:0.233845, train_ap:0.9179, train_acc:0.8994, train_auc:0.9682
# In epoch:036|batch:0080, train_loss:0.233590, train_ap:0.9130, train_acc:0.9014, train_auc:0.9709
# In epoch:036|batch:0090, train_loss:0.233776, train_ap:0.8883, train_acc:0.8867, train_auc:0.9600
# In epoch:036|batch:0100, train_loss:0.234645, train_ap:0.8869, train_acc:0.8916, train_auc:0.9612
# In epoch:036|batch:0110, train_loss:0.234897, train_ap:0.8914, train_acc:0.8945, train_auc:0.9648
# In epoch:036|batch:0120, train_loss:0.235137, train_ap:0.9058, train_acc:0.8926, train_auc:0.9682
# In epoch:036|batch:0130, train_loss:0.235294, train_ap:0.9035, train_acc:0.8809, train_auc:0.9621
# In epoch:036|batch:0140, train_loss:0.235063, train_ap:0.9119, train_acc:0.9053, train_auc:0.9686
# In epoch:036|batch:0150, train_loss:0.234799, train_ap:0.9076, train_acc:0.8877, train_auc:0.9667
# In epoch:036|batch:0160, train_loss:0.234590, train_ap:0.9117, train_acc:0.9053, train_auc:0.9671
# In epoch:036|batch:0170, train_loss:0.234882, train_ap:0.9106, train_acc:0.8940, train_auc:0.9669
# In epoch:036|batch:0000, val_loss:0.000128, val_ap:0.8898, val_acc:0.8813, val_auc:0.9571
# In epoch:036|batch:0010, val_loss:0.000123, val_ap:0.8819, val_acc:0.8833, val_auc:0.9574
# In epoch:036|batch:0020, val_loss:0.000126, val_ap:0.9028, val_acc:0.8813, val_auc:0.9626
# In epoch:036|batch:0030, val_loss:0.000126, val_ap:0.8983, val_acc:0.8804, val_auc:0.9606
# In epoch:036|batch:0040, val_loss:0.000126, val_ap:0.8906, val_acc:0.8906, val_auc:0.9583
# G: 0.917454, D: 0.651210, ALL: 0.784332
# EarlyStoper count: 10
# In epoch:037|batch:0000, train_loss:0.237548, train_ap:0.8894, train_acc:0.8965, train_auc:0.9634
# In epoch:037|batch:0010, train_loss:0.228867, train_ap:0.9067, train_acc:0.8882, train_auc:0.9661
# In epoch:037|batch:0020, train_loss:0.231922, train_ap:0.9230, train_acc:0.9009, train_auc:0.9727
# In epoch:037|batch:0030, train_loss:0.231708, train_ap:0.9172, train_acc:0.8989, train_auc:0.9668
# In epoch:037|batch:0040, train_loss:0.232661, train_ap:0.9243, train_acc:0.8984, train_auc:0.9711
# In epoch:037|batch:0050, train_loss:0.232445, train_ap:0.9235, train_acc:0.8999, train_auc:0.9712
# In epoch:037|batch:0060, train_loss:0.232304, train_ap:0.8959, train_acc:0.8896, train_auc:0.9655
# In epoch:037|batch:0070, train_loss:0.233541, train_ap:0.9027, train_acc:0.8872, train_auc:0.9643
# In epoch:037|batch:0080, train_loss:0.234202, train_ap:0.9024, train_acc:0.8955, train_auc:0.9665
# In epoch:037|batch:0090, train_loss:0.233925, train_ap:0.9146, train_acc:0.8882, train_auc:0.9696
# In epoch:037|batch:0100, train_loss:0.233326, train_ap:0.9156, train_acc:0.8936, train_auc:0.9670
# In epoch:037|batch:0110, train_loss:0.233186, train_ap:0.9127, train_acc:0.9014, train_auc:0.9671
# In epoch:037|batch:0120, train_loss:0.233766, train_ap:0.9010, train_acc:0.8760, train_auc:0.9630
# In epoch:037|batch:0130, train_loss:0.233696, train_ap:0.8956, train_acc:0.8838, train_auc:0.9616
# In epoch:037|batch:0140, train_loss:0.234287, train_ap:0.9071, train_acc:0.8887, train_auc:0.9631
# In epoch:037|batch:0150, train_loss:0.234269, train_ap:0.9036, train_acc:0.8936, train_auc:0.9646
# In epoch:037|batch:0160, train_loss:0.233990, train_ap:0.9234, train_acc:0.8916, train_auc:0.9705
# In epoch:037|batch:0170, train_loss:0.234190, train_ap:0.9000, train_acc:0.8965, train_auc:0.9659
# In epoch:037|batch:0000, val_loss:0.000128, val_ap:0.9025, val_acc:0.8804, val_auc:0.9580
# In epoch:037|batch:0010, val_loss:0.000126, val_ap:0.8866, val_acc:0.8843, val_auc:0.9588
# In epoch:037|batch:0020, val_loss:0.000127, val_ap:0.9026, val_acc:0.8955, val_auc:0.9619
# In epoch:037|batch:0030, val_loss:0.000127, val_ap:0.8913, val_acc:0.8804, val_auc:0.9636
# In epoch:037|batch:0040, val_loss:0.000126, val_ap:0.8946, val_acc:0.8867, val_auc:0.9588
# G: 0.917647, D: 0.650915, ALL: 0.784281
# EarlyStoper count: 11
# In epoch:038|batch:0000, train_loss:0.260669, train_ap:0.8831, train_acc:0.8774, train_auc:0.9567
# In epoch:038|batch:0010, train_loss:0.238685, train_ap:0.9046, train_acc:0.8916, train_auc:0.9652
# In epoch:038|batch:0020, train_loss:0.234633, train_ap:0.9106, train_acc:0.8994, train_auc:0.9687
# In epoch:038|batch:0030, train_loss:0.232747, train_ap:0.9002, train_acc:0.8901, train_auc:0.9685
# In epoch:038|batch:0040, train_loss:0.231419, train_ap:0.9011, train_acc:0.8804, train_auc:0.9623
# In epoch:038|batch:0050, train_loss:0.232097, train_ap:0.8927, train_acc:0.8867, train_auc:0.9612
# In epoch:038|batch:0060, train_loss:0.232081, train_ap:0.8950, train_acc:0.8906, train_auc:0.9611
# In epoch:038|batch:0070, train_loss:0.231939, train_ap:0.8996, train_acc:0.8818, train_auc:0.9627
# In epoch:038|batch:0080, train_loss:0.232472, train_ap:0.9215, train_acc:0.9053, train_auc:0.9726
# In epoch:038|batch:0090, train_loss:0.233307, train_ap:0.9074, train_acc:0.8921, train_auc:0.9641
# In epoch:038|batch:0100, train_loss:0.232868, train_ap:0.9094, train_acc:0.9038, train_auc:0.9695
# In epoch:038|batch:0110, train_loss:0.233218, train_ap:0.9093, train_acc:0.8862, train_auc:0.9638
# In epoch:038|batch:0120, train_loss:0.233329, train_ap:0.8944, train_acc:0.8896, train_auc:0.9636
# In epoch:038|batch:0130, train_loss:0.233498, train_ap:0.9054, train_acc:0.8979, train_auc:0.9656
# In epoch:038|batch:0140, train_loss:0.233013, train_ap:0.9184, train_acc:0.8989, train_auc:0.9710
# In epoch:038|batch:0150, train_loss:0.233305, train_ap:0.9198, train_acc:0.8901, train_auc:0.9681
# In epoch:038|batch:0160, train_loss:0.233332, train_ap:0.9052, train_acc:0.8862, train_auc:0.9620
# In epoch:038|batch:0170, train_loss:0.233638, train_ap:0.8978, train_acc:0.8936, train_auc:0.9626
# In epoch:038|batch:0000, val_loss:0.000131, val_ap:0.8979, val_acc:0.8833, val_auc:0.9572
# In epoch:038|batch:0010, val_loss:0.000122, val_ap:0.9038, val_acc:0.8872, val_auc:0.9639
# In epoch:038|batch:0020, val_loss:0.000124, val_ap:0.8828, val_acc:0.8804, val_auc:0.9554
# In epoch:038|batch:0030, val_loss:0.000125, val_ap:0.8889, val_acc:0.8911, val_auc:0.9577
# In epoch:038|batch:0040, val_loss:0.000126, val_ap:0.8933, val_acc:0.8872, val_auc:0.9616
# G: 0.917252, D: 0.650410, ALL: 0.783831
# EarlyStoper count: 12
# Early Stopping!
# Best val_metric is: 0.7875009
# In test batch:0000
# In test batch:0010
# In test batch:0020
# In test batch:0030
# In test batch:0040
# In test batch:0050
# In test batch:0060
# In test batch:0070
# In test batch:0080
# In test batch:0090
# In test batch:0100
# In test batch:0110
# In test batch:0120
# In test batch:0130
# In test batch:0140
# In test batch:0150
# In test batch:0160
# In test batch:0170
# In test batch:0180
# In test batch:0190
# In test batch:0200
# In test batch:0210
# In test batch:0220
# In test batch:0230
# In test batch:0240
# In test batch:0250
# In test batch:0260
# In test batch:0270
# In test batch:0280
# In test batch:0290
# In test batch:0300
# In test batch:0310
# In test batch:0320
# In test batch:0330
# In test batch:0340
# In test batch:0350
# In test batch:0360
# In test batch:0370
# In test batch:0380
# In test batch:0390
# In test batch:0400
# In test batch:0410
# In test batch:0420
# In test batch:0430
# In test batch:0440
# In test batch:0450
# NN out of fold AP is: 0.8948955718154248

# %%
sub = pd.DataFrame({'customer_ID': test.index,
                    'prediction': torch.softmax(test_nn_0, dim=-1)[:, 1].cpu().numpy()})
sub.to_csv('submission_mlp_delete_na_pytorch.csv', index=False)
display(sub)
# Out:
#                                               customer_ID  prediction
# 0       00000469ba478561f23a92a868bd366de6f6527a684c9a...    0.121014
# 1       00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...    0.001169
# 2       0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...    0.035061
# 3       00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...    0.502331
# 4       00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...    0.947843
# ...                                                   ...         ...
# 924616  ffff952c631f2c911b8a2a8ca56ea6e656309a83d2f64c...    0.034961
# 924617  ffffcf5df59e5e0bba2a5ac4578a34e2b5aa64a1546cd3...    0.865849
# 924618  ffffd61f098cc056dbd7d2a21380c4804bbfe60856f475...    0.815751
# 924619  ffffddef1fc3643ea179c93245b68dca0f36941cd83977...    0.613403
# 924620  fffffa7cf7e453e1acc6a1426475d5cb9400859f82ff61...    0.163546
#
# [924621 rows x 2 columns]
